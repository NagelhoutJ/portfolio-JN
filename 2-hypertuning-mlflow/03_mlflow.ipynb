# %%
from pathlib import Path
import torch
import torch.nn as nn
from loguru import logger
import warnings
warnings.simplefilter("ignore", UserWarning)

# %% [markdown]
# Let's use the mads_datasets package (see [github](https://github.com/raoulg/mads_datasets) for more details) which I created for these lessons to give everyone easy access to the datasets we use for training.

# %%
from mads_datasets import DatasetFactoryProvider, DatasetType
from mltrainer.preprocessors import BasePreprocessor

for dataset in DatasetType:
    print(dataset)
# Out:
# DatasetType.FLOWERS
# DatasetType.IMDB
# DatasetType.GESTURES
# DatasetType.FASHION
# DatasetType.SUNSPOTS
# DatasetType.IRIS
# DatasetType.PENGUINS
# DatasetType.FAVORITA
# DatasetType.SECURE

# %% [markdown]
# There are a few datasets. For images, we can use FLOWERS (~3000 photos of flowers in 5 categories) and FASHION (60k fashion icons 28x28 pixels big).

# %% [markdown]
# Lets start with our good'ol MNIST.

# %%
fashionfactory = DatasetFactoryProvider.create_factory(DatasetType.FASHION)
batchsize = 64
preprocessor = BasePreprocessor()
streamers = fashionfactory.create_datastreamer(batchsize=batchsize, preprocessor=preprocessor)
train = streamers["train"]
valid = streamers["valid"]
trainstreamer = train.stream()
validstreamer = valid.stream()
# Out:
# 2025-09-19 20:19:24.449 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at C:\Users\j.nagelhout\.cache\mads_datasets\fashionmnist
# 2025-09-19 20:19:24.450 | INFO     | mads_datasets.base:download_data:124 - File already exists at C:\Users\j.nagelhout\.cache\mads_datasets\fashionmnist\fashionmnist.pt

# %% [markdown]
# We can obtain an item:

# %%
x, y = next(iter(trainstreamer))
x.shape, y.shape
# Out:
# (torch.Size([64, 1, 28, 28]), torch.Size([64]))

# %% [markdown]
# The image follows the channels-first convention: (channel, width, height). The label is an integer.
#
# Let's re-use the model we had:

# %%
import torch
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
    print("Using MPS")
elif torch.cuda.is_available():
    device = "cuda:0"
    print("using cuda")
else:
    device = "cpu"
    print("using cpu")
# Out:
# using cpu

# %%
from torch import nn
print(f"Using {device} device")

# Define model
class CNN(nn.Module):
    def __init__(self, filters, units1, units2, input_size=(32, 1, 28, 28)):
        super().__init__()
        self.in_channels = input_size[1]
        self.input_size = input_size
        self.filters = filters
        self.units1 = units1
        self.units2 = units2

        self.convolutions = nn.Sequential(
            nn.Conv2d(self.in_channels, filters, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )

        activation_map_size = self._conv_test(input_size)
        logger.info(f"Aggregating activationmap with size {activation_map_size}")
        self.agg = nn.AvgPool2d(activation_map_size)

        self.dense = nn.Sequential(
            nn.Flatten(),
            nn.Linear(filters, units1),
            nn.ReLU(),
            nn.Linear(units1, units2),
            nn.ReLU(),
            nn.Linear(units2, 10)
        )

    def _conv_test(self, input_size = (32, 1, 28, 28)):
        x = torch.ones(input_size)
        x = self.convolutions(x)
        return x.shape[-2:]

    def forward(self, x):
        x = self.convolutions(x)
        x = self.agg(x)
        logits = self.dense(x)
        return logits

model = CNN(filters=32, units1=128, units2=64).to("cpu")
# Out:
# 2025-09-19 20:19:24.532 | INFO     | __main__:__init__:27 - Aggregating activationmap with size torch.Size([2, 2])
# Using cpu device

# %%
from mltrainer.imagemodels import CNNConfig, CNNblocks

# %%
config = CNNConfig(
    matrixshape = (28, 28), # every image is 28x28
    batchsize = batchsize,
    input_channels = 1, # we have black and white images, so only one channel
    hidden = 32, # number of filters
    kernel_size = 3, # kernel size of the convolution
    maxpool = 3, # kernel size of the maxpool
    num_layers = 4, # we will stack 4 Convolutional blocks, each with two Conv2d layers
    num_classes = 10,
)

# %%
model = CNNblocks(config)
model.config
# Out:
# Calculated matrix size: 9
# Caluclated flatten size: 288
# {'matrixshape': (28, 28),
#  'batchsize': 64,
#  'input_channels': 1,
#  'hidden': 32,
#  'kernel_size': 3,
#  'maxpool': 3,
#  'num_layers': 4,
#  'num_classes': 10}

# %%
from torchinfo import summary
summary(model, input_size=(32, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNNblocks                                [32, 10]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─ConvBlock: 2-1                    [32, 32, 28, 28]          --
# │    │    └─Sequential: 3-1              [32, 32, 28, 28]          9,568
# │    └─ConvBlock: 2-2                    [32, 32, 28, 28]          --
# │    │    └─Sequential: 3-2              [32, 32, 28, 28]          18,496
# │    └─ReLU: 2-3                         [32, 32, 28, 28]          --
# │    └─MaxPool2d: 2-4                    [32, 32, 9, 9]            --
# │    └─ConvBlock: 2-5                    [32, 32, 9, 9]            --
# │    │    └─Sequential: 3-3              [32, 32, 9, 9]            18,496
# │    └─ReLU: 2-6                         [32, 32, 9, 9]            --
# │    └─ConvBlock: 2-7                    [32, 32, 9, 9]            --
# │    │    └─Sequential: 3-4              [32, 32, 9, 9]            18,496
# │    └─ReLU: 2-8                         [32, 32, 9, 9]            --
# │    └─MaxPool2d: 2-9                    [32, 32, 3, 3]            --
# │    └─ConvBlock: 2-10                   [32, 32, 3, 3]            --
# │    │    └─Sequential: 3-5              [32, 32, 3, 3]            18,496
# │    └─ReLU: 2-11                        [32, 32, 3, 3]            --
# ├─Sequential: 1-2                        [32, 10]                  --
# │    └─Flatten: 2-12                     [32, 288]                 --
# │    └─Linear: 2-13                      [32, 32]                  9,248
# │    └─ReLU: 2-14                        [32, 32]                  --
# │    └─Linear: 2-15                      [32, 10]                  330
# ==========================================================================================
# Total params: 93,130
# Trainable params: 93,130
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 805.59
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 28.50
# Params size (MB): 0.37
# Estimated Total Size (MB): 28.98
# ==========================================================================================

# %% [markdown]
# And set up the optimizer, loss and accuracy.

# %%
import torch.optim as optim
from mltrainer import metrics
optimizer = optim.Adam
loss_fn = torch.nn.CrossEntropyLoss()
accuracy = metrics.Accuracy()

# %%
yhat = model(x.to("cpu"))
accuracy(y.to("cpu"), yhat)
# Out:
# 0.078125

# %%
from mltrainer import metrics, Trainer, TrainerSettings, ReportTypes
settings = TrainerSettings(
    epochs=3,
    metrics=[accuracy],
    logdir="demo",
    train_steps=100,
    valid_steps=100,
    reporttypes=[ReportTypes.TOML],
)

# %%
trainer = Trainer(
            model=model,
            settings=settings,
            loss_fn=loss_fn,
            optimizer=optimizer,
            traindataloader=trainstreamer,
            validdataloader=validstreamer,
            scheduler=optim.lr_scheduler.ReduceLROnPlateau,
            device=device,
        )
trainer.loop()
# Out:
# 2025-09-19 20:19:24.653 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to demo\20250919-201924
# 2025-09-19 20:19:24.655 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 100/100 [00:05<00:00, 18.96it/s]
# 2025-09-19 20:19:31.697 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.7664 test 0.9804 metric ['0.5995']
# 100%|██████████| 100/100 [00:04<00:00, 20.64it/s]
# 2025-09-19 20:19:38.236 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.8358 test 0.7311 metric ['0.6919']
# 100%|██████████| 100/100 [00:05<00:00, 19.65it/s]
# 2025-09-19 20:19:44.921 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.7208 test 0.6731 metric ['0.7488']
# 100%|██████████| 3/3 [00:20<00:00,  6.75s/it]

# %% [markdown]
# # MLflow
# MLflow is an open-source platform designed to manage the entire Machine Learning (ML) lifecycle, including experimentation, reproducibility, deployment, and governance. It provides a set of APIs and tools to streamline ML workflows, making it easier to track experiments, package code, manage model versions, and deploy models.
#
# Reasons to use MLflow over TensorBoard, gin-config, or Ray:
#
# - End-to-end ML lifecycle management: While TensorBoard focuses on visualizing model training metrics and gin-config on hyperparameter configuration, MLflow covers a broader range of tasks, such as experiment tracking, model packaging, and deployment.
#
# - Framework agnostic: MLflow is not tied to a specific ML framework, making it suitable for projects using different libraries or even multiple libraries.
#
# - Model Registry: MLflow provides a centralized model registry, allowing you to version, track, and manage your models, which is not available in TensorBoard or gin-config.
#
# - Deployment support: MLflow facilitates model deployment to various platforms, such as local, cloud, or Kubernetes environments, whereas TensorBoard and gin-config are not built for deployment tasks.
#
# - Integration with other tools: MLflow integrates with popular tools and platforms like Databricks, AWS, and Azure, making it easy to incorporate into existing workflows.
#
# However, the choice between MLflow and other tools like TensorBoard, gin-config, or Ray depends on your specific use case and the scope of the ML workflow you want to manage.

# %%
experiment_path = "mlflow_test"

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment(experiment_path)
# Out:
# <Experiment: artifact_location='file:c:/GitHub/portfolio-JN/2-hypertuning-mlflow/mlruns/1', creation_time=1758304515015, experiment_id='1', last_update_time=1758304515015, lifecycle_stage='active', name='mlflow_test', tags={}>

# %% [markdown]
# In the code above, we set the MLflow tracking URI to a local SQLite database file. This is done to configure the storage location for MLflow's experiment tracking data, such as metrics, parameters, and artifacts. By specifying a SQLite database, we enable a lightweight and easy-to-use storage solution for tracking the experiments and their associated information.
#
# The line mlflow.set_experiment("mnist_convolutions") sets the active MLflow experiment to "mnist_convolutions". This is useful for organizing and grouping your runs, as it allows you to associate the upcoming ML training runs with a specific experiment name, making it easier to search, compare, and analyze the results later.

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %% [markdown]
# We import functions and classes from the hyperopt library to perform hyperparameter optimization. This library helps us find the best hyperparameter values for our machine learning model by searching through a defined search space and using optimization algorithms like Tree-structured Parzen Estimator (TPE). The goal is to improve our model's performance by tuning its hyperparameters.
#
# Advantages of TPE:
#
# - Model-based approach: TPE is a Bayesian optimization method that models the objective function as a probability distribution. It learns from previous evaluations to decide which points in the search space to explore next, making it more efficient in finding optimal hyperparameters.
#
# - Exploration-exploitation trade-off: TPE balances the trade-off between exploration (searching in new regions of the search space) and exploitation (refining around the current best points). This can lead to better results in problems with complex search spaces.
#
# - Continuous hyperparameter optimization: TPE can handle continuous hyperparameters more naturally, as it builds a probability model to estimate the performance for any given point in the search space.
#
# Lets set up an objective function and start logging some usefull things we might want to track:

# %%
modeldir = Path("models").resolve()
if not modeldir.exists():
    modeldir.mkdir()
    print(f"Created {modeldir}")

# %%
import torch.optim as optim
from mltrainer import metrics, Trainer, TrainerSettings, ReportTypes
from datetime import datetime

# Define the hyperparameter search space
settings = TrainerSettings(
    epochs=3,
    metrics=[accuracy],
    logdir=modeldir,
    train_steps=100,
    valid_steps=100,
    reporttypes=[ReportTypes.MLFLOW, ReportTypes.TOML],
)


# Define the objective function for hyperparameter optimization
def objective(params):
    # Start a new MLflow run for tracking the experiment
    with mlflow.start_run():
        # Set MLflow tags to record metadata about the model and developer
        mlflow.set_tag("model", "convnet")
        mlflow.set_tag("dev", "raoul")
        # Log hyperparameters to MLflow
        mlflow.log_params(params)
        mlflow.log_param("batchsize", f"{batchsize}")


        # Initialize the optimizer, loss function, and accuracy metric
        optimizer = optim.Adam
        loss_fn = torch.nn.CrossEntropyLoss()
        accuracy = metrics.Accuracy()
        config = CNNConfig(
            matrixshape = (28, 28), # every image is 28x28
            batchsize = batchsize,
            input_channels = 1, # we have black and white images, so only one channel
            hidden = params["filters"], # number of filters
            kernel_size = 3, # kernel size of the convolution
            maxpool = 3, # kernel size of the maxpool
            num_layers = 4, # we will stack 4 Convolutional blocks, each with two Conv2d layers
            num_classes = 10,
        )

        # Instantiate the CNN model with the given hyperparameters
        model = CNNblocks(config)
        # Train the model using a custom train loop
        trainer = Trainer(
            model=model,
            settings=settings,
            loss_fn=loss_fn,
            optimizer=optimizer,
            traindataloader=trainstreamer,
            validdataloader=validstreamer,
            scheduler=optim.lr_scheduler.ReduceLROnPlateau,
            device=device,
        )
        trainer.loop()

        # Save the trained model with a timestamp
        tag = datetime.now().strftime("%Y%m%d-%H%M")
        modelpath = modeldir / (tag + "model.pt")
        torch.save(model, modelpath)

        # Log the saved model as an artifact in MLflow
        mlflow.log_artifact(local_path=modelpath, artifact_path="pytorch_models")
        return {'loss' : trainer.test_loss, 'status': STATUS_OK}

# %% [markdown]
# See https://hyperopt.github.io/hyperopt/getting-started/search_spaces/ for more information about searchspaces for hyperopt

# %%
search_space = {
    'filters' : scope.int(hp.quniform('filters', 16, 128, 8)),
    'kernel_size' : scope.int(hp.quniform('kernel_size', 2, 5, 1)),
    'num_layers' : scope.int(hp.quniform('num_layers', 1, 10, 1)),
}

# %% [markdown]
# We define a search space for hyperparameter optimization using Hyperopt. The search space specifies the range and distribution of hyperparameters to explore during the optimization process. This is crucial for finding the optimal set of hyperparameters that yield the best performance for the machine learning model. The search space defined here includes the number of filters in the convolutional layers, and the number of units in two fully connected layers, allowing Hyperopt to find the best combination within the given ranges.
#
#
# Now, finally, let us perform the hyperparameter search using the fmin function from hyperopt. The function takes the following arguments:
#
# - `fn=objective`: The objective function to minimize, which is defined earlier to train the model and return the test loss.
# - `space=search_space`: The search space defined earlier, containing the range of hyperparameters to explore.
# - `algo=tpe.suggest`: The optimization algorithm to use, in this case, the Tree-structured Parzen Estimator (TPE) method.
# - `max_evals=10`: The maximum number of function evaluations, i.e., the maximum number of hyperparameter combinations to try.
# - `trials=Trials()`: A Trials object to store the results of each evaluation.
#
# The fmin function searches for the best hyperparameters within the given search space using the TPE algorithm, aiming to minimize the objective function (test loss). Once the optimization process is completed, the best hyperparameters found are stored in the best_result variable.

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=3,
    trials=Trials()
)
# Out:
# Calculated matrix size: 9
# Caluclated flatten size: 648
#   0%|          | 0/3 [00:00<?, ?trial/s, best loss=?]
# 2025-09-19 20:19:45.059 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to C:\GitHub\portfolio-JN\2-hypertuning-mlflow\models\20250919-201945
# 2025-09-19 20:19:45.062 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:21,  4.67it/s]
#   2%|2         | 2/100 [00:00<00:18,  5.23it/s]
#   3%|3         | 3/100 [00:00<00:16,  5.76it/s]
#   4%|4         | 4/100 [00:00<00:15,  6.19it/s]
#   5%|5         | 5/100 [00:00<00:15,  6.31it/s]
#   6%|6         | 6/100 [00:01<00:15,  6.19it/s]
#   7%|7         | 7/100 [00:01<00:14,  6.27it/s]
#   8%|8         | 8/100 [00:01<00:15,  5.99it/s]
#   9%|9         | 9/100 [00:01<00:15,  5.89it/s]
#  10%|#         | 10/100 [00:01<00:14,  6.07it/s]
#  11%|#1        | 11/100 [00:01<00:14,  6.28it/s]
#  12%|#2        | 12/100 [00:01<00:14,  6.12it/s]
#  13%|#3        | 13/100 [00:02<00:13,  6.22it/s]
#  14%|#4        | 14/100 [00:02<00:13,  6.23it/s]
#  15%|#5        | 15/100 [00:02<00:14,  5.74it/s]
#  16%|#6        | 16/100 [00:02<00:14,  5.89it/s]
#  17%|#7        | 17/100 [00:02<00:13,  5.96it/s]
#  18%|#8        | 18/100 [00:02<00:13,  6.03it/s]
#  19%|#9        | 19/100 [00:03<00:13,  6.02it/s]
#  20%|##        | 20/100 [00:03<00:13,  6.03it/s]
#  21%|##1       | 21/100 [00:03<00:12,  6.26it/s]
#  22%|##2       | 22/100 [00:03<00:12,  6.41it/s]
#  23%|##3       | 23/100 [00:03<00:12,  6.33it/s]
#  24%|##4       | 24/100 [00:03<00:12,  6.23it/s]
#  25%|##5       | 25/100 [00:04<00:12,  6.22it/s]
#  26%|##6       | 26/100 [00:04<00:11,  6.24it/s]
#  27%|##7       | 27/100 [00:04<00:11,  6.37it/s]
#  28%|##8       | 28/100 [00:04<00:11,  6.31it/s]
#  29%|##9       | 29/100 [00:04<00:10,  6.57it/s]
#  30%|###       | 30/100 [00:04<00:11,  5.92it/s]
#  31%|###1      | 31/100 [00:05<00:11,  6.10it/s]
#  32%|###2      | 32/100 [00:05<00:11,  6.03it/s]
#  33%|###3      | 33/100 [00:05<00:11,  5.94it/s]
#  34%|###4      | 34/100 [00:05<00:11,  5.77it/s]
#  35%|###5      | 35/100 [00:05<00:11,  5.71it/s]
#  36%|###6      | 36/100 [00:05<00:11,  5.77it/s]
#  37%|###7      | 37/100 [00:06<00:10,  5.95it/s]
#  38%|###8      | 38/100 [00:06<00:10,  5.95it/s]
#  39%|###9      | 39/100 [00:06<00:10,  5.86it/s]
#  40%|####      | 40/100 [00:06<00:10,  5.82it/s]
#  41%|####1     | 41/100 [00:06<00:09,  5.96it/s]
#  42%|####2     | 42/100 [00:06<00:09,  6.03it/s]
#  43%|####3     | 43/100 [00:07<00:09,  6.08it/s]
#  44%|####4     | 44/100 [00:07<00:09,  6.08it/s]
#  45%|####5     | 45/100 [00:07<00:08,  6.12it/s]
#  46%|####6     | 46/100 [00:07<00:08,  6.14it/s]
#  47%|####6     | 47/100 [00:07<00:08,  6.07it/s]
#  48%|####8     | 48/100 [00:07<00:09,  5.67it/s]
#  49%|####9     | 49/100 [00:08<00:08,  5.78it/s]
#  50%|#####     | 50/100 [00:08<00:08,  5.95it/s]
#  51%|#####1    | 51/100 [00:08<00:08,  6.02it/s]
#  52%|#####2    | 52/100 [00:08<00:07,  6.09it/s]
#  53%|#####3    | 53/100 [00:08<00:07,  6.22it/s]
#  54%|#####4    | 54/100 [00:08<00:07,  6.28it/s]
#  55%|#####5    | 55/100 [00:09<00:07,  6.17it/s]
#  56%|#####6    | 56/100 [00:09<00:07,  6.17it/s]
#  57%|#####6    | 57/100 [00:09<00:06,  6.32it/s]
#  58%|#####8    | 58/100 [00:09<00:06,  6.13it/s]
#  59%|#####8    | 59/100 [00:09<00:06,  5.87it/s]
#  60%|######    | 60/100 [00:09<00:06,  6.06it/s]
#  61%|######1   | 61/100 [00:10<00:06,  6.19it/s]
#  62%|######2   | 62/100 [00:10<00:05,  6.38it/s]
#  63%|######3   | 63/100 [00:10<00:05,  6.22it/s]
#  64%|######4   | 64/100 [00:10<00:05,  6.26it/s]
#  65%|######5   | 65/100 [00:10<00:05,  6.39it/s]
#  66%|######6   | 66/100 [00:10<00:05,  6.40it/s]
#  67%|######7   | 67/100 [00:11<00:05,  6.28it/s]
#  68%|######8   | 68/100 [00:11<00:05,  6.22it/s]
#  69%|######9   | 69/100 [00:11<00:05,  6.04it/s]
#  70%|#######   | 70/100 [00:11<00:04,  6.09it/s]
#  71%|#######1  | 71/100 [00:11<00:04,  5.90it/s]
#  72%|#######2  | 72/100 [00:11<00:04,  5.68it/s]
#  73%|#######3  | 73/100 [00:12<00:04,  5.85it/s]
#  74%|#######4  | 74/100 [00:12<00:04,  5.95it/s]
#  75%|#######5  | 75/100 [00:12<00:04,  5.96it/s]
#  76%|#######6  | 76/100 [00:12<00:04,  5.90it/s]
#  77%|#######7  | 77/100 [00:12<00:03,  5.98it/s]
#  78%|#######8  | 78/100 [00:12<00:03,  6.21it/s]
#  79%|#######9  | 79/100 [00:13<00:03,  5.94it/s]
#  80%|########  | 80/100 [00:13<00:03,  6.04it/s]
#  81%|########1 | 81/100 [00:13<00:03,  6.17it/s]
#  82%|########2 | 82/100 [00:13<00:02,  6.14it/s]
#  83%|########2 | 83/100 [00:13<00:02,  6.01it/s]
#  84%|########4 | 84/100 [00:13<00:02,  6.28it/s]
#  85%|########5 | 85/100 [00:13<00:02,  6.31it/s]
#  86%|########6 | 86/100 [00:14<00:02,  6.39it/s]
#  87%|########7 | 87/100 [00:14<00:02,  6.36it/s]
#  88%|########8 | 88/100 [00:14<00:01,  6.21it/s]
#  89%|########9 | 89/100 [00:14<00:01,  6.05it/s]
#  90%|######### | 90/100 [00:14<00:01,  5.92it/s]
#  91%|#########1| 91/100 [00:14<00:01,  6.04it/s]
#  92%|#########2| 92/100 [00:15<00:01,  5.52it/s]
#  93%|#########3| 93/100 [00:15<00:01,  5.00it/s]
#  94%|#########3| 94/100 [00:15<00:01,  5.07it/s]
#  95%|#########5| 95/100 [00:15<00:00,  5.28it/s]
#  96%|#########6| 96/100 [00:15<00:00,  5.49it/s]
#  97%|#########7| 97/100 [00:16<00:00,  5.70it/s]
#  98%|#########8| 98/100 [00:16<00:00,  5.61it/s]
#  99%|#########9| 99/100 [00:16<00:00,  5.74it/s]
# 100%|##########| 100/100 [00:16<00:00,  5.91it/s]
# 100%|##########| 100/100 [00:16<00:00,  6.01it/s]
# 2025-09-19 20:20:07.304 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.4897 test 0.8885 metric ['0.6767']
#  33%|###3      | 1/3 [00:22<00:44, 22.24s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:15,  6.26it/s]
#   2%|2         | 2/100 [00:00<00:15,  6.40it/s]
#   3%|3         | 3/100 [00:00<00:16,  5.99it/s]
#   4%|4         | 4/100 [00:00<00:16,  5.98it/s]
#   5%|5         | 5/100 [00:00<00:15,  6.02it/s]
#   6%|6         | 6/100 [00:00<00:15,  6.03it/s]
#   7%|7         | 7/100 [00:01<00:15,  5.98it/s]
#   8%|8         | 8/100 [00:01<00:15,  6.07it/s]
#   9%|9         | 9/100 [00:01<00:15,  5.92it/s]
#  10%|#         | 10/100 [00:01<00:14,  6.13it/s]
#  11%|#1        | 11/100 [00:01<00:14,  6.21it/s]
#  12%|#2        | 12/100 [00:01<00:14,  6.22it/s]
#  13%|#3        | 13/100 [00:02<00:14,  6.17it/s]
#  14%|#4        | 14/100 [00:02<00:13,  6.19it/s]
#  15%|#5        | 15/100 [00:02<00:13,  6.28it/s]
#  16%|#6        | 16/100 [00:02<00:13,  6.18it/s]
#  17%|#7        | 17/100 [00:02<00:13,  6.18it/s]
#  18%|#8        | 18/100 [00:02<00:14,  5.74it/s]
#  19%|#9        | 19/100 [00:03<00:13,  6.07it/s]
#  20%|##        | 20/100 [00:03<00:12,  6.20it/s]
#  21%|##1       | 21/100 [00:03<00:12,  6.09it/s]
#  22%|##2       | 22/100 [00:03<00:12,  6.11it/s]
#  23%|##3       | 23/100 [00:03<00:12,  6.01it/s]
#  24%|##4       | 24/100 [00:03<00:12,  6.11it/s]
#  25%|##5       | 25/100 [00:04<00:12,  6.14it/s]
#  26%|##6       | 26/100 [00:04<00:11,  6.21it/s]
#  27%|##7       | 27/100 [00:04<00:11,  6.39it/s]
#  28%|##8       | 28/100 [00:04<00:11,  6.27it/s]
#  29%|##9       | 29/100 [00:04<00:11,  6.04it/s]
#  30%|###       | 30/100 [00:04<00:11,  6.07it/s]
#  31%|###1      | 31/100 [00:05<00:11,  5.79it/s]
#  32%|###2      | 32/100 [00:05<00:11,  5.94it/s]
#  33%|###3      | 33/100 [00:05<00:11,  6.02it/s]
#  34%|###4      | 34/100 [00:05<00:11,  5.91it/s]
#  35%|###5      | 35/100 [00:05<00:10,  6.02it/s]
#  36%|###6      | 36/100 [00:05<00:10,  5.94it/s]
#  37%|###7      | 37/100 [00:06<00:10,  5.96it/s]
#  38%|###8      | 38/100 [00:06<00:11,  5.54it/s]
#  39%|###9      | 39/100 [00:06<00:10,  5.75it/s]
#  40%|####      | 40/100 [00:06<00:10,  5.77it/s]
#  41%|####1     | 41/100 [00:06<00:10,  5.80it/s]
#  42%|####2     | 42/100 [00:06<00:09,  5.84it/s]
#  43%|####3     | 43/100 [00:07<00:09,  5.86it/s]
#  44%|####4     | 44/100 [00:07<00:09,  5.89it/s]
#  45%|####5     | 45/100 [00:07<00:09,  5.84it/s]
#  46%|####6     | 46/100 [00:07<00:08,  6.01it/s]
#  47%|####6     | 47/100 [00:07<00:08,  6.02it/s]
#  48%|####8     | 48/100 [00:07<00:08,  6.11it/s]
#  49%|####9     | 49/100 [00:08<00:08,  6.14it/s]
#  50%|#####     | 50/100 [00:08<00:08,  6.20it/s]
#  51%|#####1    | 51/100 [00:08<00:07,  6.30it/s]
#  52%|#####2    | 52/100 [00:08<00:07,  6.25it/s]
#  53%|#####3    | 53/100 [00:08<00:07,  5.88it/s]
#  54%|#####4    | 54/100 [00:08<00:07,  6.04it/s]
#  55%|#####5    | 55/100 [00:09<00:07,  6.20it/s]
#  56%|#####6    | 56/100 [00:09<00:07,  6.14it/s]
#  57%|#####6    | 57/100 [00:09<00:06,  6.18it/s]
#  58%|#####8    | 58/100 [00:09<00:07,  5.97it/s]
#  59%|#####8    | 59/100 [00:09<00:06,  6.17it/s]
#  60%|######    | 60/100 [00:09<00:06,  6.20it/s]
#  61%|######1   | 61/100 [00:10<00:06,  6.22it/s]
#  62%|######2   | 62/100 [00:10<00:06,  6.17it/s]
#  63%|######3   | 63/100 [00:10<00:05,  6.36it/s]
#  64%|######4   | 64/100 [00:10<00:05,  6.52it/s]
#  65%|######5   | 65/100 [00:10<00:05,  6.46it/s]
#  66%|######6   | 66/100 [00:10<00:05,  6.56it/s]
#  67%|######7   | 67/100 [00:10<00:05,  6.54it/s]
#  68%|######8   | 68/100 [00:11<00:05,  6.39it/s]
#  69%|######9   | 69/100 [00:11<00:04,  6.52it/s]
#  70%|#######   | 70/100 [00:11<00:04,  6.40it/s]
#  71%|#######1  | 71/100 [00:11<00:04,  6.49it/s]
#  72%|#######2  | 72/100 [00:11<00:04,  6.36it/s]
#  73%|#######3  | 73/100 [00:11<00:04,  6.38it/s]
#  74%|#######4  | 74/100 [00:12<00:04,  6.22it/s]
#  75%|#######5  | 75/100 [00:12<00:04,  5.90it/s]
#  76%|#######6  | 76/100 [00:12<00:04,  5.72it/s]
#  77%|#######7  | 77/100 [00:12<00:03,  5.92it/s]
#  78%|#######8  | 78/100 [00:12<00:03,  5.77it/s]
#  79%|#######9  | 79/100 [00:12<00:03,  5.86it/s]
#  80%|########  | 80/100 [00:13<00:03,  5.87it/s]
#  81%|########1 | 81/100 [00:13<00:03,  6.12it/s]
#  82%|########2 | 82/100 [00:13<00:02,  6.20it/s]
#  83%|########2 | 83/100 [00:13<00:02,  6.29it/s]
#  84%|########4 | 84/100 [00:13<00:02,  6.37it/s]
#  85%|########5 | 85/100 [00:13<00:02,  6.22it/s]
#  86%|########6 | 86/100 [00:14<00:02,  6.26it/s]
#  87%|########7 | 87/100 [00:14<00:02,  6.38it/s]
#  88%|########8 | 88/100 [00:14<00:01,  6.10it/s]
#  89%|########9 | 89/100 [00:14<00:01,  6.13it/s]
#  90%|######### | 90/100 [00:14<00:01,  6.13it/s]
#  91%|#########1| 91/100 [00:14<00:01,  6.19it/s]
#  92%|#########2| 92/100 [00:15<00:01,  5.75it/s]
#  93%|#########3| 93/100 [00:15<00:01,  5.76it/s]
#  94%|#########3| 94/100 [00:15<00:01,  5.82it/s]
#  95%|#########5| 95/100 [00:15<00:00,  6.00it/s]
#  96%|#########6| 96/100 [00:15<00:00,  6.13it/s]
#  97%|#########7| 97/100 [00:15<00:00,  6.36it/s]
#  98%|#########8| 98/100 [00:16<00:00,  6.45it/s]
#  99%|#########9| 99/100 [00:16<00:00,  6.45it/s]
# 100%|##########| 100/100 [00:16<00:00,  6.38it/s]
# 100%|##########| 100/100 [00:16<00:00,  6.11it/s]
# 2025-09-19 20:20:30.194 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7740 test 0.7282 metric ['0.7314']
#  67%|######6   | 2/3 [00:45<00:22, 22.62s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:19,  5.13it/s]
#   2%|2         | 2/100 [00:00<00:17,  5.56it/s]
#   3%|3         | 3/100 [00:00<00:16,  5.99it/s]
#   4%|4         | 4/100 [00:00<00:15,  6.08it/s]
#   5%|5         | 5/100 [00:00<00:15,  6.20it/s]
#   6%|6         | 6/100 [00:00<00:15,  6.26it/s]
#   7%|7         | 7/100 [00:01<00:15,  5.89it/s]
#   8%|8         | 8/100 [00:01<00:16,  5.61it/s]
#   9%|9         | 9/100 [00:01<00:16,  5.49it/s]
#  10%|#         | 10/100 [00:01<00:16,  5.48it/s]
#  11%|#1        | 11/100 [00:01<00:15,  5.63it/s]
#  12%|#2        | 12/100 [00:02<00:14,  5.87it/s]
#  13%|#3        | 13/100 [00:02<00:14,  5.92it/s]
#  14%|#4        | 14/100 [00:02<00:14,  6.01it/s]
#  15%|#5        | 15/100 [00:02<00:14,  5.99it/s]
#  16%|#6        | 16/100 [00:02<00:13,  6.18it/s]
#  17%|#7        | 17/100 [00:02<00:13,  6.19it/s]
#  18%|#8        | 18/100 [00:03<00:13,  6.09it/s]
#  19%|#9        | 19/100 [00:03<00:13,  6.12it/s]
#  20%|##        | 20/100 [00:03<00:13,  6.09it/s]
#  21%|##1       | 21/100 [00:03<00:13,  5.93it/s]
#  22%|##2       | 22/100 [00:03<00:12,  6.07it/s]
#  23%|##3       | 23/100 [00:03<00:12,  6.07it/s]
#  24%|##4       | 24/100 [00:04<00:12,  6.05it/s]
#  25%|##5       | 25/100 [00:04<00:12,  5.96it/s]
#  26%|##6       | 26/100 [00:04<00:12,  5.92it/s]
#  27%|##7       | 27/100 [00:04<00:12,  5.96it/s]
#  28%|##8       | 28/100 [00:04<00:11,  6.18it/s]
#  29%|##9       | 29/100 [00:04<00:11,  6.16it/s]
#  30%|###       | 30/100 [00:05<00:11,  6.25it/s]
#  31%|###1      | 31/100 [00:05<00:10,  6.37it/s]
#  32%|###2      | 32/100 [00:05<00:11,  6.10it/s]
#  33%|###3      | 33/100 [00:05<00:12,  5.38it/s]
#  34%|###4      | 34/100 [00:05<00:11,  5.50it/s]
#  35%|###5      | 35/100 [00:05<00:11,  5.69it/s]
#  36%|###6      | 36/100 [00:06<00:11,  5.62it/s]
#  37%|###7      | 37/100 [00:06<00:11,  5.51it/s]
#  38%|###8      | 38/100 [00:06<00:10,  5.70it/s]
#  39%|###9      | 39/100 [00:06<00:10,  5.80it/s]
#  40%|####      | 40/100 [00:06<00:10,  5.77it/s]
#  41%|####1     | 41/100 [00:06<00:10,  5.69it/s]
#  42%|####2     | 42/100 [00:07<00:10,  5.64it/s]
#  43%|####3     | 43/100 [00:07<00:09,  5.70it/s]
#  44%|####4     | 44/100 [00:07<00:09,  5.90it/s]
#  45%|####5     | 45/100 [00:07<00:08,  6.16it/s]
#  46%|####6     | 46/100 [00:07<00:08,  6.17it/s]
#  47%|####6     | 47/100 [00:07<00:08,  6.15it/s]
#  48%|####8     | 48/100 [00:08<00:08,  5.99it/s]
#  49%|####9     | 49/100 [00:08<00:08,  5.90it/s]
#  50%|#####     | 50/100 [00:08<00:08,  5.97it/s]
#  51%|#####1    | 51/100 [00:08<00:08,  5.98it/s]
#  52%|#####2    | 52/100 [00:08<00:07,  6.13it/s]
#  53%|#####3    | 53/100 [00:08<00:07,  5.89it/s]
#  54%|#####4    | 54/100 [00:09<00:07,  6.00it/s]
#  55%|#####5    | 55/100 [00:09<00:07,  6.14it/s]
#  56%|#####6    | 56/100 [00:09<00:07,  5.97it/s]
#  57%|#####6    | 57/100 [00:09<00:07,  5.74it/s]
#  58%|#####8    | 58/100 [00:09<00:07,  5.49it/s]
#  59%|#####8    | 59/100 [00:10<00:07,  5.64it/s]
#  60%|######    | 60/100 [00:10<00:07,  5.48it/s]
#  61%|######1   | 61/100 [00:10<00:06,  5.59it/s]
#  62%|######2   | 62/100 [00:10<00:06,  5.44it/s]
#  63%|######3   | 63/100 [00:10<00:06,  5.31it/s]
#  64%|######4   | 64/100 [00:10<00:06,  5.42it/s]
#  65%|######5   | 65/100 [00:11<00:06,  5.64it/s]
#  66%|######6   | 66/100 [00:11<00:05,  5.85it/s]
#  67%|######7   | 67/100 [00:11<00:05,  5.82it/s]
#  68%|######8   | 68/100 [00:11<00:05,  5.93it/s]
#  69%|######9   | 69/100 [00:11<00:05,  6.02it/s]
#  70%|#######   | 70/100 [00:11<00:05,  5.94it/s]
#  71%|#######1  | 71/100 [00:12<00:04,  5.97it/s]
#  72%|#######2  | 72/100 [00:12<00:04,  6.11it/s]
#  73%|#######3  | 73/100 [00:12<00:04,  6.17it/s]
#  74%|#######4  | 74/100 [00:12<00:04,  5.99it/s]
#  75%|#######5  | 75/100 [00:12<00:04,  5.25it/s]
#  76%|#######6  | 76/100 [00:13<00:04,  5.07it/s]
#  77%|#######7  | 77/100 [00:13<00:04,  4.94it/s]
#  78%|#######8  | 78/100 [00:13<00:04,  4.88it/s]
#  79%|#######9  | 79/100 [00:13<00:04,  4.90it/s]
#  80%|########  | 80/100 [00:13<00:03,  5.05it/s]
#  81%|########1 | 81/100 [00:14<00:03,  5.39it/s]
#  82%|########2 | 82/100 [00:14<00:03,  5.29it/s]
#  83%|########2 | 83/100 [00:14<00:03,  5.13it/s]
#  84%|########4 | 84/100 [00:14<00:03,  4.91it/s]
#  85%|########5 | 85/100 [00:14<00:02,  5.06it/s]
#  86%|########6 | 86/100 [00:15<00:02,  5.22it/s]
#  87%|########7 | 87/100 [00:15<00:02,  5.37it/s]
#  88%|########8 | 88/100 [00:15<00:02,  5.17it/s]
#  89%|########9 | 89/100 [00:15<00:02,  5.37it/s]
#  90%|######### | 90/100 [00:15<00:01,  5.49it/s]
#  91%|#########1| 91/100 [00:15<00:01,  5.61it/s]
#  92%|#########2| 92/100 [00:16<00:01,  5.68it/s]
#  93%|#########3| 93/100 [00:16<00:01,  5.89it/s]
#  94%|#########3| 94/100 [00:16<00:01,  5.83it/s]
#  95%|#########5| 95/100 [00:16<00:00,  5.95it/s]
#  96%|#########6| 96/100 [00:16<00:00,  6.03it/s]
#  97%|#########7| 97/100 [00:16<00:00,  6.20it/s]
#  98%|#########8| 98/100 [00:17<00:00,  5.99it/s]
#  99%|#########9| 99/100 [00:17<00:00,  5.86it/s]
# 100%|##########| 100/100 [00:17<00:00,  5.79it/s]
# 100%|##########| 100/100 [00:17<00:00,  5.74it/s]
# 2025-09-19 20:20:53.450 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6668 test 0.6430 metric ['0.7580']
# 100%|##########| 3/3 [01:08<00:00, 22.91s/it]
# 100%|##########| 3/3 [01:08<00:00, 22.79s/it]
# Calculated matrix size: 9
# Caluclated flatten size: 432
#  33%|███▎      | 1/3 [01:08<02:16, 68.48s/trial, best loss: 0.6430426985025406]
# 2025-09-19 20:20:53.522 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to C:\GitHub\portfolio-JN\2-hypertuning-mlflow\models\20250919-202053
# 2025-09-19 20:20:53.524 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   2%|2         | 2/100 [00:00<00:10,  9.63it/s]
#   3%|3         | 3/100 [00:00<00:10,  9.42it/s]
#   4%|4         | 4/100 [00:00<00:10,  9.59it/s]
#   6%|6         | 6/100 [00:00<00:09, 10.35it/s]
#   8%|8         | 8/100 [00:00<00:08, 11.18it/s]
#  10%|#         | 10/100 [00:00<00:08, 11.08it/s]
#  12%|#2        | 12/100 [00:01<00:07, 11.47it/s]
#  14%|#4        | 14/100 [00:01<00:07, 10.96it/s]
#  16%|#6        | 16/100 [00:01<00:08, 10.35it/s]
#  18%|#8        | 18/100 [00:01<00:08, 10.10it/s]
#  20%|##        | 20/100 [00:01<00:08,  9.57it/s]
#  22%|##2       | 22/100 [00:02<00:08,  9.71it/s]
#  23%|##3       | 23/100 [00:02<00:07,  9.74it/s]
#  25%|##5       | 25/100 [00:02<00:07, 10.10it/s]
#  27%|##7       | 27/100 [00:02<00:07, 10.34it/s]
#  29%|##9       | 29/100 [00:02<00:06, 10.44it/s]
#  31%|###1      | 31/100 [00:03<00:06, 10.32it/s]
#  33%|###3      | 33/100 [00:03<00:06, 10.70it/s]
#  35%|###5      | 35/100 [00:03<00:05, 11.06it/s]
#  37%|###7      | 37/100 [00:03<00:05, 10.75it/s]
#  39%|###9      | 39/100 [00:03<00:05, 11.14it/s]
#  41%|####1     | 41/100 [00:03<00:05, 11.02it/s]
#  43%|####3     | 43/100 [00:04<00:05, 11.31it/s]
#  45%|####5     | 45/100 [00:04<00:04, 11.09it/s]
#  47%|####6     | 47/100 [00:04<00:04, 10.72it/s]
#  49%|####9     | 49/100 [00:04<00:04, 10.39it/s]
#  51%|#####1    | 51/100 [00:04<00:04, 10.11it/s]
#  53%|#####3    | 53/100 [00:05<00:04, 10.54it/s]
#  55%|#####5    | 55/100 [00:05<00:04, 10.01it/s]
#  57%|#####6    | 57/100 [00:05<00:04,  9.96it/s]
#  59%|#####8    | 59/100 [00:05<00:04,  9.67it/s]
#  60%|######    | 60/100 [00:05<00:04,  9.56it/s]
#  62%|######2   | 62/100 [00:05<00:03, 10.10it/s]
#  64%|######4   | 64/100 [00:06<00:03,  9.73it/s]
#  66%|######6   | 66/100 [00:06<00:03, 10.03it/s]
#  68%|######8   | 68/100 [00:06<00:03, 10.05it/s]
#  70%|#######   | 70/100 [00:06<00:02, 10.24it/s]
#  72%|#######2  | 72/100 [00:06<00:02,  9.70it/s]
#  74%|#######4  | 74/100 [00:07<00:02, 10.21it/s]
#  76%|#######6  | 76/100 [00:07<00:02, 10.57it/s]
#  78%|#######8  | 78/100 [00:07<00:02, 10.80it/s]
#  80%|########  | 80/100 [00:07<00:01, 10.98it/s]
#  82%|########2 | 82/100 [00:07<00:01, 11.04it/s]
#  84%|########4 | 84/100 [00:08<00:01, 10.72it/s]
#  86%|########6 | 86/100 [00:08<00:01, 10.28it/s]
#  88%|########8 | 88/100 [00:08<00:01, 10.38it/s]
#  90%|######### | 90/100 [00:08<00:00, 10.14it/s]
#  92%|#########2| 92/100 [00:08<00:00, 10.56it/s]
#  94%|#########3| 94/100 [00:09<00:00, 10.86it/s]
#  96%|#########6| 96/100 [00:09<00:00, 11.01it/s]
#  98%|#########8| 98/100 [00:09<00:00, 11.04it/s]
# 100%|##########| 100/100 [00:09<00:00, 10.38it/s]
# 100%|##########| 100/100 [00:09<00:00, 10.41it/s]
# 2025-09-19 20:21:06.168 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.4218 test 0.7992 metric ['0.6969']
#  33%|###3      | 1/3 [00:12<00:25, 12.64s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:10,  9.40it/s]
#   3%|3         | 3/100 [00:00<00:09, 10.74it/s]
#   5%|5         | 5/100 [00:00<00:10,  9.33it/s]
#   7%|7         | 7/100 [00:00<00:09,  9.91it/s]
#   9%|9         | 9/100 [00:00<00:08, 10.39it/s]
#  11%|#1        | 11/100 [00:01<00:09,  9.69it/s]
#  12%|#2        | 12/100 [00:01<00:09,  9.15it/s]
#  13%|#3        | 13/100 [00:01<00:09,  8.83it/s]
#  14%|#4        | 14/100 [00:01<00:09,  8.96it/s]
#  15%|#5        | 15/100 [00:01<00:09,  8.84it/s]
#  16%|#6        | 16/100 [00:01<00:09,  9.11it/s]
#  18%|#8        | 18/100 [00:01<00:08,  9.49it/s]
#  19%|#9        | 19/100 [00:02<00:09,  8.42it/s]
#  20%|##        | 20/100 [00:02<00:09,  8.35it/s]
#  21%|##1       | 21/100 [00:02<00:09,  8.46it/s]
#  23%|##3       | 23/100 [00:02<00:08,  9.53it/s]
#  25%|##5       | 25/100 [00:02<00:07, 10.11it/s]
#  27%|##7       | 27/100 [00:02<00:07, 10.32it/s]
#  29%|##9       | 29/100 [00:03<00:06, 10.41it/s]
#  31%|###1      | 31/100 [00:03<00:06,  9.91it/s]
#  33%|###3      | 33/100 [00:03<00:06, 10.03it/s]
#  35%|###5      | 35/100 [00:03<00:06, 10.39it/s]
#  37%|###7      | 37/100 [00:03<00:06, 10.49it/s]
#  39%|###9      | 39/100 [00:03<00:05, 10.62it/s]
#  41%|####1     | 41/100 [00:04<00:05, 10.27it/s]
#  43%|####3     | 43/100 [00:04<00:05, 10.40it/s]
#  45%|####5     | 45/100 [00:04<00:05, 10.38it/s]
#  47%|####6     | 47/100 [00:04<00:05, 10.50it/s]
#  49%|####9     | 49/100 [00:04<00:05, 10.17it/s]
#  51%|#####1    | 51/100 [00:05<00:04, 10.31it/s]
#  53%|#####3    | 53/100 [00:05<00:04,  9.81it/s]
#  55%|#####5    | 55/100 [00:05<00:04, 10.29it/s]
#  57%|#####6    | 57/100 [00:05<00:04, 10.53it/s]
#  59%|#####8    | 59/100 [00:05<00:03, 10.82it/s]
#  61%|######1   | 61/100 [00:06<00:03, 10.88it/s]
#  63%|######3   | 63/100 [00:06<00:03, 10.68it/s]
#  65%|######5   | 65/100 [00:06<00:03, 10.22it/s]
#  67%|######7   | 67/100 [00:06<00:03, 10.17it/s]
#  69%|######9   | 69/100 [00:06<00:03, 10.26it/s]
#  71%|#######1  | 71/100 [00:07<00:02, 10.74it/s]
#  73%|#######3  | 73/100 [00:07<00:02, 10.82it/s]
#  75%|#######5  | 75/100 [00:07<00:02, 10.94it/s]
#  77%|#######7  | 77/100 [00:07<00:02, 11.12it/s]
#  79%|#######9  | 79/100 [00:07<00:01, 11.30it/s]
#  81%|########1 | 81/100 [00:07<00:01, 10.70it/s]
#  83%|########2 | 83/100 [00:08<00:01, 11.14it/s]
#  85%|########5 | 85/100 [00:08<00:01, 11.38it/s]
#  87%|########7 | 87/100 [00:08<00:01, 11.19it/s]
#  89%|########9 | 89/100 [00:08<00:00, 11.23it/s]
#  91%|#########1| 91/100 [00:08<00:00, 10.42it/s]
#  93%|#########3| 93/100 [00:09<00:00, 10.32it/s]
#  95%|#########5| 95/100 [00:09<00:00, 10.22it/s]
#  97%|#########7| 97/100 [00:09<00:00, 10.51it/s]
#  99%|#########9| 99/100 [00:09<00:00, 10.73it/s]
# 100%|##########| 100/100 [00:09<00:00, 10.28it/s]
# 2025-09-19 20:21:19.070 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7466 test 0.6999 metric ['0.7369']
#  67%|######6   | 2/3 [00:25<00:12, 12.79s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   2%|2         | 2/100 [00:00<00:09, 10.30it/s]
#   4%|4         | 4/100 [00:00<00:09, 10.19it/s]
#   6%|6         | 6/100 [00:00<00:09,  9.55it/s]
#   7%|7         | 7/100 [00:00<00:09,  9.47it/s]
#   8%|8         | 8/100 [00:00<00:09,  9.47it/s]
#  10%|#         | 10/100 [00:01<00:08, 10.16it/s]
#  12%|#2        | 12/100 [00:01<00:08, 10.31it/s]
#  14%|#4        | 14/100 [00:01<00:08, 10.14it/s]
#  16%|#6        | 16/100 [00:01<00:07, 10.53it/s]
#  18%|#8        | 18/100 [00:01<00:07, 10.88it/s]
#  20%|##        | 20/100 [00:01<00:07, 10.88it/s]
#  22%|##2       | 22/100 [00:02<00:07, 10.57it/s]
#  24%|##4       | 24/100 [00:02<00:06, 10.95it/s]
#  26%|##6       | 26/100 [00:02<00:07, 10.37it/s]
#  28%|##8       | 28/100 [00:02<00:07, 10.12it/s]
#  30%|###       | 30/100 [00:02<00:06, 10.67it/s]
#  32%|###2      | 32/100 [00:03<00:06, 11.13it/s]
#  34%|###4      | 34/100 [00:03<00:05, 11.45it/s]
#  36%|###6      | 36/100 [00:03<00:05, 11.83it/s]
#  38%|###8      | 38/100 [00:03<00:05, 11.55it/s]
#  40%|####      | 40/100 [00:03<00:05, 11.14it/s]
#  42%|####2     | 42/100 [00:03<00:05, 11.33it/s]
#  44%|####4     | 44/100 [00:04<00:05, 10.68it/s]
#  46%|####6     | 46/100 [00:04<00:05, 10.70it/s]
#  48%|####8     | 48/100 [00:04<00:04, 10.73it/s]
#  50%|#####     | 50/100 [00:04<00:04, 10.85it/s]
#  52%|#####2    | 52/100 [00:04<00:04, 10.68it/s]
#  54%|#####4    | 54/100 [00:05<00:04, 10.34it/s]
#  56%|#####6    | 56/100 [00:05<00:04, 10.74it/s]
#  58%|#####8    | 58/100 [00:05<00:03, 10.55it/s]
#  60%|######    | 60/100 [00:05<00:03, 10.75it/s]
#  62%|######2   | 62/100 [00:05<00:03, 10.55it/s]
#  64%|######4   | 64/100 [00:06<00:03, 10.66it/s]
#  66%|######6   | 66/100 [00:06<00:03, 11.04it/s]
#  68%|######8   | 68/100 [00:06<00:02, 11.08it/s]
#  70%|#######   | 70/100 [00:06<00:02, 10.93it/s]
#  72%|#######2  | 72/100 [00:06<00:02, 11.03it/s]
#  74%|#######4  | 74/100 [00:06<00:02, 11.04it/s]
#  76%|#######6  | 76/100 [00:07<00:02, 10.95it/s]
#  78%|#######8  | 78/100 [00:07<00:02, 10.86it/s]
#  80%|########  | 80/100 [00:07<00:01, 10.97it/s]
#  82%|########2 | 82/100 [00:07<00:01, 11.23it/s]
#  84%|########4 | 84/100 [00:07<00:01, 10.64it/s]
#  86%|########6 | 86/100 [00:08<00:01, 10.78it/s]
#  88%|########8 | 88/100 [00:08<00:01, 10.85it/s]
#  90%|######### | 90/100 [00:08<00:00, 10.81it/s]
#  92%|#########2| 92/100 [00:08<00:00, 10.97it/s]
#  94%|#########3| 94/100 [00:08<00:00, 10.87it/s]
#  96%|#########6| 96/100 [00:08<00:00, 11.01it/s]
#  98%|#########8| 98/100 [00:09<00:00, 10.99it/s]
# 100%|##########| 100/100 [00:09<00:00, 10.57it/s]
# 100%|##########| 100/100 [00:09<00:00, 10.74it/s]
# 2025-09-19 20:21:31.428 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6765 test 0.6708 metric ['0.7473']
# 100%|##########| 3/3 [00:37<00:00, 12.59s/it]
# 100%|##########| 3/3 [00:37<00:00, 12.63s/it]
# Calculated matrix size: 9
# Caluclated flatten size: 936
#  67%|██████▋   | 2/3 [01:46<00:50, 50.53s/trial, best loss: 0.6430426985025406]
# 2025-09-19 20:21:31.487 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to C:\GitHub\portfolio-JN\2-hypertuning-mlflow\models\20250919-202131
# 2025-09-19 20:21:31.488 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:29,  3.34it/s]
#   2%|2         | 2/100 [00:00<00:30,  3.20it/s]
#   3%|3         | 3/100 [00:00<00:31,  3.04it/s]
#   4%|4         | 4/100 [00:01<00:30,  3.11it/s]
#   5%|5         | 5/100 [00:02<00:44,  2.13it/s]
#   6%|6         | 6/100 [00:02<00:40,  2.30it/s]
#   7%|7         | 7/100 [00:02<00:36,  2.54it/s]
#   8%|8         | 8/100 [00:02<00:33,  2.74it/s]
#   9%|9         | 9/100 [00:03<00:31,  2.93it/s]
#  10%|#         | 10/100 [00:03<00:29,  3.02it/s]
#  11%|#1        | 11/100 [00:03<00:28,  3.15it/s]
#  12%|#2        | 12/100 [00:04<00:27,  3.15it/s]
#  13%|#3        | 13/100 [00:04<00:28,  3.03it/s]
#  14%|#4        | 14/100 [00:04<00:27,  3.14it/s]
#  15%|#5        | 15/100 [00:05<00:34,  2.43it/s]
#  16%|#6        | 16/100 [00:05<00:31,  2.70it/s]
#  17%|#7        | 17/100 [00:06<00:29,  2.82it/s]
#  18%|#8        | 18/100 [00:06<00:28,  2.86it/s]
#  19%|#9        | 19/100 [00:06<00:27,  2.99it/s]
#  20%|##        | 20/100 [00:07<00:26,  2.97it/s]
#  21%|##1       | 21/100 [00:07<00:25,  3.10it/s]
#  22%|##2       | 22/100 [00:07<00:24,  3.22it/s]
#  23%|##3       | 23/100 [00:07<00:23,  3.27it/s]
#  24%|##4       | 24/100 [00:08<00:39,  1.92it/s]
#  25%|##5       | 25/100 [00:09<00:33,  2.23it/s]
#  26%|##6       | 26/100 [00:09<00:29,  2.48it/s]
#  27%|##7       | 27/100 [00:09<00:27,  2.69it/s]
#  28%|##8       | 28/100 [00:10<00:24,  2.91it/s]
#  29%|##9       | 29/100 [00:10<00:23,  3.08it/s]
#  30%|###       | 30/100 [00:10<00:27,  2.50it/s]
#  31%|###1      | 31/100 [00:11<00:25,  2.70it/s]
#  32%|###2      | 32/100 [00:11<00:26,  2.61it/s]
#  33%|###3      | 33/100 [00:11<00:24,  2.78it/s]
#  34%|###4      | 34/100 [00:12<00:22,  2.98it/s]
#  35%|###5      | 35/100 [00:12<00:21,  3.07it/s]
#  36%|###6      | 36/100 [00:13<00:24,  2.62it/s]
#  37%|###7      | 37/100 [00:13<00:25,  2.43it/s]
#  38%|###8      | 38/100 [00:13<00:22,  2.72it/s]
#  39%|###9      | 39/100 [00:14<00:21,  2.88it/s]
#  40%|####      | 40/100 [00:14<00:20,  2.90it/s]
#  41%|####1     | 41/100 [00:14<00:19,  3.08it/s]
#  42%|####2     | 42/100 [00:15<00:23,  2.43it/s]
#  43%|####3     | 43/100 [00:15<00:24,  2.37it/s]
#  44%|####4     | 44/100 [00:16<00:21,  2.61it/s]
#  45%|####5     | 45/100 [00:16<00:19,  2.78it/s]
#  46%|####6     | 46/100 [00:16<00:18,  2.87it/s]
#  47%|####6     | 47/100 [00:16<00:17,  3.04it/s]
#  48%|####8     | 48/100 [00:17<00:16,  3.09it/s]
#  49%|####9     | 49/100 [00:17<00:15,  3.19it/s]
#  50%|#####     | 50/100 [00:17<00:15,  3.24it/s]
#  51%|#####1    | 51/100 [00:18<00:16,  3.06it/s]
#  52%|#####2    | 52/100 [00:18<00:15,  3.07it/s]
#  53%|#####3    | 53/100 [00:18<00:15,  3.09it/s]
#  54%|#####4    | 54/100 [00:19<00:14,  3.14it/s]
#  55%|#####5    | 55/100 [00:19<00:15,  2.98it/s]
#  56%|#####6    | 56/100 [00:19<00:13,  3.15it/s]
#  57%|#####6    | 57/100 [00:20<00:13,  3.11it/s]
#  58%|#####8    | 58/100 [00:20<00:13,  3.02it/s]
#  59%|#####8    | 59/100 [00:20<00:13,  3.07it/s]
#  60%|######    | 60/100 [00:21<00:12,  3.19it/s]
#  61%|######1   | 61/100 [00:21<00:12,  3.20it/s]
#  62%|######2   | 62/100 [00:21<00:11,  3.21it/s]
#  63%|######3   | 63/100 [00:22<00:11,  3.22it/s]
#  64%|######4   | 64/100 [00:22<00:11,  3.23it/s]
#  65%|######5   | 65/100 [00:22<00:10,  3.25it/s]
#  66%|######6   | 66/100 [00:22<00:10,  3.28it/s]
#  67%|######7   | 67/100 [00:23<00:10,  3.19it/s]
#  68%|######8   | 68/100 [00:23<00:10,  3.10it/s]
#  69%|######9   | 69/100 [00:23<00:09,  3.26it/s]
#  70%|#######   | 70/100 [00:24<00:08,  3.35it/s]
#  71%|#######1  | 71/100 [00:24<00:08,  3.37it/s]
#  72%|#######2  | 72/100 [00:24<00:08,  3.38it/s]
#  73%|#######3  | 73/100 [00:25<00:07,  3.44it/s]
#  74%|#######4  | 74/100 [00:25<00:07,  3.42it/s]
#  75%|#######5  | 75/100 [00:25<00:07,  3.30it/s]
#  76%|#######6  | 76/100 [00:26<00:07,  3.02it/s]
#  77%|#######7  | 77/100 [00:26<00:07,  3.10it/s]
#  78%|#######8  | 78/100 [00:26<00:06,  3.23it/s]
#  79%|#######9  | 79/100 [00:27<00:06,  3.09it/s]
#  80%|########  | 80/100 [00:27<00:06,  3.20it/s]
#  81%|########1 | 81/100 [00:27<00:05,  3.19it/s]
#  82%|########2 | 82/100 [00:27<00:05,  3.30it/s]
#  83%|########2 | 83/100 [00:28<00:05,  3.21it/s]
#  84%|########4 | 84/100 [00:28<00:05,  3.19it/s]
#  85%|########5 | 85/100 [00:28<00:04,  3.26it/s]
#  86%|########6 | 86/100 [00:29<00:04,  3.35it/s]
#  87%|########7 | 87/100 [00:29<00:03,  3.40it/s]
#  88%|########8 | 88/100 [00:29<00:03,  3.43it/s]
#  89%|########9 | 89/100 [00:29<00:03,  3.48it/s]
#  90%|######### | 90/100 [00:30<00:03,  3.33it/s]
#  91%|#########1| 91/100 [00:30<00:02,  3.30it/s]
#  92%|#########2| 92/100 [00:30<00:02,  3.36it/s]
#  93%|#########3| 93/100 [00:31<00:02,  2.71it/s]
#  94%|#########3| 94/100 [00:31<00:02,  2.89it/s]
#  95%|#########5| 95/100 [00:32<00:01,  2.99it/s]
#  96%|#########6| 96/100 [00:32<00:01,  3.11it/s]
#  97%|#########7| 97/100 [00:32<00:00,  3.23it/s]
#  98%|#########8| 98/100 [00:32<00:00,  3.19it/s]
#  99%|#########9| 99/100 [00:33<00:00,  3.31it/s]
# 100%|##########| 100/100 [00:33<00:00,  3.42it/s]
# 100%|##########| 100/100 [00:33<00:00,  2.99it/s]
# 2025-09-19 20:22:14.713 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.5941 test 0.8826 metric ['0.6323']
#  33%|###3      | 1/3 [00:43<01:26, 43.22s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:30,  3.20it/s]
#   2%|2         | 2/100 [00:00<00:30,  3.17it/s]
#   3%|3         | 3/100 [00:00<00:30,  3.16it/s]
#   4%|4         | 4/100 [00:01<00:35,  2.68it/s]
#   5%|5         | 5/100 [00:01<00:32,  2.88it/s]
#   6%|6         | 6/100 [00:02<00:35,  2.67it/s]
#   7%|7         | 7/100 [00:02<00:32,  2.90it/s]
#   8%|8         | 8/100 [00:02<00:30,  2.98it/s]
#   9%|9         | 9/100 [00:03<00:29,  3.08it/s]
#  10%|#         | 10/100 [00:03<00:28,  3.10it/s]
#  11%|#1        | 11/100 [00:03<00:29,  3.06it/s]
#  12%|#2        | 12/100 [00:03<00:28,  3.13it/s]
#  13%|#3        | 13/100 [00:04<00:34,  2.49it/s]
#  14%|#4        | 14/100 [00:04<00:33,  2.57it/s]
#  15%|#5        | 15/100 [00:05<00:30,  2.82it/s]
#  16%|#6        | 16/100 [00:05<00:31,  2.67it/s]
#  17%|#7        | 17/100 [00:06<00:30,  2.70it/s]
#  18%|#8        | 18/100 [00:06<00:29,  2.79it/s]
#  19%|#9        | 19/100 [00:06<00:27,  2.98it/s]
#  20%|##        | 20/100 [00:07<00:35,  2.25it/s]
#  21%|##1       | 21/100 [00:07<00:31,  2.53it/s]
#  22%|##2       | 22/100 [00:07<00:27,  2.81it/s]
#  23%|##3       | 23/100 [00:08<00:25,  3.03it/s]
#  24%|##4       | 24/100 [00:08<00:23,  3.22it/s]
#  25%|##5       | 25/100 [00:09<00:36,  2.05it/s]
#  26%|##6       | 26/100 [00:09<00:31,  2.37it/s]
#  27%|##7       | 27/100 [00:09<00:27,  2.63it/s]
#  28%|##8       | 28/100 [00:10<00:39,  1.84it/s]
#  29%|##9       | 29/100 [00:11<00:32,  2.17it/s]
#  30%|###       | 30/100 [00:11<00:28,  2.46it/s]
#  31%|###1      | 31/100 [00:11<00:25,  2.74it/s]
#  32%|###2      | 32/100 [00:11<00:23,  2.92it/s]
#  33%|###3      | 33/100 [00:12<00:21,  3.05it/s]
#  34%|###4      | 34/100 [00:12<00:21,  3.05it/s]
#  35%|###5      | 35/100 [00:12<00:20,  3.13it/s]
#  36%|###6      | 36/100 [00:13<00:19,  3.28it/s]
#  37%|###7      | 37/100 [00:13<00:19,  3.26it/s]
#  38%|###8      | 38/100 [00:13<00:18,  3.30it/s]
#  39%|###9      | 39/100 [00:13<00:18,  3.35it/s]
#  40%|####      | 40/100 [00:14<00:17,  3.44it/s]
#  41%|####1     | 41/100 [00:14<00:20,  2.88it/s]
#  42%|####2     | 42/100 [00:15<00:19,  3.03it/s]
#  43%|####3     | 43/100 [00:15<00:18,  3.06it/s]
#  44%|####4     | 44/100 [00:15<00:17,  3.13it/s]
#  45%|####5     | 45/100 [00:15<00:18,  3.00it/s]
#  46%|####6     | 46/100 [00:16<00:17,  3.14it/s]
#  47%|####6     | 47/100 [00:16<00:18,  2.90it/s]
#  48%|####8     | 48/100 [00:16<00:17,  2.98it/s]
#  49%|####9     | 49/100 [00:17<00:17,  2.99it/s]
#  50%|#####     | 50/100 [00:17<00:16,  3.11it/s]
#  51%|#####1    | 51/100 [00:17<00:16,  2.96it/s]
#  52%|#####2    | 52/100 [00:18<00:17,  2.80it/s]
#  53%|#####3    | 53/100 [00:18<00:15,  2.94it/s]
#  54%|#####4    | 54/100 [00:19<00:15,  2.97it/s]
#  55%|#####5    | 55/100 [00:19<00:15,  2.98it/s]
#  56%|#####6    | 56/100 [00:19<00:14,  3.13it/s]
#  57%|#####6    | 57/100 [00:19<00:13,  3.21it/s]
#  58%|#####8    | 58/100 [00:20<00:12,  3.24it/s]
#  59%|#####8    | 59/100 [00:20<00:13,  3.15it/s]
#  60%|######    | 60/100 [00:20<00:12,  3.17it/s]
#  61%|######1   | 61/100 [00:21<00:12,  3.22it/s]
#  62%|######2   | 62/100 [00:21<00:11,  3.28it/s]
#  63%|######3   | 63/100 [00:21<00:11,  3.32it/s]
#  64%|######4   | 64/100 [00:22<00:10,  3.37it/s]
#  65%|######5   | 65/100 [00:22<00:10,  3.43it/s]
#  66%|######6   | 66/100 [00:22<00:09,  3.45it/s]
#  67%|######7   | 67/100 [00:22<00:09,  3.42it/s]
#  68%|######8   | 68/100 [00:23<00:09,  3.39it/s]
#  69%|######9   | 69/100 [00:23<00:11,  2.71it/s]
#  70%|#######   | 70/100 [00:24<00:10,  2.89it/s]
#  71%|#######1  | 71/100 [00:24<00:09,  2.98it/s]
#  72%|#######2  | 72/100 [00:24<00:09,  2.99it/s]
#  73%|#######3  | 73/100 [00:25<00:08,  3.06it/s]
#  74%|#######4  | 74/100 [00:25<00:08,  2.99it/s]
#  75%|#######5  | 75/100 [00:25<00:08,  3.08it/s]
#  76%|#######6  | 76/100 [00:26<00:13,  1.80it/s]
#  77%|#######7  | 77/100 [00:27<00:10,  2.12it/s]
#  78%|#######8  | 78/100 [00:27<00:09,  2.41it/s]
#  79%|#######9  | 79/100 [00:27<00:08,  2.37it/s]
#  80%|########  | 80/100 [00:28<00:07,  2.67it/s]
#  81%|########1 | 81/100 [00:28<00:08,  2.16it/s]
#  82%|########2 | 82/100 [00:29<00:07,  2.31it/s]
#  83%|########2 | 83/100 [00:29<00:06,  2.55it/s]
#  84%|########4 | 84/100 [00:29<00:05,  2.79it/s]
#  85%|########5 | 85/100 [00:29<00:05,  3.00it/s]
#  86%|########6 | 86/100 [00:30<00:04,  3.06it/s]
#  87%|########7 | 87/100 [00:31<00:06,  1.97it/s]
#  88%|########8 | 88/100 [00:31<00:05,  2.29it/s]
#  89%|########9 | 89/100 [00:31<00:04,  2.57it/s]
#  90%|######### | 90/100 [00:32<00:03,  2.71it/s]
#  91%|#########1| 91/100 [00:32<00:03,  2.95it/s]
#  92%|#########2| 92/100 [00:32<00:02,  2.72it/s]
#  93%|#########3| 93/100 [00:33<00:02,  2.56it/s]
#  94%|#########3| 94/100 [00:33<00:02,  2.70it/s]
#  95%|#########5| 95/100 [00:33<00:01,  2.77it/s]
#  96%|#########6| 96/100 [00:34<00:01,  2.94it/s]
#  97%|#########7| 97/100 [00:34<00:01,  2.59it/s]
#  98%|#########8| 98/100 [00:34<00:00,  2.68it/s]
#  99%|#########9| 99/100 [00:35<00:00,  2.82it/s]
# 100%|##########| 100/100 [00:35<00:00,  2.81it/s]
# 100%|##########| 100/100 [00:35<00:00,  2.81it/s]
# 2025-09-19 20:23:00.999 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7763 test 0.7264 metric ['0.7086']
#  67%|######6   | 2/3 [01:29<00:45, 45.02s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:26,  3.79it/s]
#   2%|2         | 2/100 [00:00<00:27,  3.59it/s]
#   3%|3         | 3/100 [00:00<00:27,  3.56it/s]
#   4%|4         | 4/100 [00:01<00:29,  3.28it/s]
#   5%|5         | 5/100 [00:01<00:29,  3.24it/s]
#   6%|6         | 6/100 [00:01<00:34,  2.70it/s]
#   7%|7         | 7/100 [00:02<00:31,  2.96it/s]
#   8%|8         | 8/100 [00:02<00:29,  3.08it/s]
#   9%|9         | 9/100 [00:02<00:29,  3.09it/s]
#  10%|#         | 10/100 [00:03<00:33,  2.66it/s]
#  11%|#1        | 11/100 [00:03<00:31,  2.87it/s]
#  12%|#2        | 12/100 [00:03<00:28,  3.10it/s]
#  13%|#3        | 13/100 [00:04<00:26,  3.26it/s]
#  14%|#4        | 14/100 [00:04<00:25,  3.33it/s]
#  15%|#5        | 15/100 [00:04<00:26,  3.23it/s]
#  16%|#6        | 16/100 [00:05<00:25,  3.27it/s]
#  17%|#7        | 17/100 [00:05<00:24,  3.37it/s]
#  18%|#8        | 18/100 [00:05<00:24,  3.39it/s]
#  19%|#9        | 19/100 [00:05<00:23,  3.45it/s]
#  20%|##        | 20/100 [00:06<00:38,  2.10it/s]
#  21%|##1       | 21/100 [00:07<00:32,  2.42it/s]
#  22%|##2       | 22/100 [00:07<00:30,  2.60it/s]
#  23%|##3       | 23/100 [00:07<00:27,  2.81it/s]
#  24%|##4       | 24/100 [00:07<00:25,  3.02it/s]
#  25%|##5       | 25/100 [00:08<00:24,  3.11it/s]
#  26%|##6       | 26/100 [00:08<00:23,  3.09it/s]
#  27%|##7       | 27/100 [00:08<00:23,  3.16it/s]
#  28%|##8       | 28/100 [00:09<00:22,  3.24it/s]
#  29%|##9       | 29/100 [00:09<00:21,  3.29it/s]
#  30%|###       | 30/100 [00:09<00:22,  3.15it/s]
#  31%|###1      | 31/100 [00:10<00:22,  3.00it/s]
#  32%|###2      | 32/100 [00:10<00:21,  3.13it/s]
#  33%|###3      | 33/100 [00:10<00:20,  3.23it/s]
#  34%|###4      | 34/100 [00:11<00:19,  3.35it/s]
#  35%|###5      | 35/100 [00:11<00:20,  3.10it/s]
#  36%|###6      | 36/100 [00:11<00:20,  3.20it/s]
#  37%|###7      | 37/100 [00:12<00:19,  3.25it/s]
#  38%|###8      | 38/100 [00:12<00:18,  3.31it/s]
#  39%|###9      | 39/100 [00:13<00:25,  2.38it/s]
#  40%|####      | 40/100 [00:13<00:22,  2.70it/s]
#  41%|####1     | 41/100 [00:13<00:20,  2.87it/s]
#  42%|####2     | 42/100 [00:13<00:18,  3.07it/s]
#  43%|####3     | 43/100 [00:14<00:17,  3.19it/s]
#  44%|####4     | 44/100 [00:14<00:17,  3.25it/s]
#  45%|####5     | 45/100 [00:14<00:16,  3.28it/s]
#  46%|####6     | 46/100 [00:15<00:16,  3.27it/s]
#  47%|####6     | 47/100 [00:16<00:33,  1.57it/s]
#  48%|####8     | 48/100 [00:16<00:27,  1.92it/s]
#  49%|####9     | 49/100 [00:16<00:22,  2.27it/s]
#  50%|#####     | 50/100 [00:17<00:19,  2.59it/s]
#  51%|#####1    | 51/100 [00:17<00:17,  2.80it/s]
#  52%|#####2    | 52/100 [00:17<00:15,  3.04it/s]
#  53%|#####3    | 53/100 [00:18<00:16,  2.86it/s]
#  54%|#####4    | 54/100 [00:18<00:15,  2.97it/s]
#  55%|#####5    | 55/100 [00:18<00:14,  3.05it/s]
#  56%|#####6    | 56/100 [00:19<00:14,  3.12it/s]
#  57%|#####6    | 57/100 [00:19<00:13,  3.16it/s]
#  58%|#####8    | 58/100 [00:19<00:13,  3.12it/s]
#  59%|#####8    | 59/100 [00:19<00:12,  3.24it/s]
#  60%|######    | 60/100 [00:20<00:12,  3.24it/s]
#  61%|######1   | 61/100 [00:20<00:12,  3.25it/s]
#  62%|######2   | 62/100 [00:20<00:12,  3.14it/s]
#  63%|######3   | 63/100 [00:21<00:11,  3.15it/s]
#  64%|######4   | 64/100 [00:21<00:11,  3.22it/s]
#  65%|######5   | 65/100 [00:21<00:10,  3.29it/s]
#  66%|######6   | 66/100 [00:22<00:10,  3.25it/s]
#  67%|######7   | 67/100 [00:22<00:09,  3.31it/s]
#  68%|######8   | 68/100 [00:22<00:09,  3.38it/s]
#  69%|######9   | 69/100 [00:23<00:09,  3.39it/s]
#  70%|#######   | 70/100 [00:23<00:08,  3.43it/s]
#  71%|#######1  | 71/100 [00:23<00:10,  2.67it/s]
#  72%|#######2  | 72/100 [00:24<00:09,  2.94it/s]
#  73%|#######3  | 73/100 [00:24<00:08,  3.05it/s]
#  74%|#######4  | 74/100 [00:24<00:08,  3.17it/s]
#  75%|#######5  | 75/100 [00:25<00:07,  3.22it/s]
#  76%|#######6  | 76/100 [00:25<00:07,  3.27it/s]
#  77%|#######7  | 77/100 [00:25<00:06,  3.31it/s]
#  78%|#######8  | 78/100 [00:25<00:06,  3.28it/s]
#  79%|#######9  | 79/100 [00:26<00:06,  3.31it/s]
#  80%|########  | 80/100 [00:26<00:07,  2.75it/s]
#  81%|########1 | 81/100 [00:27<00:06,  2.90it/s]
#  82%|########2 | 82/100 [00:27<00:06,  2.89it/s]
#  83%|########2 | 83/100 [00:27<00:05,  2.89it/s]
#  84%|########4 | 84/100 [00:28<00:05,  3.00it/s]
#  85%|########5 | 85/100 [00:28<00:05,  2.96it/s]
#  86%|########6 | 86/100 [00:28<00:04,  3.02it/s]
#  87%|########7 | 87/100 [00:29<00:04,  2.96it/s]
#  88%|########8 | 88/100 [00:29<00:03,  3.07it/s]
#  89%|########9 | 89/100 [00:29<00:03,  3.09it/s]
#  90%|######### | 90/100 [00:30<00:03,  2.78it/s]
#  91%|#########1| 91/100 [00:30<00:03,  2.94it/s]
#  92%|#########2| 92/100 [00:30<00:02,  3.08it/s]
#  93%|#########3| 93/100 [00:30<00:02,  3.14it/s]
#  94%|#########3| 94/100 [00:31<00:01,  3.15it/s]
#  95%|#########5| 95/100 [00:31<00:01,  3.13it/s]
#  96%|#########6| 96/100 [00:31<00:01,  3.21it/s]
#  97%|#########7| 97/100 [00:32<00:00,  3.28it/s]
#  98%|#########8| 98/100 [00:32<00:00,  3.08it/s]
#  99%|#########9| 99/100 [00:32<00:00,  3.10it/s]
# 100%|##########| 100/100 [00:33<00:00,  3.18it/s]
# 100%|##########| 100/100 [00:33<00:00,  3.01it/s]
# 2025-09-19 20:23:44.451 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6365 test 0.6685 metric ['0.7542']
# 100%|##########| 3/3 [02:12<00:00, 44.31s/it]
# 100%|##########| 3/3 [02:12<00:00, 44.32s/it]
# 100%|██████████| 3/3 [03:59<00:00, 79.83s/trial, best loss: 0.6430426985025406]

# %% [markdown]
# After running this, you can look at the best_result

# %%
best_result
# Out:
# {'filters': np.float64(72.0),
#  'kernel_size': np.float64(3.0),
#  'num_layers': np.float64(3.0)}

# %% [markdown]
# # MLflow GUI
# MLflow has a really great dashboard.
# you can see it with the command:
# ```bash
# mlflow server \
#     --backend-store-uri sqlite:///mlflow.db \
#     --host 127.0.0.1 \
#     --port 5000 \
# ```
#
# The `--backend-store-uri` argument specifies the location of the SQLite database file, which is used to store experiment metadata, such as parameters, metrics, and artifacts.
# We have initialized the experiment with `mlflow.set_tracking_uri("sqlite:///mlflow.db")`, so `mlflow.db` is the location we need.
#
# `--host` tells the server we use our own machine (localhost), and `--port` specifies the port number on which the server will listen for incoming requests. In this case, we are using port 5000. Sometimes, you can have conflicts on a specific port and it could help to change the port (eg to 5001)
#
# Note that on a windows machine, the `\` gives errors (because, why not, right) so for windows you might need to remove the `\` and put everything on a single line.
#
# I have created a `Makefile` to automate these commands, but if it doesnt work (again, because you are on windows for example) you can just type the command by hand in your terminal.
#
# After starting this up, go to `http://127.0.0.1:5000` in your browser. You should see the MLflow UI, where you can explore your experiments, runs, and metrics. The UI provides a user-friendly way to visualize and compare different runs, making it easier to analyze the results of your hyperparameter optimization and model training.

# %% [markdown]
# Test for tuning parameters

# %%
import torch
import torch.nn as nn
from typing import List, Literal, Optional

class FlexCNN(nn.Module):
    """
    Een modulaire CNN waarmee je conv-blokken, normalisatie en dropout als hyperparameters kunt variëren.
    """
    def __init__(
        self,
        input_channels: int = 1,
        num_classes: int = 10,
        conv_blocks: int = 3,
        base_filters: int = 32,
        filters_growth: float = 1.0,  # 1.0 = constant, 2.0 = verdubbelen per blok, etc.
        kernel_size: int = 3,
        pool_kernel: int = 2,
        norm: Literal["batch", "layer", "none"] = "batch",
        hidden_units: List[int] = [128, 64],
        dropout_p: float = 0.2,
        global_pool: Literal["avg", "max", "adaptive"] = "adaptive",
    ):
        super().__init__()
        self.input_channels = input_channels
        self.num_classes = num_classes
        self.conv_blocks = conv_blocks
        self.base_filters = base_filters
        self.filters_growth = filters_growth
        self.kernel_size = kernel_size
        self.pool_kernel = pool_kernel
        self.norm = norm
        self.hidden_units = hidden_units
        self.dropout_p = dropout_p
        self.global_pool = global_pool

        # ---- Convolutionele blokken (ModuleList) ----
        in_ch = input_channels
        convs = []
        filters = base_filters
        padding = kernel_size // 2  # 'same-ish' bij stride=1

        for b in range(conv_blocks):
            block = []
            block.append(nn.Conv2d(in_ch, int(filters), kernel_size=kernel_size, stride=1, padding=padding))
            if norm == "batch":
                block.append(nn.BatchNorm2d(int(filters)))
            elif norm == "layer":
                # LayerNorm over (C,H,W) -> channels-last LN: beter via GroupNorm met 1 group
                block.append(nn.GroupNorm(1, int(filters)))
            block.append(nn.ReLU(inplace=True))
            block.append(nn.MaxPool2d(kernel_size=pool_kernel))

            convs.append(nn.Sequential(*block))
            in_ch = int(filters)
            filters = int(filters * filters_growth if filters_growth > 0 else filters)

        self.convs = nn.ModuleList(convs)

        # ---- Global pooling om feature-dim te fixeren ----
        if global_pool == "avg":
            self.global_pool_layer = nn.AdaptiveAvgPool2d((1,1))
        elif global_pool == "max":
            self.global_pool_layer = nn.AdaptiveMaxPool2d((1,1))
        else:
            self.global_pool_layer = nn.AdaptiveAvgPool2d((1,1))  # default

        # ---- Dense gedeelte + Dropout ----
        dense_layers = [nn.Flatten()]  # (N, C, 1, 1) -> (N, C)
        in_features = in_ch  # na global pool is C over
        for hu in hidden_units:
            dense_layers.append(nn.Linear(in_features, hu))
            # Normalisatie kan ook op dense: BatchNorm1d of LayerNorm
            if norm == "batch":
                dense_layers.append(nn.BatchNorm1d(hu))
            elif norm == "layer":
                dense_layers.append(nn.LayerNorm(hu))
            dense_layers.append(nn.ReLU(inplace=True))
            if dropout_p and dropout_p > 0:
                dense_layers.append(nn.Dropout(p=dropout_p))
            in_features = hu

        dense_layers.append(nn.Linear(in_features, num_classes))
        self.dense = nn.Sequential(*dense_layers)

    def forward(self, x):
        for block in self.convs:
            x = block(x)
        x = self.global_pool_layer(x)
        logits = self.dense(x)
        return logits

# %%
import mlflow
from mltrainer import metrics, Trainer, TrainerSettings, ReportTypes
import torch.optim as optim

# Tracking en experiment instellen
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("cnn_hparam_search")

# Trainer settings (pas aan op jouw dataset/pipeline)
accuracy = metrics.Accuracy()
settings = TrainerSettings(
    epochs=6,                  # iets langer trainen geeft stabielere vergelijking
    metrics=[accuracy],
    logdir="modellogs",
    train_steps=200,           # pas aan naar je dataset/generator
    valid_steps=100,
    reporttypes=[ReportTypes.MLFLOW, ReportTypes.TOML],
)
# Out:
# 2025/09/19 20:37:14 INFO mlflow.tracking.fluent: Experiment with name 'cnn_hparam_search' does not exist. Creating a new experiment.
# 2025-09-19 20:37:14.486 | INFO     | mltrainer.settings:check_path:60 - Created logdir c:\GitHub\portfolio-JN\2-hypertuning-mlflow\modellogs

# %%
# Voorbeeld search space (pas gerust aan of breid uit)
grids = {
    "conv_blocks": [2, 3, 4],
    "base_filters": [16, 32],
    "filters_growth": [1.0, 2.0],
    "norm": ["none", "batch", "layer"],
    "dropout_p": [0.0, 0.3],
    "hidden_units": [(128,), (128, 64)],
    "lr": [1e-3, 3e-4],
    "weight_decay": [0.0, 1e-4],
    "batchsize": [64],  # als je batchsize varieert, log die ook en geef hem door aan je dataloader
}

import itertools

def run_one(hp):
    # Model maken
    model = FlexCNN(
        input_channels=1,
        num_classes=10,
        conv_blocks=hp["conv_blocks"],
        base_filters=hp["base_filters"],
        filters_growth=hp["filters_growth"],
        norm=hp["norm"],
        hidden_units=list(hp["hidden_units"]),
        dropout_p=hp["dropout_p"],
        global_pool="adaptive",
    ).to("cpu")

    # Trainer klaarzetten (je eigen streamers invullen)
    loss_fn = nn.CrossEntropyLoss()
    optimizer = optim.Adam
    scheduler = None  # of bijvoorbeeld optim.lr_scheduler.ReduceLROnPlateau

    trainer = Trainer(
        model=model,
        settings=settings,
        loss_fn=loss_fn,
        optimizer=optimizer,
        traindataloader=trainstreamer,     # <-- gebruik je bestaande
        validdataloader=validstreamer,     # <-- gebruik je bestaande
        scheduler=scheduler
    )

    # MLflow run
    with mlflow.start_run():
        # Hyperparameters loggen
        mlflow.log_params({
            "conv_blocks": hp["conv_blocks"],
            "base_filters": hp["base_filters"],
            "filters_growth": hp["filters_growth"],
            "norm": hp["norm"],
            "dropout_p": hp["dropout_p"],
            "hidden_units": "-".join(map(str, hp["hidden_units"])),
            "lr": hp["lr"],
            "weight_decay": hp["weight_decay"],
            "batchsize": hp["batchsize"],
        })
        mlflow.set_tag("model", "FlexCNN")
        mlflow.set_tag("dev", "JN")

        # Zorg dat je optimizer de lr/weight_decay mee krijgt (je Trainer kan dat als class doorgeven)
        # Als je Trainer explicit kwargs verwacht:
        trainer.optimizer_kwargs = {"lr": hp["lr"], "weight_decay": hp["weight_decay"]}

        # Trainen/valideren
        trainer.loop()  # jouw Trainer logt MLFLOW/TOML al via settings

        # (Optioneel) extra metrics of artefacten loggen
        # mlflow.log_metric("final_val_acc", float(...))
        # mlflow.log_artifact("path/naar/confusion_matrix.png")
    return

# Bruteforce grid (klein houden om te starten)
keys = list(grids.keys())
values = [grids[k] for k in keys]
for combo in itertools.product(*values):
    hp = dict(zip(keys, combo))
    run_one(hp)
# Out:
# 2025-09-19 20:38:19.175 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-203819
# 2025-09-19 20:38:19.178 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 118.67it/s]
# 2025-09-19 20:38:21.324 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.9764 test 1.6079 metric ['0.4353']
# 100%|██████████| 200/200 [00:01<00:00, 122.55it/s]
# 2025-09-19 20:38:23.383 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.3603 test 1.1987 metric ['0.5505']
# 100%|██████████| 200/200 [00:01<00:00, 132.17it/s]
# 2025-09-19 20:38:25.291 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.1248 test 1.0968 metric ['0.6255']
# 100%|██████████| 200/200 [00:01<00:00, 121.80it/s]
# 2025-09-19 20:38:27.385 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.0167 test 1.0335 metric ['0.6384']
# 100%|██████████| 200/200 [00:01<00:00, 128.77it/s]
# 2025-09-19 20:38:29.340 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.9955 test 0.9470 metric ['0.6580']
# 100%|██████████| 200/200 [00:01<00:00, 119.23it/s]
# 2025-09-19 20:38:31.429 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.9314 test 0.9145 metric ['0.6792']
# 100%|██████████| 6/6 [00:12<00:00,  2.04s/it]
# 2025-09-19 20:38:31.438 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-203831
# 2025-09-19 20:38:31.439 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 130.98it/s]
# 2025-09-19 20:38:33.464 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.9410 test 1.4606 metric ['0.4678']
# 100%|██████████| 200/200 [00:01<00:00, 119.35it/s]
# 2025-09-19 20:38:35.589 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.2542 test 1.1575 metric ['0.6097']
# 100%|██████████| 200/200 [00:01<00:00, 119.74it/s]
# 2025-09-19 20:38:37.695 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.0856 test 1.0310 metric ['0.6530']
# 100%|██████████| 200/200 [00:01<00:00, 113.77it/s]
# 2025-09-19 20:38:39.900 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.9702 test 0.9608 metric ['0.6722']
# 100%|██████████| 200/200 [00:01<00:00, 120.04it/s]
# 2025-09-19 20:38:42.032 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.9231 test 0.9424 metric ['0.6648']
# 100%|██████████| 200/200 [00:01<00:00, 120.75it/s]
# 2025-09-19 20:38:44.101 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.8851 test 0.8528 metric ['0.6980']
# 100%|██████████| 6/6 [00:12<00:00,  2.11s/it]
# 2025-09-19 20:38:44.110 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-203844
# 2025-09-19 20:38:44.111 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 119.71it/s]
# 2025-09-19 20:38:46.249 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.9839 test 1.4917 metric ['0.4437']
# 100%|██████████| 200/200 [00:01<00:00, 127.35it/s]
# 2025-09-19 20:38:48.213 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.2616 test 1.1501 metric ['0.5781']
# 100%|██████████| 200/200 [00:01<00:00, 118.48it/s]
# 2025-09-19 20:38:50.376 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.0634 test 1.0129 metric ['0.6120']
# 100%|██████████| 200/200 [00:01<00:00, 126.07it/s]
# 2025-09-19 20:38:52.411 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.9753 test 0.9748 metric ['0.6409']
# 100%|██████████| 200/200 [00:01<00:00, 128.46it/s]
# 2025-09-19 20:38:54.383 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.9294 test 0.9362 metric ['0.6506']
# 100%|██████████| 200/200 [00:01<00:00, 124.61it/s]
# 2025-09-19 20:38:56.407 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.8895 test 0.8624 metric ['0.6763']
# 100%|██████████| 6/6 [00:12<00:00,  2.04s/it]
# 2025-09-19 20:38:56.416 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-203856
# 2025-09-19 20:38:56.416 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 115.41it/s]
# 2025-09-19 20:38:58.641 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0337 test 1.6634 metric ['0.4152']
# 100%|██████████| 200/200 [00:01<00:00, 110.97it/s]
# 2025-09-19 20:39:00.900 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.3505 test 1.1699 metric ['0.5859']
# 100%|██████████| 200/200 [00:01<00:00, 108.64it/s]
# 2025-09-19 20:39:03.203 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.0775 test 1.0188 metric ['0.6212']
# 100%|██████████| 200/200 [00:01<00:00, 124.07it/s]
# 2025-09-19 20:39:05.249 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.9727 test 0.9505 metric ['0.6542']
# 100%|██████████| 200/200 [00:01<00:00, 112.12it/s]
# 2025-09-19 20:39:07.535 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.9080 test 0.8702 metric ['0.6825']
# 100%|██████████| 200/200 [00:01<00:00, 116.99it/s]
# 2025-09-19 20:39:09.682 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.8550 test 0.8579 metric ['0.6919']
# 100%|██████████| 6/6 [00:13<00:00,  2.21s/it]
# 2025-09-19 20:39:09.689 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-203909
# 2025-09-19 20:39:09.690 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 111.62it/s]
# 2025-09-19 20:39:11.977 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.9935 test 1.6475 metric ['0.3630']
# 100%|██████████| 200/200 [00:01<00:00, 105.08it/s]
# 2025-09-19 20:39:14.324 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.5572 test 1.4200 metric ['0.4364']
# 100%|██████████| 200/200 [00:01<00:00, 114.45it/s]
# 2025-09-19 20:39:16.534 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.3036 test 1.2260 metric ['0.5167']
# 100%|██████████| 200/200 [00:02<00:00, 97.28it/s]
# 2025-09-19 20:39:19.070 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.1517 test 1.1366 metric ['0.5419']
# 100%|██████████| 200/200 [00:01<00:00, 112.31it/s]
# 2025-09-19 20:39:21.291 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.0942 test 1.0567 metric ['0.6012']
# 100%|██████████| 200/200 [00:02<00:00, 94.00it/s]
# 2025-09-19 20:39:23.917 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 1.0281 test 1.0153 metric ['0.6273']
# 100%|██████████| 6/6 [00:14<00:00,  2.37s/it]
# 2025-09-19 20:39:23.926 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-203923
# 2025-09-19 20:39:23.927 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 97.40it/s]
# 2025-09-19 20:39:26.443 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0229 test 1.7210 metric ['0.3156']
# 100%|██████████| 200/200 [00:01<00:00, 117.84it/s]
# 2025-09-19 20:39:28.652 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.5504 test 1.3625 metric ['0.4764']
# 100%|██████████| 200/200 [00:01<00:00, 114.28it/s]
# 2025-09-19 20:39:30.863 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.2832 test 1.1597 metric ['0.5502']
# 100%|██████████| 200/200 [00:01<00:00, 106.78it/s]
# 2025-09-19 20:39:33.243 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.0764 test 1.0292 metric ['0.6239']
# 100%|██████████| 200/200 [00:02<00:00, 94.37it/s]
# 2025-09-19 20:39:35.826 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.9725 test 0.9516 metric ['0.6623']
# 100%|██████████| 200/200 [00:01<00:00, 109.49it/s]
# 2025-09-19 20:39:38.097 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.9175 test 0.9036 metric ['0.6655']
# 100%|██████████| 6/6 [00:14<00:00,  2.36s/it]
# 2025-09-19 20:39:38.104 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-203938
# 2025-09-19 20:39:38.105 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 112.28it/s]
# 2025-09-19 20:39:40.358 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.9578 test 1.6032 metric ['0.3983']
# 100%|██████████| 200/200 [00:01<00:00, 113.01it/s]
# 2025-09-19 20:39:42.539 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.3800 test 1.2573 metric ['0.5086']
# 100%|██████████| 200/200 [00:01<00:00, 110.67it/s]
# 2025-09-19 20:39:44.811 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.1569 test 1.1018 metric ['0.5822']
# 100%|██████████| 200/200 [00:01<00:00, 107.57it/s]
# 2025-09-19 20:39:47.101 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.0426 test 1.0397 metric ['0.6180']
# 100%|██████████| 200/200 [00:01<00:00, 108.08it/s]
# 2025-09-19 20:39:49.457 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.0027 test 0.9639 metric ['0.6583']
# 100%|██████████| 200/200 [00:01<00:00, 113.80it/s]
# 2025-09-19 20:39:51.695 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.9775 test 0.9449 metric ['0.6489']
# 100%|██████████| 6/6 [00:13<00:00,  2.26s/it]
# 2025-09-19 20:39:51.703 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-203951
# 2025-09-19 20:39:51.703 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 115.01it/s]
# 2025-09-19 20:39:53.914 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.9826 test 1.6128 metric ['0.3717']
# 100%|██████████| 200/200 [00:01<00:00, 110.91it/s]
# 2025-09-19 20:39:56.160 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.4867 test 1.3197 metric ['0.4800']
# 100%|██████████| 200/200 [00:01<00:00, 112.31it/s]
# 2025-09-19 20:39:58.443 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.2328 test 1.1321 metric ['0.5795']
# 100%|██████████| 200/200 [00:01<00:00, 105.36it/s]
# 2025-09-19 20:40:00.853 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.0744 test 1.0474 metric ['0.6111']
# 100%|██████████| 200/200 [00:02<00:00, 98.06it/s]
# 2025-09-19 20:40:03.338 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.0068 test 0.9626 metric ['0.6434']
# 100%|██████████| 200/200 [00:02<00:00, 87.77it/s]
# 2025-09-19 20:40:06.053 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.9578 test 0.9517 metric ['0.6452']
# 100%|██████████| 6/6 [00:14<00:00,  2.39s/it]
# 2025-09-19 20:40:06.061 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204006
# 2025-09-19 20:40:06.062 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 119.91it/s]
# 2025-09-19 20:40:08.212 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0666 test 1.7507 metric ['0.3972']
# 100%|██████████| 200/200 [00:01<00:00, 106.85it/s]
# 2025-09-19 20:40:10.555 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.4608 test 1.1716 metric ['0.6041']
# 100%|██████████| 200/200 [00:01<00:00, 124.13it/s]
# 2025-09-19 20:40:12.560 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.1401 test 1.0343 metric ['0.6322']
# 100%|██████████| 200/200 [00:01<00:00, 126.52it/s]
# 2025-09-19 20:40:14.566 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.0354 test 1.0020 metric ['0.6327']
# 100%|██████████| 200/200 [00:01<00:00, 112.85it/s]
# 2025-09-19 20:40:16.820 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.0007 test 0.9409 metric ['0.6623']
# 100%|██████████| 200/200 [00:01<00:00, 116.75it/s]
# 2025-09-19 20:40:18.979 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.9678 test 0.9409 metric ['0.6542']
# 100%|██████████| 6/6 [00:12<00:00,  2.15s/it]
# 2025-09-19 20:40:18.989 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204018
# 2025-09-19 20:40:18.990 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 112.53it/s]
# 2025-09-19 20:40:21.281 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0277 test 1.6970 metric ['0.3247']
# 100%|██████████| 200/200 [00:01<00:00, 123.04it/s]
# 2025-09-19 20:40:23.300 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.5087 test 1.3274 metric ['0.4641']
# 100%|██████████| 200/200 [00:01<00:00, 126.69it/s]
# 2025-09-19 20:40:25.312 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.3127 test 1.2132 metric ['0.5787']
# 100%|██████████| 200/200 [00:01<00:00, 112.73it/s]
# 2025-09-19 20:40:27.553 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.1834 test 1.0942 metric ['0.6252']
# 100%|██████████| 200/200 [00:01<00:00, 121.05it/s]
# 2025-09-19 20:40:29.595 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.0817 test 0.9994 metric ['0.6511']
# 100%|██████████| 200/200 [00:01<00:00, 132.41it/s]
# 2025-09-19 20:40:31.600 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 1.0213 test 0.9752 metric ['0.6278']
# 100%|██████████| 6/6 [00:12<00:00,  2.10s/it]
# 2025-09-19 20:40:31.608 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204031
# 2025-09-19 20:40:31.609 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 118.72it/s]
# 2025-09-19 20:40:33.771 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0224 test 1.7033 metric ['0.3911']
# 100%|██████████| 200/200 [00:01<00:00, 120.66it/s]
# 2025-09-19 20:40:35.878 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.4586 test 1.2454 metric ['0.5219']
# 100%|██████████| 200/200 [00:01<00:00, 112.18it/s]
# 2025-09-19 20:40:38.094 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.2088 test 1.1118 metric ['0.5736']
# 100%|██████████| 200/200 [00:01<00:00, 113.64it/s]
# 2025-09-19 20:40:40.321 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.1151 test 1.0347 metric ['0.6331']
# 100%|██████████| 200/200 [00:01<00:00, 123.44it/s]
# 2025-09-19 20:40:42.330 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.0537 test 1.0097 metric ['0.6325']
# 100%|██████████| 200/200 [00:01<00:00, 120.09it/s]
# 2025-09-19 20:40:44.405 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 1.0043 test 0.9672 metric ['0.6581']
# 100%|██████████| 6/6 [00:12<00:00,  2.13s/it]
# 2025-09-19 20:40:44.412 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204044
# 2025-09-19 20:40:44.413 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 121.45it/s]
# 2025-09-19 20:40:46.481 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0523 test 1.6637 metric ['0.3912']
# 100%|██████████| 200/200 [00:01<00:00, 127.36it/s]
# 2025-09-19 20:40:48.445 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.4428 test 1.2452 metric ['0.5377']
# 100%|██████████| 200/200 [00:01<00:00, 110.78it/s]
# 2025-09-19 20:40:50.743 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.1886 test 1.1161 metric ['0.5731']
# 100%|██████████| 200/200 [00:01<00:00, 113.05it/s]
# 2025-09-19 20:40:52.978 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.0910 test 1.0094 metric ['0.6395']
# 100%|██████████| 200/200 [00:01<00:00, 114.74it/s]
# 2025-09-19 20:40:55.195 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.9988 test 0.9448 metric ['0.6506']
# 100%|██████████| 200/200 [00:01<00:00, 124.19it/s]
# 2025-09-19 20:40:57.229 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.9770 test 0.9396 metric ['0.6672']
# 100%|██████████| 6/6 [00:12<00:00,  2.13s/it]
# 2025-09-19 20:40:57.238 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204057
# 2025-09-19 20:40:57.239 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 109.03it/s]
# 2025-09-19 20:40:59.591 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0546 test 1.6424 metric ['0.4442']
# 100%|██████████| 200/200 [00:01<00:00, 103.22it/s]
# 2025-09-19 20:41:01.977 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.4294 test 1.1517 metric ['0.6022']
# 100%|██████████| 200/200 [00:01<00:00, 106.72it/s]
# 2025-09-19 20:41:04.349 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.1934 test 1.0576 metric ['0.6342']
# 100%|██████████| 200/200 [00:01<00:00, 110.64it/s]
# 2025-09-19 20:41:06.664 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.1117 test 1.0054 metric ['0.6434']
# 100%|██████████| 200/200 [00:02<00:00, 96.45it/s]
# 2025-09-19 20:41:09.170 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.0554 test 0.9488 metric ['0.6450']
# 100%|██████████| 200/200 [00:01<00:00, 103.21it/s]
# 2025-09-19 20:41:11.632 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 1.0237 test 0.9245 metric ['0.6516']
# 100%|██████████| 6/6 [00:14<00:00,  2.39s/it]
# 2025-09-19 20:41:11.640 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204111
# 2025-09-19 20:41:11.641 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 100.58it/s]
# 2025-09-19 20:41:14.092 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.9864 test 1.3607 metric ['0.5247']
# 100%|██████████| 200/200 [00:01<00:00, 110.33it/s]
# 2025-09-19 20:41:16.415 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.3044 test 1.1191 metric ['0.5803']
# 100%|██████████| 200/200 [00:02<00:00, 99.22it/s]
# 2025-09-19 20:41:18.888 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.1395 test 1.0453 metric ['0.6120']
# 100%|██████████| 200/200 [00:01<00:00, 111.36it/s]
# 2025-09-19 20:41:21.142 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.0614 test 0.9656 metric ['0.6547']
# 100%|██████████| 200/200 [00:01<00:00, 103.69it/s]
# 2025-09-19 20:41:23.656 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.0347 test 0.9373 metric ['0.6450']
# 100%|██████████| 200/200 [00:01<00:00, 105.53it/s]
# 2025-09-19 20:41:25.968 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.9981 test 0.9271 metric ['0.6478']
# 100%|██████████| 6/6 [00:14<00:00,  2.38s/it]
# 2025-09-19 20:41:25.976 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204125
# 2025-09-19 20:41:25.978 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 107.21it/s]
# 2025-09-19 20:41:28.338 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0423 test 1.7247 metric ['0.2759']
# 100%|██████████| 200/200 [00:01<00:00, 104.25it/s]
# 2025-09-19 20:41:30.730 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.5866 test 1.3159 metric ['0.4553']
# 100%|██████████| 200/200 [00:01<00:00, 115.81it/s]
# 2025-09-19 20:41:32.886 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.2719 test 1.1075 metric ['0.5802']
# 100%|██████████| 200/200 [00:02<00:00, 99.91it/s]
# 2025-09-19 20:41:35.345 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.1709 test 1.0461 metric ['0.6011']
# 100%|██████████| 200/200 [00:01<00:00, 112.76it/s]
# 2025-09-19 20:41:37.557 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.1066 test 1.0163 metric ['0.6162']
# 100%|██████████| 200/200 [00:02<00:00, 97.88it/s]
# 2025-09-19 20:41:40.054 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 1.0503 test 0.9533 metric ['0.6452']
# 100%|██████████| 6/6 [00:14<00:00,  2.34s/it]
# 2025-09-19 20:41:40.063 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204140
# 2025-09-19 20:41:40.064 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:01<00:00, 104.22it/s]
# 2025-09-19 20:41:42.404 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 2.0383 test 1.7012 metric ['0.3141']
# 100%|██████████| 200/200 [00:01<00:00, 118.77it/s]
# 2025-09-19 20:41:44.555 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 1.5623 test 1.3159 metric ['0.4231']
# 100%|██████████| 200/200 [00:01<00:00, 111.11it/s]
# 2025-09-19 20:41:46.830 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 1.2832 test 1.1606 metric ['0.5502']
# 100%|██████████| 200/200 [00:01<00:00, 109.69it/s]
# 2025-09-19 20:41:49.132 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 1.1849 test 1.0842 metric ['0.5814']
# 100%|██████████| 200/200 [00:01<00:00, 103.44it/s]
# 2025-09-19 20:41:51.533 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 1.1420 test 1.0312 metric ['0.6042']
# 100%|██████████| 200/200 [00:01<00:00, 109.45it/s]
# 2025-09-19 20:41:53.793 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 1.0911 test 1.0258 metric ['0.6223']
# 100%|██████████| 6/6 [00:13<00:00,  2.28s/it]
# 2025-09-19 20:41:53.803 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204153
# 2025-09-19 20:41:53.803 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 96.27it/s]
# 2025-09-19 20:41:56.404 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0739 test 0.7901 metric ['0.7255']
# 100%|██████████| 200/200 [00:02<00:00, 78.20it/s]
# 2025-09-19 20:41:59.450 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6282 test 0.7397 metric ['0.7262']
# 100%|██████████| 200/200 [00:02<00:00, 88.03it/s]
# 2025-09-19 20:42:02.190 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5662 test 0.6478 metric ['0.7555']
# 100%|██████████| 200/200 [00:02<00:00, 89.86it/s]
# 2025-09-19 20:42:04.896 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5293 test 0.6421 metric ['0.7798']
# 100%|██████████| 200/200 [00:02<00:00, 92.65it/s]
# 2025-09-19 20:42:07.519 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5057 test 0.8644 metric ['0.6852']
# 2025-09-19 20:42:07.520 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6421, current loss 0.8644.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 87.80it/s]
# 2025-09-19 20:42:10.263 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4716 test 0.7777 metric ['0.7172']
# 2025-09-19 20:42:10.264 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6421, current loss 0.7777.Counter 2/10.
# 100%|██████████| 6/6 [00:16<00:00,  2.74s/it]
# 2025-09-19 20:42:10.274 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204210
# 2025-09-19 20:42:10.275 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 93.49it/s]
# 2025-09-19 20:42:12.878 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.1279 test 0.7594 metric ['0.7358']
# 100%|██████████| 200/200 [00:02<00:00, 95.15it/s]
# 2025-09-19 20:42:15.489 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6487 test 0.7445 metric ['0.7420']
# 100%|██████████| 200/200 [00:02<00:00, 87.10it/s]
# 2025-09-19 20:42:18.342 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5721 test 0.5974 metric ['0.7845']
# 100%|██████████| 200/200 [00:02<00:00, 85.06it/s]
# 2025-09-19 20:42:21.187 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5265 test 0.6175 metric ['0.7769']
# 2025-09-19 20:42:21.187 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5974, current loss 0.6175.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 98.37it/s]
# 2025-09-19 20:42:23.679 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5139 test 0.5677 metric ['0.7875']
# 100%|██████████| 200/200 [00:02<00:00, 95.68it/s]
# 2025-09-19 20:42:26.305 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4816 test 0.5978 metric ['0.7788']
# 2025-09-19 20:42:26.306 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5677, current loss 0.5978.Counter 1/10.
# 100%|██████████| 6/6 [00:16<00:00,  2.67s/it]
# 2025-09-19 20:42:26.318 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204226
# 2025-09-19 20:42:26.319 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 91.17it/s]
# 2025-09-19 20:42:29.063 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0803 test 0.8322 metric ['0.6986']
# 100%|██████████| 200/200 [00:02<00:00, 99.03it/s]
# 2025-09-19 20:42:31.590 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6304 test 0.6642 metric ['0.7728']
# 100%|██████████| 200/200 [00:02<00:00, 80.01it/s]
# 2025-09-19 20:42:34.718 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5485 test 0.6656 metric ['0.7530']
# 2025-09-19 20:42:34.719 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6642, current loss 0.6656.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 75.25it/s]
# 2025-09-19 20:42:37.895 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5182 test 0.6734 metric ['0.7548']
# 2025-09-19 20:42:37.896 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6642, current loss 0.6734.Counter 2/10.
# 100%|██████████| 200/200 [00:02<00:00, 89.88it/s]
# 2025-09-19 20:42:40.627 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4913 test 0.6277 metric ['0.7545']
# 100%|██████████| 200/200 [00:02<00:00, 86.68it/s]
# 2025-09-19 20:42:43.505 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4645 test 0.5943 metric ['0.7939']
# 100%|██████████| 6/6 [00:17<00:00,  2.86s/it]
# 2025-09-19 20:42:43.515 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204243
# 2025-09-19 20:42:43.516 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 86.01it/s]
# 2025-09-19 20:42:46.379 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0558 test 0.7016 metric ['0.7700']
# 100%|██████████| 200/200 [00:02<00:00, 89.66it/s]
# 2025-09-19 20:42:49.145 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6258 test 0.6545 metric ['0.7573']
# 100%|██████████| 200/200 [00:02<00:00, 82.83it/s]
# 2025-09-19 20:42:52.172 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5578 test 0.7268 metric ['0.7284']
# 2025-09-19 20:42:52.173 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6545, current loss 0.7268.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 87.33it/s]
# 2025-09-19 20:42:55.060 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5094 test 0.5487 metric ['0.8005']
# 100%|██████████| 200/200 [00:02<00:00, 95.03it/s]
# 2025-09-19 20:42:57.613 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4888 test 0.6173 metric ['0.7677']
# 2025-09-19 20:42:57.613 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5487, current loss 0.6173.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 85.43it/s]
# 2025-09-19 20:43:00.438 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4799 test 0.6564 metric ['0.7605']
# 2025-09-19 20:43:00.439 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5487, current loss 0.6564.Counter 2/10.
# 100%|██████████| 6/6 [00:16<00:00,  2.82s/it]
# 2025-09-19 20:43:00.447 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204300
# 2025-09-19 20:43:00.448 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 78.92it/s]
# 2025-09-19 20:43:03.558 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0545 test 0.8313 metric ['0.6992']
# 100%|██████████| 200/200 [00:02<00:00, 78.81it/s]
# 2025-09-19 20:43:06.680 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6267 test 0.9703 metric ['0.6411']
# 2025-09-19 20:43:06.680 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.8313, current loss 0.9703.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 82.09it/s]
# 2025-09-19 20:43:09.607 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5632 test 0.5652 metric ['0.7967']
# 100%|██████████| 200/200 [00:02<00:00, 84.82it/s]
# 2025-09-19 20:43:12.520 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5361 test 0.5202 metric ['0.8108']
# 100%|██████████| 200/200 [00:02<00:00, 76.93it/s]
# 2025-09-19 20:43:15.605 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5097 test 0.5134 metric ['0.8156']
# 100%|██████████| 200/200 [00:02<00:00, 74.98it/s]
# 2025-09-19 20:43:18.813 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4731 test 0.5583 metric ['0.7967']
# 2025-09-19 20:43:18.814 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5134, current loss 0.5583.Counter 1/10.
# 100%|██████████| 6/6 [00:18<00:00,  3.06s/it]
# 2025-09-19 20:43:18.825 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204318
# 2025-09-19 20:43:18.826 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 81.89it/s]
# 2025-09-19 20:43:21.770 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0689 test 1.1069 metric ['0.5983']
# 100%|██████████| 200/200 [00:02<00:00, 80.06it/s]
# 2025-09-19 20:43:24.786 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6141 test 0.7284 metric ['0.7197']
# 100%|██████████| 200/200 [00:02<00:00, 89.07it/s]
# 2025-09-19 20:43:27.481 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5447 test 0.6334 metric ['0.7725']
# 100%|██████████| 200/200 [00:02<00:00, 86.14it/s]
# 2025-09-19 20:43:30.329 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5249 test 0.6336 metric ['0.7683']
# 2025-09-19 20:43:30.329 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6334, current loss 0.6336.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 83.29it/s]
# 2025-09-19 20:43:33.177 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4874 test 0.5100 metric ['0.8175']
# 100%|██████████| 200/200 [00:02<00:00, 82.48it/s]
# 2025-09-19 20:43:36.136 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4649 test 0.5431 metric ['0.8033']
# 2025-09-19 20:43:36.137 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5100, current loss 0.5431.Counter 1/10.
# 100%|██████████| 6/6 [00:17<00:00,  2.88s/it]
# 2025-09-19 20:43:36.145 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204336
# 2025-09-19 20:43:36.146 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 86.49it/s]
# 2025-09-19 20:43:38.956 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0695 test 0.7471 metric ['0.7348']
# 100%|██████████| 200/200 [00:02<00:00, 85.65it/s]
# 2025-09-19 20:43:41.862 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6322 test 0.6954 metric ['0.7564']
# 100%|██████████| 200/200 [00:02<00:00, 84.27it/s]
# 2025-09-19 20:43:44.799 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5687 test 0.6040 metric ['0.7891']
# 100%|██████████| 200/200 [00:02<00:00, 85.67it/s]
# 2025-09-19 20:43:47.623 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5224 test 0.6245 metric ['0.7816']
# 2025-09-19 20:43:47.624 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6040, current loss 0.6245.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 89.27it/s]
# 2025-09-19 20:43:50.401 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5033 test 0.9374 metric ['0.6703']
# 2025-09-19 20:43:50.402 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6040, current loss 0.9374.Counter 2/10.
# 100%|██████████| 200/200 [00:02<00:00, 84.69it/s]
# 2025-09-19 20:43:53.243 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4843 test 0.6186 metric ['0.7792']
# 2025-09-19 20:43:53.244 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6040, current loss 0.6186.Counter 3/10.
# 100%|██████████| 6/6 [00:17<00:00,  2.84s/it]
# 2025-09-19 20:43:53.252 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204353
# 2025-09-19 20:43:53.253 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 84.11it/s]
# 2025-09-19 20:43:56.181 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0353 test 1.0755 metric ['0.6244']
# 100%|██████████| 200/200 [00:02<00:00, 84.86it/s]
# 2025-09-19 20:43:59.023 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6344 test 0.9742 metric ['0.6580']
# 100%|██████████| 200/200 [00:02<00:00, 83.53it/s]
# 2025-09-19 20:44:01.879 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5714 test 0.7107 metric ['0.7408']
# 100%|██████████| 200/200 [00:02<00:00, 84.16it/s]
# 2025-09-19 20:44:04.709 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5090 test 0.5969 metric ['0.7863']
# 100%|██████████| 200/200 [00:02<00:00, 87.59it/s]
# 2025-09-19 20:44:07.508 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4972 test 0.9679 metric ['0.6633']
# 2025-09-19 20:44:07.509 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5969, current loss 0.9679.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 77.61it/s]
# 2025-09-19 20:44:10.629 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4737 test 0.9066 metric ['0.6900']
# 2025-09-19 20:44:10.629 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5969, current loss 0.9066.Counter 2/10.
# 100%|██████████| 6/6 [00:17<00:00,  2.89s/it]
# 2025-09-19 20:44:10.637 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204410
# 2025-09-19 20:44:10.638 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 82.27it/s]
# 2025-09-19 20:44:13.666 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2307 test 0.9137 metric ['0.6950']
# 100%|██████████| 200/200 [00:02<00:00, 89.45it/s]
# 2025-09-19 20:44:16.369 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7141 test 0.6974 metric ['0.7494']
# 100%|██████████| 200/200 [00:02<00:00, 88.42it/s]
# 2025-09-19 20:44:19.109 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6305 test 0.9295 metric ['0.6623']
# 2025-09-19 20:44:19.109 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6974, current loss 0.9295.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 97.05it/s]
# 2025-09-19 20:44:21.627 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5949 test 0.6112 metric ['0.7761']
# 100%|██████████| 200/200 [00:02<00:00, 93.10it/s]
# 2025-09-19 20:44:24.219 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5479 test 0.6190 metric ['0.7697']
# 2025-09-19 20:44:24.220 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6112, current loss 0.6190.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 97.85it/s]
# 2025-09-19 20:44:26.748 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.5248 test 0.5744 metric ['0.7934']
# 100%|██████████| 6/6 [00:16<00:00,  2.68s/it]
# 2025-09-19 20:44:26.757 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204426
# 2025-09-19 20:44:26.758 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 84.17it/s]
# 2025-09-19 20:44:29.626 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.1371 test 0.8062 metric ['0.7194']
# 100%|██████████| 200/200 [00:02<00:00, 92.78it/s]
# 2025-09-19 20:44:32.359 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7007 test 0.7346 metric ['0.7491']
# 100%|██████████| 200/200 [00:02<00:00, 91.68it/s]
# 2025-09-19 20:44:35.007 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6294 test 0.7086 metric ['0.7309']
# 100%|██████████| 200/200 [00:02<00:00, 99.21it/s]
# 2025-09-19 20:44:37.535 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5675 test 0.5848 metric ['0.7848']
# 100%|██████████| 200/200 [00:02<00:00, 89.45it/s]
# 2025-09-19 20:44:40.347 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5496 test 0.5520 metric ['0.7958']
# 100%|██████████| 200/200 [00:02<00:00, 81.81it/s]
# 2025-09-19 20:44:43.323 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.5263 test 0.5973 metric ['0.7778']
# 2025-09-19 20:44:43.324 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5520, current loss 0.5973.Counter 1/10.
# 100%|██████████| 6/6 [00:16<00:00,  2.76s/it]
# 2025-09-19 20:44:43.332 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204443
# 2025-09-19 20:44:43.333 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 85.43it/s]
# 2025-09-19 20:44:46.199 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.1816 test 0.7978 metric ['0.7278']
# 100%|██████████| 200/200 [00:02<00:00, 93.98it/s]
# 2025-09-19 20:44:48.773 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7147 test 0.9550 metric ['0.6416']
# 2025-09-19 20:44:48.774 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.7978, current loss 0.9550.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 89.18it/s]
# 2025-09-19 20:44:51.469 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6168 test 0.9951 metric ['0.6488']
# 2025-09-19 20:44:51.469 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.7978, current loss 0.9951.Counter 2/10.
# 100%|██████████| 200/200 [00:02<00:00, 83.95it/s]
# 2025-09-19 20:44:54.301 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.5814 test 0.5809 metric ['0.7892']
# 100%|██████████| 200/200 [00:02<00:00, 91.49it/s]
# 2025-09-19 20:44:56.959 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5620 test 0.5570 metric ['0.7978']
# 100%|██████████| 200/200 [00:02<00:00, 90.29it/s]
# 2025-09-19 20:44:59.606 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.5340 test 0.5186 metric ['0.8098']
# 100%|██████████| 6/6 [00:16<00:00,  2.71s/it]
# 2025-09-19 20:44:59.614 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204459
# 2025-09-19 20:44:59.614 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 82.90it/s]
# 2025-09-19 20:45:02.563 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2322 test 0.8498 metric ['0.6992']
# 100%|██████████| 200/200 [00:02<00:00, 88.16it/s]
# 2025-09-19 20:45:05.315 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7495 test 0.8955 metric ['0.6647']
# 2025-09-19 20:45:05.315 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.8498, current loss 0.8955.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 94.89it/s]
# 2025-09-19 20:45:07.871 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6547 test 1.0094 metric ['0.6475']
# 2025-09-19 20:45:07.872 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.8498, current loss 1.0094.Counter 2/10.
# 100%|██████████| 200/200 [00:02<00:00, 86.70it/s]
# 2025-09-19 20:45:10.650 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.6071 test 0.6196 metric ['0.7670']
# 100%|██████████| 200/200 [00:02<00:00, 91.99it/s]
# 2025-09-19 20:45:13.311 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5699 test 0.7170 metric ['0.7419']
# 2025-09-19 20:45:13.311 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6196, current loss 0.7170.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 84.95it/s]
# 2025-09-19 20:45:16.194 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.5459 test 0.5432 metric ['0.8048']
# 100%|██████████| 6/6 [00:16<00:00,  2.76s/it]
# 2025-09-19 20:45:16.203 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204516
# 2025-09-19 20:45:16.204 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 77.42it/s]
# 2025-09-19 20:45:19.290 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2639 test 0.8136 metric ['0.7244']
# 100%|██████████| 200/200 [00:02<00:00, 83.75it/s]
# 2025-09-19 20:45:22.147 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7781 test 0.7498 metric ['0.7284']
# 100%|██████████| 200/200 [00:02<00:00, 81.13it/s]
# 2025-09-19 20:45:25.151 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6848 test 0.7247 metric ['0.7264']
# 100%|██████████| 200/200 [00:03<00:00, 59.90it/s]
# 2025-09-19 20:45:28.948 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.6486 test 0.6927 metric ['0.7331']
# 100%|██████████| 200/200 [00:02<00:00, 76.19it/s]
# 2025-09-19 20:45:32.052 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.6149 test 0.5671 metric ['0.8050']
# 100%|██████████| 200/200 [00:02<00:00, 81.95it/s]
# 2025-09-19 20:45:35.071 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.5931 test 0.6085 metric ['0.7811']
# 2025-09-19 20:45:35.071 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5671, current loss 0.6085.Counter 1/10.
# 100%|██████████| 6/6 [00:18<00:00,  3.14s/it]
# 2025-09-19 20:45:35.082 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204535
# 2025-09-19 20:45:35.084 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 79.94it/s]
# 2025-09-19 20:45:38.076 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2970 test 0.9413 metric ['0.6500']
# 100%|██████████| 200/200 [00:02<00:00, 85.03it/s]
# 2025-09-19 20:45:40.947 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.8194 test 0.8312 metric ['0.6939']
# 100%|██████████| 200/200 [00:02<00:00, 85.54it/s]
# 2025-09-19 20:45:43.738 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.7144 test 0.6293 metric ['0.7742']
# 100%|██████████| 200/200 [00:02<00:00, 76.39it/s]
# 2025-09-19 20:45:46.900 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.6398 test 0.5983 metric ['0.7702']
# 100%|██████████| 200/200 [00:02<00:00, 84.39it/s]
# 2025-09-19 20:45:49.754 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.6254 test 0.6463 metric ['0.7553']
# 2025-09-19 20:45:49.754 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5983, current loss 0.6463.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 79.69it/s]
# 2025-09-19 20:45:52.728 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.5932 test 0.6661 metric ['0.7594']
# 2025-09-19 20:45:52.729 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5983, current loss 0.6661.Counter 2/10.
# 100%|██████████| 6/6 [00:17<00:00,  2.94s/it]
# 2025-09-19 20:45:52.737 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204552
# 2025-09-19 20:45:52.738 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 85.42it/s]
# 2025-09-19 20:45:55.561 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2340 test 0.8390 metric ['0.7070']
# 100%|██████████| 200/200 [00:02<00:00, 80.92it/s]
# 2025-09-19 20:45:58.584 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7724 test 0.7966 metric ['0.6869']
# 100%|██████████| 200/200 [00:02<00:00, 82.78it/s]
# 2025-09-19 20:46:01.571 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6834 test 0.5810 metric ['0.7875']
# 100%|██████████| 200/200 [00:02<00:00, 83.26it/s]
# 2025-09-19 20:46:04.499 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.6252 test 0.5454 metric ['0.8009']
# 100%|██████████| 200/200 [00:02<00:00, 84.66it/s]
# 2025-09-19 20:46:07.362 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.5989 test 0.5608 metric ['0.7973']
# 2025-09-19 20:46:07.363 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5454, current loss 0.5608.Counter 1/10.
# 100%|██████████| 200/200 [00:03<00:00, 64.78it/s]
# 2025-09-19 20:46:11.100 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.5917 test 0.6211 metric ['0.7666']
# 2025-09-19 20:46:11.102 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5454, current loss 0.6211.Counter 2/10.
# 100%|██████████| 6/6 [00:18<00:00,  3.06s/it]
# 2025-09-19 20:46:11.112 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204611
# 2025-09-19 20:46:11.113 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:03<00:00, 66.09it/s]
# 2025-09-19 20:46:14.978 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2699 test 0.7822 metric ['0.7409']
# 100%|██████████| 200/200 [00:03<00:00, 58.89it/s]
# 2025-09-19 20:46:19.055 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7698 test 0.8382 metric ['0.6873']
# 2025-09-19 20:46:19.056 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.7822, current loss 0.8382.Counter 1/10.
# 100%|██████████| 200/200 [00:03<00:00, 62.56it/s]
# 2025-09-19 20:46:22.988 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6745 test 0.6842 metric ['0.7412']
# 100%|██████████| 200/200 [00:03<00:00, 62.01it/s]
# 2025-09-19 20:46:26.913 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.6383 test 0.6689 metric ['0.7498']
# 100%|██████████| 200/200 [00:03<00:00, 63.82it/s]
# 2025-09-19 20:46:30.700 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.6089 test 0.7136 metric ['0.7395']
# 2025-09-19 20:46:30.701 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.6689, current loss 0.7136.Counter 1/10.
# 100%|██████████| 200/200 [00:02<00:00, 69.00it/s]
# 2025-09-19 20:46:34.202 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.5898 test 0.6569 metric ['0.7567']
# 100%|██████████| 6/6 [00:23<00:00,  3.84s/it]
# 2025-09-19 20:46:34.212 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204634
# 2025-09-19 20:46:34.213 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:02<00:00, 81.21it/s]
# 2025-09-19 20:46:37.308 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.4990 test 0.9751 metric ['0.6541']
# 100%|██████████| 200/200 [00:02<00:00, 82.14it/s]
# 2025-09-19 20:46:40.350 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.8619 test 0.8018 metric ['0.7002']
# 100%|██████████| 200/200 [00:02<00:00, 86.75it/s]
# 2025-09-19 20:46:43.234 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.7565 test 0.7218 metric ['0.7448']
# 100%|██████████| 200/200 [00:02<00:00, 82.00it/s]
# 2025-09-19 20:46:46.268 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.6935 test 0.6951 metric ['0.7442']
# 100%|██████████| 200/200 [00:02<00:00, 81.71it/s]
# 2025-09-19 20:46:49.378 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.6508 test 0.6717 metric ['0.7528']
# 100%|██████████| 200/200 [00:02<00:00, 79.03it/s]
# 2025-09-19 20:46:52.512 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.6365 test 0.6578 metric ['0.7611']
# 100%|██████████| 6/6 [00:18<00:00,  3.05s/it]
# 2025-09-19 20:46:52.521 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250919-204652
# ...
# 100%|██████████| 200/200 [00:10<00:00, 19.98it/s]
# 2025-09-20 01:23:11.423 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4583 test 0.4134 metric ['0.8531']
# 100%|██████████| 200/200 [00:08<00:00, 24.62it/s]
# 2025-09-20 01:23:20.979 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3837 test 0.4074 metric ['0.8484']
# 100%|██████████| 200/200 [00:08<00:00, 24.53it/s]
# 2025-09-20 01:23:30.507 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3457 test 0.3616 metric ['0.8670']
# 100%|██████████| 200/200 [00:09<00:00, 21.46it/s]
# 2025-09-20 01:23:41.389 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3305 test 0.3649 metric ['0.8667']
# 2025-09-20 01:23:41.389 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3616, current loss 0.3649.Counter 1/10.
# 100%|██████████| 200/200 [00:09<00:00, 21.16it/s]
# 2025-09-20 01:23:52.540 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3203 test 0.3073 metric ['0.8864']
# 100%|██████████| 6/6 [01:03<00:00, 10.63s/it]
# 2025-09-20 01:23:52.561 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-012352
# 2025-09-20 01:23:52.563 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:09<00:00, 20.63it/s]
# 2025-09-20 01:24:03.956 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8587 test 0.5486 metric ['0.7902']
# 100%|██████████| 200/200 [00:09<00:00, 21.21it/s]
# 2025-09-20 01:24:15.084 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4615 test 0.4228 metric ['0.8520']
# 100%|██████████| 200/200 [00:09<00:00, 20.95it/s]
# 2025-09-20 01:24:26.144 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4058 test 0.3975 metric ['0.8619']
# 100%|██████████| 200/200 [00:09<00:00, 21.84it/s]
# 2025-09-20 01:24:36.942 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3526 test 0.3787 metric ['0.8639']
# 100%|██████████| 200/200 [00:09<00:00, 21.64it/s]
# 2025-09-20 01:24:47.776 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3399 test 0.3236 metric ['0.8845']
# 100%|██████████| 200/200 [00:09<00:00, 21.86it/s]
# 2025-09-20 01:24:59.215 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3071 test 0.3536 metric ['0.8739']
# 2025-09-20 01:24:59.216 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3236, current loss 0.3536.Counter 1/10.
# 100%|██████████| 6/6 [01:06<00:00, 11.10s/it]
# 2025-09-20 01:24:59.234 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-012459
# 2025-09-20 01:24:59.235 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:09<00:00, 21.96it/s]
# 2025-09-20 01:25:09.737 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8652 test 0.5715 metric ['0.7933']
# 100%|██████████| 200/200 [00:07<00:00, 25.19it/s]
# 2025-09-20 01:25:18.991 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4658 test 0.4187 metric ['0.8450']
# 100%|██████████| 200/200 [00:07<00:00, 25.79it/s]
# 2025-09-20 01:25:28.423 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3829 test 0.3816 metric ['0.8658']
# 100%|██████████| 200/200 [00:07<00:00, 25.24it/s]
# 2025-09-20 01:25:37.736 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3617 test 0.3238 metric ['0.8788']
# 100%|██████████| 200/200 [00:08<00:00, 23.29it/s]
# 2025-09-20 01:25:48.000 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3050 test 0.2988 metric ['0.8938']
# 100%|██████████| 200/200 [00:09<00:00, 20.43it/s]
# 2025-09-20 01:25:59.543 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2942 test 0.3189 metric ['0.8875']
# 2025-09-20 01:25:59.544 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.2988, current loss 0.3189.Counter 1/10.
# 100%|██████████| 6/6 [01:00<00:00, 10.04s/it]
# 2025-09-20 01:25:59.561 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-012559
# 2025-09-20 01:25:59.563 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:09<00:00, 21.67it/s]
# 2025-09-20 01:26:10.271 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8454 test 0.5507 metric ['0.8100']
# 100%|██████████| 200/200 [00:09<00:00, 21.75it/s]
# 2025-09-20 01:26:21.052 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4691 test 0.3980 metric ['0.8575']
# 100%|██████████| 200/200 [00:09<00:00, 21.57it/s]
# 2025-09-20 01:26:31.948 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3964 test 0.3643 metric ['0.8734']
# 100%|██████████| 200/200 [00:09<00:00, 21.42it/s]
# 2025-09-20 01:26:42.848 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3483 test 0.3643 metric ['0.8669']
# 100%|██████████| 200/200 [00:09<00:00, 20.80it/s]
# 2025-09-20 01:26:53.933 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3354 test 0.3555 metric ['0.8712']
# 100%|██████████| 200/200 [00:08<00:00, 24.73it/s]
# 2025-09-20 01:27:03.315 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3121 test 0.3060 metric ['0.8861']
# 100%|██████████| 6/6 [01:03<00:00, 10.62s/it]
# 2025-09-20 01:27:03.329 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-012703
# 2025-09-20 01:27:03.331 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:07<00:00, 26.48it/s]
# 2025-09-20 01:27:12.578 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.7883 test 0.4949 metric ['0.8234']
# 100%|██████████| 200/200 [00:09<00:00, 22.08it/s]
# 2025-09-20 01:27:22.956 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4448 test 0.4284 metric ['0.8445']
# 100%|██████████| 200/200 [00:08<00:00, 23.24it/s]
# 2025-09-20 01:27:32.908 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3963 test 0.3642 metric ['0.8678']
# 100%|██████████| 200/200 [00:09<00:00, 20.90it/s]
# 2025-09-20 01:27:44.145 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3672 test 0.3365 metric ['0.8778']
# 100%|██████████| 200/200 [00:08<00:00, 23.06it/s]
# 2025-09-20 01:27:54.382 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3364 test 0.3245 metric ['0.8802']
# 100%|██████████| 200/200 [00:09<00:00, 20.55it/s]
# 2025-09-20 01:28:05.691 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3317 test 0.3172 metric ['0.8822']
# 100%|██████████| 6/6 [01:02<00:00, 10.39s/it]
# 2025-09-20 01:28:05.702 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-012805
# 2025-09-20 01:28:05.703 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:09<00:00, 21.24it/s]
# 2025-09-20 01:28:16.620 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8327 test 0.5473 metric ['0.8033']
# 100%|██████████| 200/200 [00:09<00:00, 21.60it/s]
# 2025-09-20 01:28:27.226 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4751 test 0.4183 metric ['0.8430']
# 100%|██████████| 200/200 [00:08<00:00, 23.66it/s]
# 2025-09-20 01:28:36.927 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4102 test 0.3539 metric ['0.8727']
# 100%|██████████| 200/200 [00:07<00:00, 25.73it/s]
# 2025-09-20 01:28:46.022 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3532 test 0.3365 metric ['0.8791']
# 100%|██████████| 200/200 [00:07<00:00, 25.75it/s]
# 2025-09-20 01:28:55.111 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3414 test 0.3300 metric ['0.8814']
# 100%|██████████| 200/200 [00:09<00:00, 21.20it/s]
# 2025-09-20 01:29:06.074 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3116 test 0.3155 metric ['0.8894']
# 100%|██████████| 6/6 [01:00<00:00, 10.06s/it]
# 2025-09-20 01:29:06.086 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-012906
# 2025-09-20 01:29:06.088 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:09<00:00, 21.85it/s]
# 2025-09-20 01:29:16.919 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8406 test 0.5304 metric ['0.8067']
# 100%|██████████| 200/200 [00:08<00:00, 23.88it/s]
# 2025-09-20 01:29:26.765 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4673 test 0.4235 metric ['0.8458']
# 100%|██████████| 200/200 [00:08<00:00, 22.49it/s]
# 2025-09-20 01:29:37.007 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3963 test 0.3966 metric ['0.8539']
# 100%|██████████| 200/200 [00:07<00:00, 25.89it/s]
# 2025-09-20 01:29:46.064 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3635 test 0.4143 metric ['0.8545']
# 2025-09-20 01:29:46.065 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3966, current loss 0.4143.Counter 1/10.
# 100%|██████████| 200/200 [00:07<00:00, 26.97it/s]
# 2025-09-20 01:29:54.796 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3294 test 0.3368 metric ['0.8759']
# 100%|██████████| 200/200 [00:07<00:00, 25.16it/s]
# 2025-09-20 01:30:04.538 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3291 test 0.3344 metric ['0.8719']
# 100%|██████████| 6/6 [00:58<00:00,  9.74s/it]
# 2025-09-20 01:30:04.555 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-013004
# 2025-09-20 01:30:04.558 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:08<00:00, 22.23it/s]
# 2025-09-20 01:30:15.182 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8446 test 0.5019 metric ['0.8137']
# 100%|██████████| 200/200 [00:08<00:00, 22.28it/s]
# 2025-09-20 01:30:25.688 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4720 test 0.4346 metric ['0.8309']
# 100%|██████████| 200/200 [00:09<00:00, 21.85it/s]
# 2025-09-20 01:30:36.292 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4025 test 0.3904 metric ['0.8564']
# 100%|██████████| 200/200 [00:08<00:00, 22.28it/s]
# 2025-09-20 01:30:46.666 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3692 test 0.3445 metric ['0.8741']
# 100%|██████████| 200/200 [00:09<00:00, 21.98it/s]
# 2025-09-20 01:30:57.366 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3406 test 0.3254 metric ['0.8781']
# 100%|██████████| 200/200 [00:08<00:00, 23.98it/s]
# 2025-09-20 01:31:06.972 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3180 test 0.3213 metric ['0.8838']
# 100%|██████████| 6/6 [01:02<00:00, 10.40s/it]
# 2025-09-20 01:31:06.984 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-013106
# 2025-09-20 01:31:06.985 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:08<00:00, 24.19it/s]
# 2025-09-20 01:31:16.611 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0505 test 0.5816 metric ['0.7919']
# 100%|██████████| 200/200 [00:07<00:00, 25.09it/s]
# 2025-09-20 01:31:26.121 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5744 test 0.4962 metric ['0.8220']
# 100%|██████████| 200/200 [00:10<00:00, 19.87it/s]
# 2025-09-20 01:31:37.728 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4757 test 0.4194 metric ['0.8597']
# 100%|██████████| 200/200 [00:09<00:00, 21.72it/s]
# 2025-09-20 01:31:48.372 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4355 test 0.3936 metric ['0.8622']
# 100%|██████████| 200/200 [00:09<00:00, 21.67it/s]
# 2025-09-20 01:31:59.226 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4029 test 0.3827 metric ['0.8661']
# 100%|██████████| 200/200 [00:10<00:00, 19.92it/s]
# 2025-09-20 01:32:10.948 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3771 test 0.3256 metric ['0.8831']
# 100%|██████████| 6/6 [01:03<00:00, 10.65s/it]
# 2025-09-20 01:32:10.963 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-013210
# 2025-09-20 01:32:10.965 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:09<00:00, 20.91it/s]
# 2025-09-20 01:32:22.365 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0554 test 0.5983 metric ['0.7766']
# 100%|██████████| 200/200 [00:08<00:00, 24.01it/s]
# 2025-09-20 01:32:32.098 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5745 test 0.4909 metric ['0.8222']
# 100%|██████████| 200/200 [00:07<00:00, 25.26it/s]
# 2025-09-20 01:32:41.429 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4859 test 0.4373 metric ['0.8431']
# 100%|██████████| 200/200 [00:08<00:00, 23.86it/s]
# 2025-09-20 01:32:51.250 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4542 test 0.3840 metric ['0.8614']
# 100%|██████████| 200/200 [00:09<00:00, 21.44it/s]
# 2025-09-20 01:33:02.061 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4043 test 0.3827 metric ['0.8619']
# 100%|██████████| 200/200 [00:08<00:00, 22.27it/s]
# 2025-09-20 01:33:12.718 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3836 test 0.3213 metric ['0.8842']
# 100%|██████████| 6/6 [01:01<00:00, 10.28s/it]
# 2025-09-20 01:33:12.736 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-013312
# 2025-09-20 01:33:12.738 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:09<00:00, 21.21it/s]
# 2025-09-20 01:33:23.710 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0825 test 0.5887 metric ['0.7834']
# 100%|██████████| 200/200 [00:09<00:00, 21.10it/s]
# 2025-09-20 01:33:34.633 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5631 test 0.4301 metric ['0.8477']
# 100%|██████████| 200/200 [00:08<00:00, 24.51it/s]
# 2025-09-20 01:33:44.086 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4672 test 0.4091 metric ['0.8517']
# 100%|██████████| 200/200 [00:08<00:00, 24.87it/s]
# 2025-09-20 01:33:53.413 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4269 test 0.3721 metric ['0.8670']
# 100%|██████████| 200/200 [00:08<00:00, 22.75it/s]
# 2025-09-20 01:34:03.602 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3999 test 0.3515 metric ['0.8712']
# 100%|██████████| 200/200 [00:09<00:00, 21.00it/s]
# 2025-09-20 01:34:14.521 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3757 test 0.3266 metric ['0.8828']
# 100%|██████████| 6/6 [01:01<00:00, 10.29s/it]
# 2025-09-20 01:34:14.531 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250920-013414
# 2025-09-20 01:34:14.532 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:08<00:00, 24.24it/s]
# 2025-09-20 01:34:24.295 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0461 test 0.5656 metric ['0.7972']
# 100%|██████████| 200/200 [00:08<00:00, 23.62it/s]
# 2025-09-20 01:34:34.102 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5590 test 0.4629 metric ['0.8322']
# 100%|██████████| 200/200 [00:07<00:00, 25.76it/s]
# 2025-09-20 01:34:43.187 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4769 test 0.4261 metric ['0.8394']
# 100%|██████████| 200/200 [00:07<00:00, 26.71it/s]
# 2025-09-20 01:34:52.014 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4262 test 0.3645 metric ['0.8694']
# 100%|██████████| 200/200 [00:07<00:00, 26.06it/s]
# 2025-09-20 01:35:01.097 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3868 test 0.3464 metric ['0.8730']
# 100%|██████████| 200/200 [00:08<00:00, 23.55it/s]
# 2025-09-20 01:35:11.047 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3851 test 0.3438 metric ['0.8816']
# 100%|██████████| 6/6 [00:56<00:00,  9.41s/it]
