# %%
from pathlib import Path
import torch
import torch.nn as nn
from loguru import logger
import warnings
warnings.simplefilter("ignore", UserWarning)

# %% [markdown]
# Let's use the mads_datasets package (see [github](https://github.com/raoulg/mads_datasets) for more details) which I created for these lessons to give everyone easy access to the datasets we use for training.

# %%
from mads_datasets import DatasetFactoryProvider, DatasetType
from mltrainer.preprocessors import BasePreprocessor

for dataset in DatasetType:
    print(dataset)
# Out:
# DatasetType.FLOWERS
# DatasetType.IMDB
# DatasetType.GESTURES
# DatasetType.FASHION
# DatasetType.SUNSPOTS
# DatasetType.IRIS
# DatasetType.PENGUINS
# DatasetType.FAVORITA
# DatasetType.SECURE

# %% [markdown]
# There are a few datasets. For images, we can use FLOWERS (~3000 photos of flowers in 5 categories) and FASHION (60k fashion icons 28x28 pixels big).

# %% [markdown]
# Lets start with our good'ol MNIST.

# %%
fashionfactory = DatasetFactoryProvider.create_factory(DatasetType.FASHION)
batchsize = 64
preprocessor = BasePreprocessor()
streamers = fashionfactory.create_datastreamer(batchsize=batchsize, preprocessor=preprocessor)
train = streamers["train"]
valid = streamers["valid"]
trainstreamer = train.stream()
validstreamer = valid.stream()
# Out:
# 2025-09-22 13:10:25.211 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at C:\Users\j.nagelhout\.cache\mads_datasets\fashionmnist
# 2025-09-22 13:10:25.213 | INFO     | mads_datasets.base:download_data:124 - File already exists at C:\Users\j.nagelhout\.cache\mads_datasets\fashionmnist\fashionmnist.pt

# %% [markdown]
# We can obtain an item:

# %%
x, y = next(iter(trainstreamer))
x.shape, y.shape
# Out:
# (torch.Size([64, 1, 28, 28]), torch.Size([64]))

# %% [markdown]
# The image follows the channels-first convention: (channel, width, height). The label is an integer.
#
# Let's re-use the model we had:

# %%
import torch
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
    print("Using MPS")
elif torch.cuda.is_available():
    device = "cuda:0"
    print("using cuda")
else:
    device = "cpu"
    print("using cpu")
# Out:
# using cpu

# %%
from torch import nn
print(f"Using {device} device")

# Define model
class CNN(nn.Module):
    def __init__(self, filters, units1, units2, input_size=(32, 1, 28, 28)):
        super().__init__()
        self.in_channels = input_size[1]
        self.input_size = input_size
        self.filters = filters
        self.units1 = units1
        self.units2 = units2

        self.convolutions = nn.Sequential(
            nn.Conv2d(self.in_channels, filters, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(filters, filters, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )

        activation_map_size = self._conv_test(input_size)
        logger.info(f"Aggregating activationmap with size {activation_map_size}")
        self.agg = nn.AvgPool2d(activation_map_size)

        self.dense = nn.Sequential(
            nn.Flatten(),
            nn.Linear(filters, units1),
            nn.ReLU(),
            nn.Linear(units1, units2),
            nn.ReLU(),
            nn.Linear(units2, 10)
        )

    def _conv_test(self, input_size = (32, 1, 28, 28)):
        x = torch.ones(input_size)
        x = self.convolutions(x)
        return x.shape[-2:]

    def forward(self, x):
        x = self.convolutions(x)
        x = self.agg(x)
        logits = self.dense(x)
        return logits

model = CNN(filters=32, units1=128, units2=64).to("cpu")
# Out:
# 2025-09-22 13:10:42.405 | INFO     | __main__:__init__:27 - Aggregating activationmap with size torch.Size([2, 2])
# Using cpu device

# %%
from mltrainer.imagemodels import CNNConfig, CNNblocks

# %%
config = CNNConfig(
    matrixshape = (28, 28), # every image is 28x28
    batchsize = batchsize,
    input_channels = 1, # we have black and white images, so only one channel
    hidden = 32, # number of filters
    kernel_size = 3, # kernel size of the convolution
    maxpool = 3, # kernel size of the maxpool
    num_layers = 4, # we will stack 4 Convolutional blocks, each with two Conv2d layers
    num_classes = 10,
)

# %%
model = CNNblocks(config)
model.config
# Out:
# Calculated matrix size: 9
# Caluclated flatten size: 288
# {'matrixshape': (28, 28),
#  'batchsize': 64,
#  'input_channels': 1,
#  'hidden': 32,
#  'kernel_size': 3,
#  'maxpool': 3,
#  'num_layers': 4,
#  'num_classes': 10}

# %%
from torchinfo import summary
summary(model, input_size=(32, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNNblocks                                [32, 10]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─ConvBlock: 2-1                    [32, 32, 28, 28]          --
# │    │    └─Sequential: 3-1              [32, 32, 28, 28]          9,568
# │    └─ConvBlock: 2-2                    [32, 32, 28, 28]          --
# │    │    └─Sequential: 3-2              [32, 32, 28, 28]          18,496
# │    └─ReLU: 2-3                         [32, 32, 28, 28]          --
# │    └─MaxPool2d: 2-4                    [32, 32, 9, 9]            --
# │    └─ConvBlock: 2-5                    [32, 32, 9, 9]            --
# │    │    └─Sequential: 3-3              [32, 32, 9, 9]            18,496
# │    └─ReLU: 2-6                         [32, 32, 9, 9]            --
# │    └─ConvBlock: 2-7                    [32, 32, 9, 9]            --
# │    │    └─Sequential: 3-4              [32, 32, 9, 9]            18,496
# │    └─ReLU: 2-8                         [32, 32, 9, 9]            --
# │    └─MaxPool2d: 2-9                    [32, 32, 3, 3]            --
# │    └─ConvBlock: 2-10                   [32, 32, 3, 3]            --
# │    │    └─Sequential: 3-5              [32, 32, 3, 3]            18,496
# │    └─ReLU: 2-11                        [32, 32, 3, 3]            --
# ├─Sequential: 1-2                        [32, 10]                  --
# │    └─Flatten: 2-12                     [32, 288]                 --
# │    └─Linear: 2-13                      [32, 32]                  9,248
# │    └─ReLU: 2-14                        [32, 32]                  --
# │    └─Linear: 2-15                      [32, 10]                  330
# ==========================================================================================
# Total params: 93,130
# Trainable params: 93,130
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 805.59
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 28.50
# Params size (MB): 0.37
# Estimated Total Size (MB): 28.98
# ==========================================================================================

# %% [markdown]
# And set up the optimizer, loss and accuracy.

# %%
import torch.optim as optim
from mltrainer import metrics
optimizer = optim.Adam
loss_fn = torch.nn.CrossEntropyLoss()
accuracy = metrics.Accuracy()

# %%
yhat = model(x.to("cpu"))
accuracy(y.to("cpu"), yhat)
# Out:
# 0.046875

# %%
from mltrainer import metrics, Trainer, TrainerSettings, ReportTypes
settings = TrainerSettings(
    epochs=3,
    metrics=[accuracy],
    logdir="demo",
    train_steps=100,
    valid_steps=100,
    reporttypes=[ReportTypes.TOML],
)

# %%
trainer = Trainer(
            model=model,
            settings=settings,
            loss_fn=loss_fn,
            optimizer=optimizer,
            traindataloader=trainstreamer,
            validdataloader=validstreamer,
            scheduler=optim.lr_scheduler.ReduceLROnPlateau,
            device=device,
        )
trainer.loop()
# Out:
# 2025-09-22 13:11:14.467 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to demo\20250922-131114
# 2025-09-22 13:11:17.098 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 100/100 [00:11<00:00,  8.82it/s]
# 2025-09-22 13:11:31.633 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.7767 test 0.9674 metric ['0.6205']
# 100%|██████████| 100/100 [00:10<00:00,  9.54it/s]
# 2025-09-22 13:11:45.272 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.8353 test 0.8023 metric ['0.7095']
# 100%|██████████| 100/100 [00:08<00:00, 12.08it/s]
# 2025-09-22 13:11:55.252 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.7219 test 0.6720 metric ['0.7434']
# 100%|██████████| 3/3 [00:38<00:00, 12.72s/it]

# %% [markdown]
# # MLflow
# MLflow is an open-source platform designed to manage the entire Machine Learning (ML) lifecycle, including experimentation, reproducibility, deployment, and governance. It provides a set of APIs and tools to streamline ML workflows, making it easier to track experiments, package code, manage model versions, and deploy models.
#
# Reasons to use MLflow over TensorBoard, gin-config, or Ray:
#
# - End-to-end ML lifecycle management: While TensorBoard focuses on visualizing model training metrics and gin-config on hyperparameter configuration, MLflow covers a broader range of tasks, such as experiment tracking, model packaging, and deployment.
#
# - Framework agnostic: MLflow is not tied to a specific ML framework, making it suitable for projects using different libraries or even multiple libraries.
#
# - Model Registry: MLflow provides a centralized model registry, allowing you to version, track, and manage your models, which is not available in TensorBoard or gin-config.
#
# - Deployment support: MLflow facilitates model deployment to various platforms, such as local, cloud, or Kubernetes environments, whereas TensorBoard and gin-config are not built for deployment tasks.
#
# - Integration with other tools: MLflow integrates with popular tools and platforms like Databricks, AWS, and Azure, making it easy to incorporate into existing workflows.
#
# However, the choice between MLflow and other tools like TensorBoard, gin-config, or Ray depends on your specific use case and the scope of the ML workflow you want to manage.

# %%
experiment_path = "mlflow_test"

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment(experiment_path)
# Out:
# 2025/09/22 13:11:57 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/09/22 13:11:57 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='file:c:/GitHub/portfolio-JN/2-hypertuning-mlflow/mlruns/1', creation_time=1758304515015, experiment_id='1', last_update_time=1758304515015, lifecycle_stage='active', name='mlflow_test', tags={}>

# %% [markdown]
# In the code above, we set the MLflow tracking URI to a local SQLite database file. This is done to configure the storage location for MLflow's experiment tracking data, such as metrics, parameters, and artifacts. By specifying a SQLite database, we enable a lightweight and easy-to-use storage solution for tracking the experiments and their associated information.
#
# The line mlflow.set_experiment("mnist_convolutions") sets the active MLflow experiment to "mnist_convolutions". This is useful for organizing and grouping your runs, as it allows you to associate the upcoming ML training runs with a specific experiment name, making it easier to search, compare, and analyze the results later.

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %% [markdown]
# We import functions and classes from the hyperopt library to perform hyperparameter optimization. This library helps us find the best hyperparameter values for our machine learning model by searching through a defined search space and using optimization algorithms like Tree-structured Parzen Estimator (TPE). The goal is to improve our model's performance by tuning its hyperparameters.
#
# Advantages of TPE:
#
# - Model-based approach: TPE is a Bayesian optimization method that models the objective function as a probability distribution. It learns from previous evaluations to decide which points in the search space to explore next, making it more efficient in finding optimal hyperparameters.
#
# - Exploration-exploitation trade-off: TPE balances the trade-off between exploration (searching in new regions of the search space) and exploitation (refining around the current best points). This can lead to better results in problems with complex search spaces.
#
# - Continuous hyperparameter optimization: TPE can handle continuous hyperparameters more naturally, as it builds a probability model to estimate the performance for any given point in the search space.
#
# Lets set up an objective function and start logging some usefull things we might want to track:

# %%
modeldir = Path("models").resolve()
if not modeldir.exists():
    modeldir.mkdir()
    print(f"Created {modeldir}")

# %%
import torch.optim as optim
from mltrainer import metrics, Trainer, TrainerSettings, ReportTypes
from datetime import datetime

# Define the hyperparameter search space
settings = TrainerSettings(
    epochs=3,
    metrics=[accuracy],
    logdir=modeldir,
    train_steps=100,
    valid_steps=100,
    reporttypes=[ReportTypes.MLFLOW, ReportTypes.TOML],
)


# Define the objective function for hyperparameter optimization
def objective(params):
    # Start a new MLflow run for tracking the experiment
    with mlflow.start_run():
        # Set MLflow tags to record metadata about the model and developer
        mlflow.set_tag("model", "convnet")
        mlflow.set_tag("dev", "raoul")
        # Log hyperparameters to MLflow
        mlflow.log_params(params)
        mlflow.log_param("batchsize", f"{batchsize}")


        # Initialize the optimizer, loss function, and accuracy metric
        optimizer = optim.Adam
        loss_fn = torch.nn.CrossEntropyLoss()
        accuracy = metrics.Accuracy()
        config = CNNConfig(
            matrixshape = (28, 28), # every image is 28x28
            batchsize = batchsize,
            input_channels = 1, # we have black and white images, so only one channel
            hidden = params["filters"], # number of filters
            kernel_size = 3, # kernel size of the convolution
            maxpool = 3, # kernel size of the maxpool
            num_layers = 4, # we will stack 4 Convolutional blocks, each with two Conv2d layers
            num_classes = 10,
        )

        # Instantiate the CNN model with the given hyperparameters
        model = CNNblocks(config)
        # Train the model using a custom train loop
        trainer = Trainer(
            model=model,
            settings=settings,
            loss_fn=loss_fn,
            optimizer=optimizer,
            traindataloader=trainstreamer,
            validdataloader=validstreamer,
            scheduler=optim.lr_scheduler.ReduceLROnPlateau,
            device=device,
        )
        trainer.loop()

        # Save the trained model with a timestamp
        tag = datetime.now().strftime("%Y%m%d-%H%M")
        modelpath = modeldir / (tag + "model.pt")
        torch.save(model, modelpath)

        # Log the saved model as an artifact in MLflow
        mlflow.log_artifact(local_path=modelpath, artifact_path="pytorch_models")
        return {'loss' : trainer.test_loss, 'status': STATUS_OK}

# %% [markdown]
# See https://hyperopt.github.io/hyperopt/getting-started/search_spaces/ for more information about searchspaces for hyperopt

# %%
search_space = {
    'filters' : scope.int(hp.quniform('filters', 16, 128, 8)),
    'kernel_size' : scope.int(hp.quniform('kernel_size', 2, 5, 1)),
    'num_layers' : scope.int(hp.quniform('num_layers', 1, 10, 1)),
}

# %% [markdown]
# We define a search space for hyperparameter optimization using Hyperopt. The search space specifies the range and distribution of hyperparameters to explore during the optimization process. This is crucial for finding the optimal set of hyperparameters that yield the best performance for the machine learning model. The search space defined here includes the number of filters in the convolutional layers, and the number of units in two fully connected layers, allowing Hyperopt to find the best combination within the given ranges.
#
#
# Now, finally, let us perform the hyperparameter search using the fmin function from hyperopt. The function takes the following arguments:
#
# - `fn=objective`: The objective function to minimize, which is defined earlier to train the model and return the test loss.
# - `space=search_space`: The search space defined earlier, containing the range of hyperparameters to explore.
# - `algo=tpe.suggest`: The optimization algorithm to use, in this case, the Tree-structured Parzen Estimator (TPE) method.
# - `max_evals=10`: The maximum number of function evaluations, i.e., the maximum number of hyperparameter combinations to try.
# - `trials=Trials()`: A Trials object to store the results of each evaluation.
#
# The fmin function searches for the best hyperparameters within the given search space using the TPE algorithm, aiming to minimize the objective function (test loss). Once the optimization process is completed, the best hyperparameters found are stored in the best_result variable.

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=3,
    trials=Trials()
)
# Out:
# Calculated matrix size: 9
# Caluclated flatten size: 360
#   0%|          | 0/3 [00:00<?, ?trial/s, best loss=?]
# 2025-09-22 13:12:07.633 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to C:\GitHub\portfolio-JN\2-hypertuning-mlflow\models\20250922-131207
# 2025-09-22 13:12:07.635 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:17,  5.77it/s]
#   2%|2         | 2/100 [00:00<00:14,  6.57it/s]
#   3%|3         | 3/100 [00:00<00:13,  7.01it/s]
#   4%|4         | 4/100 [00:00<00:13,  7.08it/s]
#   5%|5         | 5/100 [00:00<00:13,  7.03it/s]
#   6%|6         | 6/100 [00:00<00:12,  7.32it/s]
#   7%|7         | 7/100 [00:00<00:12,  7.39it/s]
#   8%|8         | 8/100 [00:01<00:12,  7.24it/s]
#   9%|9         | 9/100 [00:01<00:12,  7.27it/s]
#  10%|#         | 10/100 [00:01<00:11,  7.59it/s]
#  11%|#1        | 11/100 [00:01<00:11,  8.02it/s]
#  12%|#2        | 12/100 [00:01<00:10,  8.28it/s]
#  13%|#3        | 13/100 [00:01<00:10,  8.41it/s]
#  14%|#4        | 14/100 [00:01<00:10,  8.42it/s]
#  15%|#5        | 15/100 [00:01<00:10,  8.42it/s]
#  16%|#6        | 16/100 [00:02<00:10,  8.20it/s]
#  17%|#7        | 17/100 [00:02<00:10,  8.26it/s]
#  18%|#8        | 18/100 [00:02<00:09,  8.31it/s]
#  19%|#9        | 19/100 [00:02<00:09,  8.49it/s]
#  20%|##        | 20/100 [00:02<00:09,  8.21it/s]
#  21%|##1       | 21/100 [00:02<00:09,  8.50it/s]
#  22%|##2       | 22/100 [00:02<00:08,  8.75it/s]
#  23%|##3       | 23/100 [00:02<00:08,  8.80it/s]
#  24%|##4       | 24/100 [00:03<00:08,  8.78it/s]
#  25%|##5       | 25/100 [00:03<00:08,  8.71it/s]
#  26%|##6       | 26/100 [00:03<00:08,  8.43it/s]
#  27%|##7       | 27/100 [00:03<00:09,  7.93it/s]
#  28%|##8       | 28/100 [00:03<00:09,  7.76it/s]
#  29%|##9       | 29/100 [00:03<00:08,  8.00it/s]
#  30%|###       | 30/100 [00:03<00:08,  8.25it/s]
#  31%|###1      | 31/100 [00:03<00:08,  8.34it/s]
#  32%|###2      | 32/100 [00:03<00:08,  8.32it/s]
#  33%|###3      | 33/100 [00:04<00:08,  7.89it/s]
#  34%|###4      | 34/100 [00:04<00:08,  7.82it/s]
#  35%|###5      | 35/100 [00:04<00:08,  7.69it/s]
#  36%|###6      | 36/100 [00:04<00:08,  7.79it/s]
#  37%|###7      | 37/100 [00:04<00:07,  7.88it/s]
#  38%|###8      | 38/100 [00:04<00:07,  7.90it/s]
#  39%|###9      | 39/100 [00:04<00:07,  8.22it/s]
#  40%|####      | 40/100 [00:05<00:07,  8.21it/s]
#  41%|####1     | 41/100 [00:05<00:07,  8.21it/s]
#  42%|####2     | 42/100 [00:05<00:07,  7.87it/s]
#  43%|####3     | 43/100 [00:05<00:07,  7.37it/s]
#  44%|####4     | 44/100 [00:05<00:07,  7.37it/s]
#  45%|####5     | 45/100 [00:05<00:07,  7.07it/s]
#  46%|####6     | 46/100 [00:05<00:07,  7.36it/s]
#  47%|####6     | 47/100 [00:05<00:06,  7.78it/s]
#  48%|####8     | 48/100 [00:06<00:06,  7.65it/s]
#  49%|####9     | 49/100 [00:06<00:06,  7.90it/s]
#  50%|#####     | 50/100 [00:06<00:05,  8.36it/s]
#  52%|#####2    | 52/100 [00:06<00:05,  9.04it/s]
#  53%|#####3    | 53/100 [00:06<00:05,  8.99it/s]
#  54%|#####4    | 54/100 [00:06<00:05,  8.86it/s]
#  55%|#####5    | 55/100 [00:06<00:05,  8.76it/s]
#  56%|#####6    | 56/100 [00:06<00:05,  8.64it/s]
#  57%|#####6    | 57/100 [00:07<00:04,  8.65it/s]
#  58%|#####8    | 58/100 [00:07<00:04,  8.68it/s]
#  59%|#####8    | 59/100 [00:07<00:04,  8.35it/s]
#  60%|######    | 60/100 [00:07<00:04,  8.57it/s]
#  61%|######1   | 61/100 [00:07<00:04,  8.88it/s]
#  62%|######2   | 62/100 [00:07<00:04,  8.73it/s]
#  63%|######3   | 63/100 [00:07<00:04,  8.58it/s]
#  64%|######4   | 64/100 [00:07<00:04,  8.45it/s]
#  65%|######5   | 65/100 [00:08<00:04,  8.33it/s]
#  66%|######6   | 66/100 [00:08<00:04,  7.87it/s]
#  67%|######7   | 67/100 [00:08<00:04,  7.53it/s]
#  68%|######8   | 68/100 [00:08<00:04,  7.83it/s]
#  69%|######9   | 69/100 [00:08<00:03,  7.88it/s]
#  70%|#######   | 70/100 [00:08<00:04,  7.30it/s]
#  71%|#######1  | 71/100 [00:08<00:03,  7.51it/s]
#  72%|#######2  | 72/100 [00:08<00:03,  7.63it/s]
#  73%|#######3  | 73/100 [00:09<00:03,  7.48it/s]
#  74%|#######4  | 74/100 [00:09<00:03,  7.11it/s]
#  75%|#######5  | 75/100 [00:09<00:03,  7.05it/s]
#  76%|#######6  | 76/100 [00:09<00:03,  6.86it/s]
#  77%|#######7  | 77/100 [00:09<00:03,  6.91it/s]
#  78%|#######8  | 78/100 [00:09<00:03,  7.05it/s]
#  79%|#######9  | 79/100 [00:09<00:02,  7.29it/s]
#  81%|########1 | 81/100 [00:10<00:02,  8.82it/s]
#  83%|########2 | 83/100 [00:10<00:01,  9.73it/s]
#  85%|########5 | 85/100 [00:10<00:01, 10.33it/s]
#  87%|########7 | 87/100 [00:10<00:01, 10.92it/s]
#  89%|########9 | 89/100 [00:10<00:00, 11.01it/s]
#  91%|#########1| 91/100 [00:11<00:00, 11.22it/s]
#  93%|#########3| 93/100 [00:11<00:00, 11.43it/s]
#  95%|#########5| 95/100 [00:11<00:00, 11.63it/s]
#  97%|#########7| 97/100 [00:11<00:00, 12.14it/s]
#  99%|#########9| 99/100 [00:11<00:00, 12.25it/s]
# 100%|##########| 100/100 [00:11<00:00,  8.52it/s]
# 2025-09-22 13:12:22.004 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.5843 test 0.9365 metric ['0.6481']
#  33%|###3      | 1/3 [00:14<00:28, 14.36s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:24,  4.09it/s]
#   2%|2         | 2/100 [00:00<00:17,  5.68it/s]
#   3%|3         | 3/100 [00:00<00:14,  6.70it/s]
#   4%|4         | 4/100 [00:00<00:12,  7.60it/s]
#   5%|5         | 5/100 [00:00<00:11,  7.98it/s]
#   6%|6         | 6/100 [00:00<00:11,  8.35it/s]
#   7%|7         | 7/100 [00:00<00:10,  8.71it/s]
#   8%|8         | 8/100 [00:01<00:10,  8.83it/s]
#   9%|9         | 9/100 [00:01<00:10,  8.82it/s]
#  10%|#         | 10/100 [00:01<00:10,  8.74it/s]
#  11%|#1        | 11/100 [00:01<00:10,  8.35it/s]
#  12%|#2        | 12/100 [00:01<00:10,  8.12it/s]
#  13%|#3        | 13/100 [00:01<00:10,  8.30it/s]
#  14%|#4        | 14/100 [00:01<00:09,  8.72it/s]
#  15%|#5        | 15/100 [00:01<00:09,  9.07it/s]
#  16%|#6        | 16/100 [00:01<00:09,  9.26it/s]
#  18%|#8        | 18/100 [00:02<00:08,  9.75it/s]
#  20%|##        | 20/100 [00:02<00:08,  9.73it/s]
#  21%|##1       | 21/100 [00:02<00:08,  9.02it/s]
#  22%|##2       | 22/100 [00:02<00:08,  8.91it/s]
#  23%|##3       | 23/100 [00:02<00:08,  9.05it/s]
#  24%|##4       | 24/100 [00:02<00:08,  8.58it/s]
#  25%|##5       | 25/100 [00:02<00:08,  8.44it/s]
#  26%|##6       | 26/100 [00:03<00:08,  8.48it/s]
#  27%|##7       | 27/100 [00:03<00:08,  8.70it/s]
#  28%|##8       | 28/100 [00:03<00:07,  9.01it/s]
#  29%|##9       | 29/100 [00:03<00:07,  9.25it/s]
#  30%|###       | 30/100 [00:03<00:07,  9.34it/s]
#  31%|###1      | 31/100 [00:03<00:07,  9.31it/s]
#  32%|###2      | 32/100 [00:03<00:07,  9.19it/s]
#  33%|###3      | 33/100 [00:03<00:07,  8.80it/s]
#  34%|###4      | 34/100 [00:03<00:07,  8.45it/s]
#  35%|###5      | 35/100 [00:04<00:07,  8.40it/s]
#  36%|###6      | 36/100 [00:04<00:07,  8.02it/s]
#  37%|###7      | 37/100 [00:04<00:08,  7.87it/s]
#  38%|###8      | 38/100 [00:04<00:07,  7.92it/s]
#  39%|###9      | 39/100 [00:04<00:07,  8.09it/s]
#  40%|####      | 40/100 [00:04<00:07,  8.33it/s]
#  41%|####1     | 41/100 [00:04<00:07,  8.11it/s]
#  42%|####2     | 42/100 [00:04<00:07,  7.89it/s]
#  43%|####3     | 43/100 [00:05<00:07,  7.65it/s]
#  44%|####4     | 44/100 [00:05<00:07,  7.73it/s]
#  45%|####5     | 45/100 [00:05<00:06,  8.10it/s]
#  46%|####6     | 46/100 [00:05<00:06,  8.31it/s]
#  47%|####6     | 47/100 [00:05<00:06,  8.31it/s]
#  48%|####8     | 48/100 [00:05<00:06,  8.37it/s]
#  49%|####9     | 49/100 [00:05<00:06,  8.08it/s]
#  50%|#####     | 50/100 [00:05<00:06,  7.97it/s]
#  51%|#####1    | 51/100 [00:06<00:06,  8.00it/s]
#  52%|#####2    | 52/100 [00:06<00:06,  7.98it/s]
#  53%|#####3    | 53/100 [00:06<00:05,  8.08it/s]
#  54%|#####4    | 54/100 [00:06<00:05,  8.17it/s]
#  55%|#####5    | 55/100 [00:06<00:05,  8.06it/s]
#  56%|#####6    | 56/100 [00:06<00:05,  7.88it/s]
#  57%|#####6    | 57/100 [00:06<00:05,  7.70it/s]
#  58%|#####8    | 58/100 [00:06<00:05,  7.82it/s]
#  59%|#####8    | 59/100 [00:07<00:05,  7.75it/s]
#  60%|######    | 60/100 [00:07<00:04,  8.20it/s]
#  61%|######1   | 61/100 [00:07<00:04,  8.36it/s]
#  62%|######2   | 62/100 [00:07<00:04,  8.01it/s]
#  63%|######3   | 63/100 [00:07<00:04,  8.01it/s]
#  64%|######4   | 64/100 [00:07<00:04,  8.26it/s]
#  65%|######5   | 65/100 [00:07<00:04,  8.15it/s]
#  66%|######6   | 66/100 [00:07<00:04,  8.21it/s]
#  67%|######7   | 67/100 [00:08<00:03,  8.29it/s]
#  68%|######8   | 68/100 [00:08<00:03,  8.26it/s]
#  69%|######9   | 69/100 [00:08<00:03,  8.15it/s]
#  70%|#######   | 70/100 [00:08<00:03,  8.08it/s]
#  71%|#######1  | 71/100 [00:08<00:03,  7.74it/s]
#  72%|#######2  | 72/100 [00:08<00:03,  7.42it/s]
#  73%|#######3  | 73/100 [00:08<00:03,  7.80it/s]
#  74%|#######4  | 74/100 [00:08<00:03,  8.11it/s]
#  75%|#######5  | 75/100 [00:09<00:03,  8.14it/s]
#  76%|#######6  | 76/100 [00:09<00:02,  8.25it/s]
#  77%|#######7  | 77/100 [00:09<00:02,  8.36it/s]
#  78%|#######8  | 78/100 [00:09<00:02,  8.17it/s]
#  79%|#######9  | 79/100 [00:09<00:02,  7.66it/s]
#  80%|########  | 80/100 [00:09<00:02,  7.96it/s]
#  81%|########1 | 81/100 [00:09<00:02,  8.08it/s]
#  82%|########2 | 82/100 [00:09<00:02,  8.03it/s]
#  83%|########2 | 83/100 [00:10<00:02,  8.04it/s]
#  84%|########4 | 84/100 [00:10<00:02,  7.83it/s]
#  85%|########5 | 85/100 [00:10<00:01,  7.86it/s]
#  86%|########6 | 86/100 [00:10<00:01,  7.96it/s]
#  87%|########7 | 87/100 [00:10<00:01,  8.11it/s]
#  88%|########8 | 88/100 [00:10<00:01,  8.39it/s]
#  89%|########9 | 89/100 [00:10<00:01,  8.49it/s]
#  90%|######### | 90/100 [00:10<00:01,  8.32it/s]
#  91%|#########1| 91/100 [00:11<00:01,  8.13it/s]
#  92%|#########2| 92/100 [00:11<00:00,  8.16it/s]
#  93%|#########3| 93/100 [00:11<00:00,  8.14it/s]
#  94%|#########3| 94/100 [00:11<00:00,  8.03it/s]
#  95%|#########5| 95/100 [00:11<00:00,  7.93it/s]
#  96%|#########6| 96/100 [00:11<00:00,  7.81it/s]
#  97%|#########7| 97/100 [00:11<00:00,  7.84it/s]
#  98%|#########8| 98/100 [00:11<00:00,  8.07it/s]
#  99%|#########9| 99/100 [00:12<00:00,  8.23it/s]
# 100%|##########| 100/100 [00:12<00:00,  8.13it/s]
# 100%|##########| 100/100 [00:12<00:00,  8.21it/s]
# 2025-09-22 13:12:37.932 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.8421 test 0.8169 metric ['0.6989']
#  67%|######6   | 2/3 [00:30<00:15, 15.28s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:35,  2.75it/s]
#   2%|2         | 2/100 [00:00<00:22,  4.33it/s]
#   3%|3         | 3/100 [00:00<00:18,  5.36it/s]
#   4%|4         | 4/100 [00:00<00:16,  6.00it/s]
#   5%|5         | 5/100 [00:00<00:14,  6.53it/s]
#   6%|6         | 6/100 [00:01<00:13,  7.16it/s]
#   7%|7         | 7/100 [00:01<00:12,  7.63it/s]
#   8%|8         | 8/100 [00:01<00:11,  7.89it/s]
#   9%|9         | 9/100 [00:01<00:11,  8.03it/s]
#  10%|#         | 10/100 [00:01<00:10,  8.43it/s]
#  12%|#2        | 12/100 [00:01<00:08, 10.12it/s]
#  14%|#4        | 14/100 [00:01<00:07, 11.88it/s]
#  16%|#6        | 16/100 [00:01<00:06, 13.05it/s]
#  18%|#8        | 18/100 [00:02<00:05, 13.69it/s]
#  20%|##        | 20/100 [00:02<00:05, 14.22it/s]
#  22%|##2       | 22/100 [00:02<00:05, 14.72it/s]
#  24%|##4       | 24/100 [00:02<00:05, 15.01it/s]
#  26%|##6       | 26/100 [00:02<00:04, 15.07it/s]
#  28%|##8       | 28/100 [00:02<00:05, 14.25it/s]
#  30%|###       | 30/100 [00:02<00:05, 13.72it/s]
#  32%|###2      | 32/100 [00:02<00:05, 13.37it/s]
#  34%|###4      | 34/100 [00:03<00:05, 12.51it/s]
#  36%|###6      | 36/100 [00:03<00:05, 12.59it/s]
#  38%|###8      | 38/100 [00:03<00:04, 12.59it/s]
#  40%|####      | 40/100 [00:03<00:04, 12.99it/s]
#  42%|####2     | 42/100 [00:03<00:04, 13.77it/s]
#  44%|####4     | 44/100 [00:03<00:03, 14.32it/s]
#  46%|####6     | 46/100 [00:04<00:03, 14.61it/s]
#  48%|####8     | 48/100 [00:04<00:03, 14.78it/s]
#  50%|#####     | 50/100 [00:04<00:03, 14.76it/s]
#  52%|#####2    | 52/100 [00:04<00:03, 14.74it/s]
#  54%|#####4    | 54/100 [00:04<00:03, 14.90it/s]
#  56%|#####6    | 56/100 [00:04<00:02, 15.01it/s]
#  58%|#####8    | 58/100 [00:04<00:02, 15.39it/s]
#  60%|######    | 60/100 [00:04<00:02, 15.56it/s]
#  62%|######2   | 62/100 [00:05<00:02, 15.22it/s]
#  64%|######4   | 64/100 [00:05<00:02, 14.91it/s]
#  66%|######6   | 66/100 [00:05<00:02, 15.18it/s]
#  68%|######8   | 68/100 [00:05<00:02, 15.36it/s]
#  70%|#######   | 70/100 [00:05<00:02, 14.63it/s]
#  72%|#######2  | 72/100 [00:05<00:01, 14.78it/s]
#  74%|#######4  | 74/100 [00:05<00:01, 15.02it/s]
#  76%|#######6  | 76/100 [00:06<00:01, 15.21it/s]
#  78%|#######8  | 78/100 [00:06<00:01, 15.18it/s]
#  80%|########  | 80/100 [00:06<00:01, 15.54it/s]
#  82%|########2 | 82/100 [00:06<00:01, 15.71it/s]
#  84%|########4 | 84/100 [00:06<00:01, 15.79it/s]
#  86%|########6 | 86/100 [00:06<00:00, 15.66it/s]
#  88%|########8 | 88/100 [00:06<00:00, 15.67it/s]
#  90%|######### | 90/100 [00:06<00:00, 15.86it/s]
#  92%|#########2| 92/100 [00:07<00:00, 15.54it/s]
#  94%|#########3| 94/100 [00:07<00:00, 15.52it/s]
#  96%|#########6| 96/100 [00:07<00:00, 15.55it/s]
#  98%|#########8| 98/100 [00:07<00:00, 15.61it/s]
# 100%|##########| 100/100 [00:07<00:00, 15.71it/s]
# 100%|##########| 100/100 [00:07<00:00, 13.28it/s]
# 2025-09-22 13:12:47.742 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.7364 test 0.6821 metric ['0.7416']
# 100%|##########| 3/3 [00:40<00:00, 12.78s/it]
# 100%|##########| 3/3 [00:40<00:00, 13.37s/it]
# Calculated matrix size: 9
# Caluclated flatten size: 360
#  33%|███▎      | 1/3 [00:40<01:21, 40.52s/trial, best loss: 0.6821397212147713]
# 2025-09-22 13:12:47.834 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to C:\GitHub\portfolio-JN\2-hypertuning-mlflow\models\20250922-131247
# 2025-09-22 13:12:47.836 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:25,  3.86it/s]
#   2%|2         | 2/100 [00:00<00:18,  5.24it/s]
#   3%|3         | 3/100 [00:00<00:14,  6.47it/s]
#   4%|4         | 4/100 [00:00<00:13,  7.22it/s]
#   5%|5         | 5/100 [00:00<00:12,  7.73it/s]
#   6%|6         | 6/100 [00:00<00:11,  8.09it/s]
#   7%|7         | 7/100 [00:00<00:10,  8.46it/s]
#   8%|8         | 8/100 [00:01<00:10,  8.64it/s]
#   9%|9         | 9/100 [00:01<00:10,  8.83it/s]
#  10%|#         | 10/100 [00:01<00:10,  8.57it/s]
#  11%|#1        | 11/100 [00:01<00:10,  8.87it/s]
#  13%|#3        | 13/100 [00:01<00:08,  9.72it/s]
#  14%|#4        | 14/100 [00:01<00:08,  9.74it/s]
#  15%|#5        | 15/100 [00:01<00:08,  9.48it/s]
#  16%|#6        | 16/100 [00:01<00:09,  9.11it/s]
#  17%|#7        | 17/100 [00:02<00:09,  8.62it/s]
#  18%|#8        | 18/100 [00:02<00:09,  8.38it/s]
#  19%|#9        | 19/100 [00:02<00:09,  8.24it/s]
#  20%|##        | 20/100 [00:02<00:09,  8.22it/s]
#  21%|##1       | 21/100 [00:02<00:09,  8.10it/s]
#  22%|##2       | 22/100 [00:02<00:09,  7.89it/s]
#  23%|##3       | 23/100 [00:02<00:09,  7.73it/s]
#  24%|##4       | 24/100 [00:02<00:09,  7.76it/s]
#  25%|##5       | 25/100 [00:03<00:09,  7.81it/s]
#  26%|##6       | 26/100 [00:03<00:09,  7.91it/s]
#  27%|##7       | 27/100 [00:03<00:08,  8.15it/s]
#  28%|##8       | 28/100 [00:03<00:08,  8.29it/s]
#  29%|##9       | 29/100 [00:03<00:08,  8.69it/s]
#  30%|###       | 30/100 [00:03<00:08,  8.70it/s]
#  32%|###2      | 32/100 [00:03<00:07,  9.59it/s]
#  33%|###3      | 33/100 [00:03<00:06,  9.66it/s]
#  34%|###4      | 34/100 [00:04<00:06,  9.62it/s]
#  35%|###5      | 35/100 [00:04<00:06,  9.67it/s]
#  36%|###6      | 36/100 [00:04<00:06,  9.48it/s]
#  37%|###7      | 37/100 [00:04<00:06,  9.43it/s]
#  38%|###8      | 38/100 [00:04<00:06,  9.33it/s]
#  39%|###9      | 39/100 [00:04<00:06,  9.22it/s]
#  40%|####      | 40/100 [00:04<00:06,  8.96it/s]
#  41%|####1     | 41/100 [00:04<00:06,  8.83it/s]
#  42%|####2     | 42/100 [00:04<00:06,  8.59it/s]
#  43%|####3     | 43/100 [00:05<00:06,  8.34it/s]
#  44%|####4     | 44/100 [00:05<00:06,  8.25it/s]
#  45%|####5     | 45/100 [00:05<00:06,  8.10it/s]
#  46%|####6     | 46/100 [00:05<00:06,  8.08it/s]
#  47%|####6     | 47/100 [00:05<00:06,  8.03it/s]
#  48%|####8     | 48/100 [00:05<00:06,  7.89it/s]
#  49%|####9     | 49/100 [00:05<00:06,  7.89it/s]
#  50%|#####     | 50/100 [00:05<00:06,  8.07it/s]
#  51%|#####1    | 51/100 [00:06<00:05,  8.25it/s]
#  52%|#####2    | 52/100 [00:06<00:05,  8.26it/s]
#  53%|#####3    | 53/100 [00:06<00:05,  8.02it/s]
#  54%|#####4    | 54/100 [00:06<00:05,  8.06it/s]
#  55%|#####5    | 55/100 [00:06<00:05,  8.01it/s]
#  56%|#####6    | 56/100 [00:06<00:05,  7.62it/s]
#  57%|#####6    | 57/100 [00:06<00:05,  7.66it/s]
#  58%|#####8    | 58/100 [00:06<00:05,  7.74it/s]
#  59%|#####8    | 59/100 [00:07<00:05,  7.83it/s]
#  60%|######    | 60/100 [00:07<00:04,  8.05it/s]
#  61%|######1   | 61/100 [00:07<00:04,  8.19it/s]
#  62%|######2   | 62/100 [00:07<00:04,  8.06it/s]
#  63%|######3   | 63/100 [00:07<00:04,  7.90it/s]
#  64%|######4   | 64/100 [00:07<00:04,  7.89it/s]
#  65%|######5   | 65/100 [00:07<00:04,  8.28it/s]
#  66%|######6   | 66/100 [00:07<00:04,  8.49it/s]
#  67%|######7   | 67/100 [00:08<00:03,  8.68it/s]
#  68%|######8   | 68/100 [00:08<00:03,  8.76it/s]
#  69%|######9   | 69/100 [00:08<00:03,  8.85it/s]
#  70%|#######   | 70/100 [00:08<00:03,  8.86it/s]
#  71%|#######1  | 71/100 [00:08<00:03,  8.60it/s]
#  72%|#######2  | 72/100 [00:08<00:03,  8.34it/s]
#  73%|#######3  | 73/100 [00:08<00:03,  8.32it/s]
#  74%|#######4  | 74/100 [00:08<00:03,  8.04it/s]
#  75%|#######5  | 75/100 [00:09<00:03,  7.73it/s]
#  76%|#######6  | 76/100 [00:09<00:03,  7.59it/s]
#  77%|#######7  | 77/100 [00:09<00:03,  7.65it/s]
#  78%|#######8  | 78/100 [00:09<00:02,  7.74it/s]
#  79%|#######9  | 79/100 [00:09<00:02,  7.71it/s]
#  80%|########  | 80/100 [00:09<00:02,  7.78it/s]
#  81%|########1 | 81/100 [00:09<00:02,  8.00it/s]
#  82%|########2 | 82/100 [00:09<00:02,  7.97it/s]
#  83%|########2 | 83/100 [00:10<00:02,  7.79it/s]
#  84%|########4 | 84/100 [00:10<00:01,  8.08it/s]
#  85%|########5 | 85/100 [00:10<00:01,  8.07it/s]
#  86%|########6 | 86/100 [00:10<00:01,  8.27it/s]
#  87%|########7 | 87/100 [00:10<00:01,  8.49it/s]
#  88%|########8 | 88/100 [00:10<00:01,  8.68it/s]
#  89%|########9 | 89/100 [00:10<00:01,  8.61it/s]
#  90%|######### | 90/100 [00:10<00:01,  8.47it/s]
#  91%|#########1| 91/100 [00:10<00:01,  8.58it/s]
#  92%|#########2| 92/100 [00:11<00:00,  8.27it/s]
#  93%|#########3| 93/100 [00:11<00:00,  8.68it/s]
#  94%|#########3| 94/100 [00:11<00:00,  8.88it/s]
#  95%|#########5| 95/100 [00:11<00:00,  8.99it/s]
#  96%|#########6| 96/100 [00:11<00:00,  8.71it/s]
#  97%|#########7| 97/100 [00:11<00:00,  8.44it/s]
#  98%|#########8| 98/100 [00:11<00:00,  8.27it/s]
#  99%|#########9| 99/100 [00:11<00:00,  8.32it/s]
# 100%|##########| 100/100 [00:12<00:00,  8.22it/s]
# 100%|##########| 100/100 [00:12<00:00,  8.30it/s]
# 2025-09-22 13:13:03.469 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.7359 test 1.0158 metric ['0.6159']
#  33%|###3      | 1/3 [00:15<00:31, 15.63s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:37,  2.65it/s]
#   2%|2         | 2/100 [00:00<00:22,  4.32it/s]
#   3%|3         | 3/100 [00:00<00:17,  5.64it/s]
#   4%|4         | 4/100 [00:00<00:14,  6.79it/s]
#   6%|6         | 6/100 [00:00<00:11,  8.40it/s]
#   7%|7         | 7/100 [00:01<00:10,  8.46it/s]
#   8%|8         | 8/100 [00:01<00:11,  8.12it/s]
#   9%|9         | 9/100 [00:01<00:11,  7.94it/s]
#  11%|#1        | 11/100 [00:01<00:09,  8.90it/s]
#  13%|#3        | 13/100 [00:01<00:09,  9.39it/s]
#  15%|#5        | 15/100 [00:01<00:08,  9.70it/s]
#  17%|#7        | 17/100 [00:02<00:08,  9.87it/s]
#  18%|#8        | 18/100 [00:02<00:08,  9.73it/s]
#  19%|#9        | 19/100 [00:02<00:08,  9.72it/s]
#  20%|##        | 20/100 [00:02<00:08,  9.46it/s]
#  21%|##1       | 21/100 [00:02<00:08,  9.18it/s]
#  22%|##2       | 22/100 [00:02<00:08,  8.99it/s]
#  23%|##3       | 23/100 [00:02<00:08,  8.93it/s]
#  24%|##4       | 24/100 [00:02<00:08,  8.81it/s]
#  25%|##5       | 25/100 [00:03<00:09,  8.25it/s]
#  26%|##6       | 26/100 [00:03<00:09,  8.17it/s]
#  27%|##7       | 27/100 [00:03<00:08,  8.12it/s]
#  28%|##8       | 28/100 [00:03<00:08,  8.33it/s]
#  29%|##9       | 29/100 [00:03<00:08,  8.28it/s]
#  30%|###       | 30/100 [00:03<00:08,  8.52it/s]
#  32%|###2      | 32/100 [00:03<00:07,  9.30it/s]
#  33%|###3      | 33/100 [00:03<00:07,  9.19it/s]
#  34%|###4      | 34/100 [00:04<00:07,  9.11it/s]
#  35%|###5      | 35/100 [00:04<00:07,  9.08it/s]
#  36%|###6      | 36/100 [00:04<00:07,  8.89it/s]
#  37%|###7      | 37/100 [00:04<00:07,  8.70it/s]
#  38%|###8      | 38/100 [00:04<00:07,  8.60it/s]
#  39%|###9      | 39/100 [00:04<00:07,  8.59it/s]
#  40%|####      | 40/100 [00:04<00:06,  8.62it/s]
#  41%|####1     | 41/100 [00:04<00:07,  8.27it/s]
#  42%|####2     | 42/100 [00:04<00:07,  8.03it/s]
#  43%|####3     | 43/100 [00:05<00:07,  8.04it/s]
#  44%|####4     | 44/100 [00:05<00:07,  7.88it/s]
#  45%|####5     | 45/100 [00:05<00:06,  7.97it/s]
#  46%|####6     | 46/100 [00:05<00:06,  8.07it/s]
#  47%|####6     | 47/100 [00:05<00:06,  7.99it/s]
#  48%|####8     | 48/100 [00:05<00:06,  7.79it/s]
#  49%|####9     | 49/100 [00:05<00:06,  7.65it/s]
#  50%|#####     | 50/100 [00:06<00:06,  7.73it/s]
#  51%|#####1    | 51/100 [00:06<00:06,  7.68it/s]
#  52%|#####2    | 52/100 [00:06<00:06,  7.53it/s]
#  53%|#####3    | 53/100 [00:06<00:06,  7.51it/s]
#  54%|#####4    | 54/100 [00:06<00:06,  7.58it/s]
#  55%|#####5    | 55/100 [00:06<00:06,  7.36it/s]
#  56%|#####6    | 56/100 [00:06<00:05,  7.40it/s]
#  57%|#####6    | 57/100 [00:06<00:05,  7.71it/s]
#  58%|#####8    | 58/100 [00:07<00:05,  7.93it/s]
#  59%|#####8    | 59/100 [00:07<00:05,  7.71it/s]
#  60%|######    | 60/100 [00:07<00:05,  7.89it/s]
#  61%|######1   | 61/100 [00:07<00:04,  7.84it/s]
#  62%|######2   | 62/100 [00:07<00:04,  7.73it/s]
#  63%|######3   | 63/100 [00:07<00:04,  7.67it/s]
#  64%|######4   | 64/100 [00:07<00:04,  7.63it/s]
#  65%|######5   | 65/100 [00:07<00:04,  7.77it/s]
#  66%|######6   | 66/100 [00:08<00:04,  7.99it/s]
#  67%|######7   | 67/100 [00:08<00:03,  8.47it/s]
#  68%|######8   | 68/100 [00:08<00:03,  8.74it/s]
#  69%|######9   | 69/100 [00:08<00:03,  8.83it/s]
#  70%|#######   | 70/100 [00:08<00:03,  8.66it/s]
#  71%|#######1  | 71/100 [00:08<00:03,  8.48it/s]
#  72%|#######2  | 72/100 [00:08<00:03,  8.23it/s]
#  73%|#######3  | 73/100 [00:08<00:03,  8.07it/s]
#  74%|#######4  | 74/100 [00:09<00:03,  8.04it/s]
#  75%|#######5  | 75/100 [00:09<00:03,  8.01it/s]
#  76%|#######6  | 76/100 [00:09<00:03,  7.52it/s]
#  77%|#######7  | 77/100 [00:09<00:02,  7.99it/s]
#  79%|#######9  | 79/100 [00:09<00:02,  9.30it/s]
#  81%|########1 | 81/100 [00:09<00:01,  9.87it/s]
#  83%|########2 | 83/100 [00:09<00:01, 10.18it/s]
#  85%|########5 | 85/100 [00:10<00:01, 10.29it/s]
#  87%|########7 | 87/100 [00:10<00:01, 10.38it/s]
#  89%|########9 | 89/100 [00:10<00:00, 11.15it/s]
#  91%|#########1| 91/100 [00:10<00:00, 11.70it/s]
#  93%|#########3| 93/100 [00:10<00:00, 11.97it/s]
#  95%|#########5| 95/100 [00:10<00:00, 12.14it/s]
#  97%|#########7| 97/100 [00:11<00:00, 12.33it/s]
#  99%|#########9| 99/100 [00:11<00:00, 12.56it/s]
# 100%|##########| 100/100 [00:11<00:00,  8.81it/s]
# 2025-09-22 13:13:17.460 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.9292 test 0.8744 metric ['0.6697']
#  67%|######6   | 2/3 [00:29<00:14, 14.67s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:34,  2.84it/s]
#   2%|2         | 2/100 [00:00<00:23,  4.11it/s]
#   3%|3         | 3/100 [00:00<00:19,  4.99it/s]
#   4%|4         | 4/100 [00:00<00:15,  6.13it/s]
#   6%|6         | 6/100 [00:00<00:11,  8.08it/s]
#   8%|8         | 8/100 [00:01<00:10,  9.09it/s]
#   9%|9         | 9/100 [00:01<00:10,  9.01it/s]
#  10%|#         | 10/100 [00:01<00:10,  8.94it/s]
#  12%|#2        | 12/100 [00:01<00:08, 10.21it/s]
#  14%|#4        | 14/100 [00:01<00:07, 11.82it/s]
#  16%|#6        | 16/100 [00:01<00:06, 12.90it/s]
#  18%|#8        | 18/100 [00:01<00:05, 13.76it/s]
#  20%|##        | 20/100 [00:02<00:05, 14.41it/s]
#  22%|##2       | 22/100 [00:02<00:05, 14.70it/s]
#  24%|##4       | 24/100 [00:02<00:05, 15.15it/s]
#  26%|##6       | 26/100 [00:02<00:04, 15.36it/s]
#  28%|##8       | 28/100 [00:02<00:04, 15.44it/s]
#  30%|###       | 30/100 [00:02<00:04, 15.55it/s]
#  32%|###2      | 32/100 [00:02<00:04, 15.70it/s]
#  34%|###4      | 34/100 [00:02<00:04, 15.57it/s]
#  36%|###6      | 36/100 [00:03<00:04, 15.80it/s]
#  38%|###8      | 38/100 [00:03<00:03, 15.73it/s]
#  40%|####      | 40/100 [00:03<00:03, 15.74it/s]
#  42%|####2     | 42/100 [00:03<00:03, 15.71it/s]
#  44%|####4     | 44/100 [00:03<00:03, 15.74it/s]
#  46%|####6     | 46/100 [00:03<00:03, 15.71it/s]
#  48%|####8     | 48/100 [00:03<00:03, 14.92it/s]
#  50%|#####     | 50/100 [00:03<00:03, 14.45it/s]
#  52%|#####2    | 52/100 [00:04<00:03, 14.22it/s]
#  54%|#####4    | 54/100 [00:04<00:03, 14.32it/s]
#  56%|#####6    | 56/100 [00:04<00:02, 14.70it/s]
#  58%|#####8    | 58/100 [00:04<00:02, 15.00it/s]
#  60%|######    | 60/100 [00:04<00:02, 15.23it/s]
#  62%|######2   | 62/100 [00:04<00:02, 15.47it/s]
#  64%|######4   | 64/100 [00:04<00:02, 15.37it/s]
#  66%|######6   | 66/100 [00:05<00:02, 15.61it/s]
#  68%|######8   | 68/100 [00:05<00:02, 15.29it/s]
#  70%|#######   | 70/100 [00:05<00:01, 15.18it/s]
#  72%|#######2  | 72/100 [00:05<00:01, 15.02it/s]
#  74%|#######4  | 74/100 [00:05<00:01, 15.09it/s]
#  76%|#######6  | 76/100 [00:05<00:01, 14.97it/s]
#  78%|#######8  | 78/100 [00:05<00:01, 14.70it/s]
#  80%|########  | 80/100 [00:05<00:01, 14.64it/s]
#  82%|########2 | 82/100 [00:06<00:01, 13.65it/s]
#  84%|########4 | 84/100 [00:06<00:01, 13.57it/s]
#  86%|########6 | 86/100 [00:06<00:00, 14.06it/s]
#  88%|########8 | 88/100 [00:06<00:00, 14.12it/s]
#  90%|######### | 90/100 [00:06<00:00, 14.33it/s]
#  92%|#########2| 92/100 [00:06<00:00, 14.48it/s]
#  94%|#########3| 94/100 [00:06<00:00, 14.35it/s]
#  96%|#########6| 96/100 [00:07<00:00, 14.45it/s]
#  98%|#########8| 98/100 [00:07<00:00, 14.54it/s]
# 100%|##########| 100/100 [00:07<00:00, 14.34it/s]
# 100%|##########| 100/100 [00:07<00:00, 13.53it/s]
# 2025-09-22 13:13:27.137 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.8014 test 0.7373 metric ['0.7023']
# 100%|##########| 3/3 [00:39<00:00, 12.39s/it]
# 100%|##########| 3/3 [00:39<00:00, 13.10s/it]
# Calculated matrix size: 9
# Caluclated flatten size: 720
#  67%|██████▋   | 2/3 [01:19<00:39, 39.85s/trial, best loss: 0.6821397212147713]
# 2025-09-22 13:13:27.208 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to C:\GitHub\portfolio-JN\2-hypertuning-mlflow\models\20250922-131327
# 2025-09-22 13:13:27.209 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:39,  2.52it/s]
#   2%|2         | 2/100 [00:00<00:28,  3.46it/s]
#   3%|3         | 3/100 [00:00<00:22,  4.23it/s]
#   4%|4         | 4/100 [00:00<00:20,  4.68it/s]
#   5%|5         | 5/100 [00:01<00:18,  5.02it/s]
#   6%|6         | 6/100 [00:01<00:18,  5.07it/s]
#   7%|7         | 7/100 [00:01<00:19,  4.76it/s]
#   8%|8         | 8/100 [00:01<00:18,  5.00it/s]
#   9%|9         | 9/100 [00:01<00:17,  5.23it/s]
#  10%|#         | 10/100 [00:02<00:16,  5.44it/s]
#  11%|#1        | 11/100 [00:02<00:15,  5.60it/s]
#  12%|#2        | 12/100 [00:02<00:15,  5.64it/s]
#  13%|#3        | 13/100 [00:02<00:15,  5.44it/s]
#  14%|#4        | 14/100 [00:02<00:16,  5.17it/s]
#  15%|#5        | 15/100 [00:03<00:17,  4.98it/s]
#  16%|#6        | 16/100 [00:03<00:17,  4.88it/s]
#  17%|#7        | 17/100 [00:03<00:16,  5.01it/s]
#  18%|#8        | 18/100 [00:03<00:15,  5.26it/s]
#  19%|#9        | 19/100 [00:03<00:15,  5.39it/s]
#  20%|##        | 20/100 [00:04<00:15,  5.21it/s]
#  21%|##1       | 21/100 [00:04<00:14,  5.39it/s]
#  22%|##2       | 22/100 [00:04<00:14,  5.39it/s]
#  23%|##3       | 23/100 [00:04<00:14,  5.43it/s]
#  24%|##4       | 24/100 [00:04<00:13,  5.50it/s]
#  25%|##5       | 25/100 [00:04<00:13,  5.48it/s]
#  26%|##6       | 26/100 [00:05<00:14,  5.11it/s]
#  27%|##7       | 27/100 [00:05<00:14,  5.02it/s]
#  28%|##8       | 28/100 [00:05<00:14,  5.03it/s]
#  29%|##9       | 29/100 [00:05<00:14,  4.78it/s]
#  30%|###       | 30/100 [00:05<00:14,  4.82it/s]
#  31%|###1      | 31/100 [00:06<00:14,  4.79it/s]
#  32%|###2      | 32/100 [00:06<00:14,  4.78it/s]
#  33%|###3      | 33/100 [00:06<00:14,  4.77it/s]
#  34%|###4      | 34/100 [00:06<00:13,  4.82it/s]
#  35%|###5      | 35/100 [00:07<00:13,  4.89it/s]
#  36%|###6      | 36/100 [00:07<00:12,  5.14it/s]
#  37%|###7      | 37/100 [00:07<00:12,  5.04it/s]
#  38%|###8      | 38/100 [00:07<00:12,  5.03it/s]
#  39%|###9      | 39/100 [00:07<00:12,  4.95it/s]
#  40%|####      | 40/100 [00:08<00:12,  4.85it/s]
#  41%|####1     | 41/100 [00:08<00:11,  4.95it/s]
#  42%|####2     | 42/100 [00:08<00:11,  4.93it/s]
#  43%|####3     | 43/100 [00:08<00:11,  4.77it/s]
#  44%|####4     | 44/100 [00:08<00:11,  4.67it/s]
#  45%|####5     | 45/100 [00:09<00:11,  4.68it/s]
#  46%|####6     | 46/100 [00:09<00:10,  4.93it/s]
#  47%|####6     | 47/100 [00:09<00:10,  5.10it/s]
#  48%|####8     | 48/100 [00:09<00:10,  5.02it/s]
#  49%|####9     | 49/100 [00:09<00:10,  5.03it/s]
#  50%|#####     | 50/100 [00:10<00:10,  4.90it/s]
#  51%|#####1    | 51/100 [00:10<00:10,  4.76it/s]
#  52%|#####2    | 52/100 [00:10<00:09,  4.98it/s]
#  53%|#####3    | 53/100 [00:10<00:10,  4.67it/s]
#  54%|#####4    | 54/100 [00:10<00:09,  4.67it/s]
#  55%|#####5    | 55/100 [00:11<00:09,  4.79it/s]
#  56%|#####6    | 56/100 [00:11<00:09,  4.85it/s]
#  57%|#####6    | 57/100 [00:11<00:08,  5.03it/s]
#  58%|#####8    | 58/100 [00:11<00:08,  5.19it/s]
#  59%|#####8    | 59/100 [00:11<00:07,  5.36it/s]
#  60%|######    | 60/100 [00:12<00:07,  5.46it/s]
#  61%|######1   | 61/100 [00:12<00:07,  5.32it/s]
#  62%|######2   | 62/100 [00:12<00:07,  5.05it/s]
#  63%|######3   | 63/100 [00:12<00:07,  4.95it/s]
#  64%|######4   | 64/100 [00:12<00:07,  4.92it/s]
#  65%|######5   | 65/100 [00:13<00:06,  5.03it/s]
#  66%|######6   | 66/100 [00:13<00:06,  5.16it/s]
#  67%|######7   | 67/100 [00:13<00:06,  5.35it/s]
#  68%|######8   | 68/100 [00:13<00:05,  5.37it/s]
#  69%|######9   | 69/100 [00:13<00:05,  5.43it/s]
#  70%|#######   | 70/100 [00:13<00:05,  5.48it/s]
#  71%|#######1  | 71/100 [00:14<00:05,  5.51it/s]
#  72%|#######2  | 72/100 [00:14<00:05,  5.54it/s]
#  73%|#######3  | 73/100 [00:14<00:05,  5.38it/s]
#  74%|#######4  | 74/100 [00:14<00:05,  5.15it/s]
#  75%|#######5  | 75/100 [00:14<00:04,  5.04it/s]
#  76%|#######6  | 76/100 [00:15<00:04,  4.88it/s]
#  77%|#######7  | 77/100 [00:15<00:04,  4.82it/s]
#  78%|#######8  | 78/100 [00:15<00:04,  4.93it/s]
#  79%|#######9  | 79/100 [00:15<00:04,  4.91it/s]
#  80%|########  | 80/100 [00:15<00:04,  4.83it/s]
#  81%|########1 | 81/100 [00:16<00:04,  4.58it/s]
#  82%|########2 | 82/100 [00:16<00:03,  4.65it/s]
#  83%|########2 | 83/100 [00:16<00:03,  4.65it/s]
#  84%|########4 | 84/100 [00:16<00:03,  4.73it/s]
#  85%|########5 | 85/100 [00:17<00:03,  4.73it/s]
#  86%|########6 | 86/100 [00:17<00:02,  4.69it/s]
#  87%|########7 | 87/100 [00:17<00:02,  4.60it/s]
#  88%|########8 | 88/100 [00:17<00:02,  4.69it/s]
#  89%|########9 | 89/100 [00:17<00:02,  4.62it/s]
#  90%|######### | 90/100 [00:18<00:02,  4.55it/s]
#  91%|#########1| 91/100 [00:18<00:01,  4.61it/s]
#  92%|#########2| 92/100 [00:18<00:01,  4.66it/s]
#  93%|#########3| 93/100 [00:18<00:01,  4.60it/s]
#  94%|#########3| 94/100 [00:19<00:01,  4.59it/s]
#  95%|#########5| 95/100 [00:19<00:01,  4.40it/s]
#  96%|#########6| 96/100 [00:19<00:00,  4.58it/s]
#  97%|#########7| 97/100 [00:19<00:00,  4.75it/s]
#  98%|#########8| 98/100 [00:19<00:00,  4.65it/s]
#  99%|#########9| 99/100 [00:20<00:00,  4.64it/s]
# 100%|##########| 100/100 [00:20<00:00,  4.44it/s]
# 100%|##########| 100/100 [00:20<00:00,  4.92it/s]
# 2025-09-22 13:13:53.546 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.6606 test 0.8877 metric ['0.6731']
#  33%|###3      | 1/3 [00:26<00:52, 26.33s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:35,  2.78it/s]
#   2%|2         | 2/100 [00:00<00:25,  3.81it/s]
#   3%|3         | 3/100 [00:00<00:23,  4.08it/s]
#   4%|4         | 4/100 [00:00<00:21,  4.43it/s]
#   5%|5         | 5/100 [00:01<00:20,  4.55it/s]
#   6%|6         | 6/100 [00:01<00:21,  4.31it/s]
#   7%|7         | 7/100 [00:01<00:21,  4.41it/s]
#   8%|8         | 8/100 [00:01<00:20,  4.56it/s]
#   9%|9         | 9/100 [00:02<00:18,  4.82it/s]
#  10%|#         | 10/100 [00:02<00:17,  5.01it/s]
#  11%|#1        | 11/100 [00:02<00:17,  5.11it/s]
#  12%|#2        | 12/100 [00:02<00:16,  5.23it/s]
#  13%|#3        | 13/100 [00:02<00:16,  5.33it/s]
#  14%|#4        | 14/100 [00:02<00:15,  5.38it/s]
#  15%|#5        | 15/100 [00:03<00:15,  5.40it/s]
#  16%|#6        | 16/100 [00:03<00:15,  5.43it/s]
#  17%|#7        | 17/100 [00:03<00:15,  5.45it/s]
#  18%|#8        | 18/100 [00:03<00:15,  5.45it/s]
#  19%|#9        | 19/100 [00:03<00:14,  5.46it/s]
#  20%|##        | 20/100 [00:04<00:14,  5.51it/s]
#  21%|##1       | 21/100 [00:04<00:14,  5.46it/s]
#  22%|##2       | 22/100 [00:04<00:14,  5.45it/s]
#  23%|##3       | 23/100 [00:04<00:14,  5.41it/s]
#  24%|##4       | 24/100 [00:04<00:13,  5.50it/s]
#  25%|##5       | 25/100 [00:04<00:13,  5.48it/s]
#  26%|##6       | 26/100 [00:05<00:13,  5.53it/s]
#  27%|##7       | 27/100 [00:05<00:13,  5.56it/s]
#  28%|##8       | 28/100 [00:05<00:12,  5.61it/s]
#  29%|##9       | 29/100 [00:05<00:12,  5.57it/s]
#  30%|###       | 30/100 [00:05<00:13,  5.24it/s]
#  31%|###1      | 31/100 [00:06<00:12,  5.38it/s]
#  32%|###2      | 32/100 [00:06<00:12,  5.47it/s]
#  33%|###3      | 33/100 [00:06<00:12,  5.53it/s]
#  34%|###4      | 34/100 [00:06<00:12,  5.49it/s]
#  35%|###5      | 35/100 [00:06<00:12,  5.37it/s]
#  36%|###6      | 36/100 [00:06<00:11,  5.34it/s]
#  37%|###7      | 37/100 [00:07<00:11,  5.35it/s]
#  38%|###8      | 38/100 [00:07<00:11,  5.42it/s]
#  39%|###9      | 39/100 [00:07<00:11,  5.33it/s]
#  40%|####      | 40/100 [00:07<00:11,  5.44it/s]
#  41%|####1     | 41/100 [00:07<00:10,  5.46it/s]
#  42%|####2     | 42/100 [00:08<00:10,  5.53it/s]
#  43%|####3     | 43/100 [00:08<00:10,  5.56it/s]
#  44%|####4     | 44/100 [00:08<00:10,  5.57it/s]
#  45%|####5     | 45/100 [00:08<00:09,  5.56it/s]
#  46%|####6     | 46/100 [00:08<00:09,  5.47it/s]
#  47%|####6     | 47/100 [00:08<00:09,  5.45it/s]
#  48%|####8     | 48/100 [00:09<00:09,  5.51it/s]
#  49%|####9     | 49/100 [00:09<00:09,  5.50it/s]
#  50%|#####     | 50/100 [00:09<00:09,  5.55it/s]
#  51%|#####1    | 51/100 [00:09<00:09,  5.44it/s]
#  52%|#####2    | 52/100 [00:09<00:09,  5.23it/s]
#  53%|#####3    | 53/100 [00:10<00:09,  5.15it/s]
#  54%|#####4    | 54/100 [00:10<00:08,  5.11it/s]
#  55%|#####5    | 55/100 [00:10<00:08,  5.33it/s]
#  56%|#####6    | 56/100 [00:10<00:08,  5.33it/s]
#  57%|#####6    | 57/100 [00:10<00:07,  5.41it/s]
#  58%|#####8    | 58/100 [00:11<00:07,  5.45it/s]
#  59%|#####8    | 59/100 [00:11<00:07,  5.54it/s]
#  60%|######    | 60/100 [00:11<00:07,  5.66it/s]
#  61%|######1   | 61/100 [00:11<00:06,  5.82it/s]
#  62%|######2   | 62/100 [00:11<00:06,  5.82it/s]
#  63%|######3   | 63/100 [00:11<00:06,  5.78it/s]
#  64%|######4   | 64/100 [00:12<00:06,  5.84it/s]
#  65%|######5   | 65/100 [00:12<00:05,  5.85it/s]
#  66%|######6   | 66/100 [00:12<00:05,  5.84it/s]
#  67%|######7   | 67/100 [00:12<00:05,  5.83it/s]
#  68%|######8   | 68/100 [00:12<00:05,  5.87it/s]
#  69%|######9   | 69/100 [00:12<00:05,  5.87it/s]
#  70%|#######   | 70/100 [00:13<00:05,  5.85it/s]
#  71%|#######1  | 71/100 [00:13<00:04,  5.88it/s]
#  72%|#######2  | 72/100 [00:13<00:04,  5.91it/s]
#  73%|#######3  | 73/100 [00:13<00:04,  5.93it/s]
#  74%|#######4  | 74/100 [00:13<00:04,  5.88it/s]
#  75%|#######5  | 75/100 [00:13<00:04,  5.87it/s]
#  76%|#######6  | 76/100 [00:14<00:04,  5.87it/s]
#  77%|#######7  | 77/100 [00:14<00:03,  5.86it/s]
#  78%|#######8  | 78/100 [00:14<00:03,  5.86it/s]
#  79%|#######9  | 79/100 [00:14<00:03,  5.84it/s]
#  80%|########  | 80/100 [00:14<00:03,  5.83it/s]
#  81%|########1 | 81/100 [00:14<00:03,  5.82it/s]
#  82%|########2 | 82/100 [00:15<00:03,  5.50it/s]
#  83%|########2 | 83/100 [00:15<00:03,  5.56it/s]
#  84%|########4 | 84/100 [00:15<00:02,  5.62it/s]
#  85%|########5 | 85/100 [00:15<00:02,  5.66it/s]
#  86%|########6 | 86/100 [00:15<00:02,  5.58it/s]
#  87%|########7 | 87/100 [00:16<00:02,  5.56it/s]
#  88%|########8 | 88/100 [00:16<00:02,  5.38it/s]
#  89%|########9 | 89/100 [00:16<00:02,  5.29it/s]
#  90%|######### | 90/100 [00:16<00:01,  5.17it/s]
#  91%|#########1| 91/100 [00:16<00:01,  5.11it/s]
#  92%|#########2| 92/100 [00:17<00:01,  5.26it/s]
#  93%|#########3| 93/100 [00:17<00:01,  5.30it/s]
#  94%|#########3| 94/100 [00:17<00:01,  5.15it/s]
#  95%|#########5| 95/100 [00:17<00:00,  5.11it/s]
#  96%|#########6| 96/100 [00:17<00:00,  5.18it/s]
#  97%|#########7| 97/100 [00:18<00:00,  5.11it/s]
#  98%|#########8| 98/100 [00:18<00:00,  5.14it/s]
#  99%|#########9| 99/100 [00:18<00:00,  5.24it/s]
# 100%|##########| 100/100 [00:18<00:00,  5.33it/s]
# 100%|##########| 100/100 [00:18<00:00,  5.39it/s]
# 2025-09-22 13:14:18.022 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7973 test 0.7472 metric ['0.7188']
#  67%|######6   | 2/3 [00:50<00:25, 25.24s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|1         | 1/100 [00:00<00:48,  2.03it/s]
#   2%|2         | 2/100 [00:00<00:31,  3.11it/s]
#   3%|3         | 3/100 [00:00<00:26,  3.65it/s]
#   4%|4         | 4/100 [00:01<00:22,  4.30it/s]
#   5%|5         | 5/100 [00:01<00:20,  4.65it/s]
#   6%|6         | 6/100 [00:01<00:20,  4.60it/s]
#   7%|7         | 7/100 [00:01<00:18,  4.91it/s]
#   8%|8         | 8/100 [00:01<00:17,  5.15it/s]
#   9%|9         | 9/100 [00:02<00:16,  5.35it/s]
#  10%|#         | 10/100 [00:02<00:16,  5.39it/s]
#  11%|#1        | 11/100 [00:02<00:16,  5.43it/s]
#  12%|#2        | 12/100 [00:02<00:15,  5.51it/s]
#  13%|#3        | 13/100 [00:02<00:15,  5.52it/s]
#  14%|#4        | 14/100 [00:02<00:15,  5.55it/s]
#  15%|#5        | 15/100 [00:03<00:15,  5.56it/s]
#  16%|#6        | 16/100 [00:03<00:15,  5.59it/s]
#  17%|#7        | 17/100 [00:03<00:14,  5.56it/s]
#  18%|#8        | 18/100 [00:03<00:14,  5.62it/s]
#  19%|#9        | 19/100 [00:03<00:14,  5.61it/s]
#  20%|##        | 20/100 [00:03<00:14,  5.64it/s]
#  21%|##1       | 21/100 [00:04<00:14,  5.62it/s]
#  22%|##2       | 22/100 [00:04<00:13,  5.65it/s]
#  23%|##3       | 23/100 [00:04<00:13,  5.68it/s]
#  24%|##4       | 24/100 [00:04<00:13,  5.70it/s]
#  25%|##5       | 25/100 [00:04<00:13,  5.70it/s]
#  26%|##6       | 26/100 [00:05<00:13,  5.67it/s]
#  27%|##7       | 27/100 [00:05<00:12,  5.72it/s]
#  28%|##8       | 28/100 [00:05<00:12,  5.74it/s]
#  29%|##9       | 29/100 [00:05<00:13,  5.42it/s]
#  30%|###       | 30/100 [00:05<00:12,  5.46it/s]
#  31%|###1      | 31/100 [00:05<00:13,  5.18it/s]
#  32%|###2      | 32/100 [00:06<00:13,  5.13it/s]
#  33%|###3      | 33/100 [00:06<00:12,  5.25it/s]
#  34%|###4      | 34/100 [00:06<00:12,  5.35it/s]
#  35%|###5      | 35/100 [00:06<00:12,  5.32it/s]
#  36%|###6      | 36/100 [00:06<00:12,  5.27it/s]
#  37%|###7      | 37/100 [00:07<00:11,  5.43it/s]
#  38%|###8      | 38/100 [00:07<00:11,  5.54it/s]
#  39%|###9      | 39/100 [00:07<00:10,  5.55it/s]
#  40%|####      | 40/100 [00:07<00:10,  5.55it/s]
#  41%|####1     | 41/100 [00:07<00:10,  5.56it/s]
#  42%|####2     | 42/100 [00:07<00:10,  5.61it/s]
#  43%|####3     | 43/100 [00:08<00:10,  5.63it/s]
#  44%|####4     | 44/100 [00:08<00:09,  5.66it/s]
#  45%|####5     | 45/100 [00:08<00:09,  5.69it/s]
#  46%|####6     | 46/100 [00:08<00:09,  5.65it/s]
#  47%|####6     | 47/100 [00:08<00:09,  5.64it/s]
#  48%|####8     | 48/100 [00:09<00:09,  5.38it/s]
#  49%|####9     | 49/100 [00:09<00:09,  5.47it/s]
#  50%|#####     | 50/100 [00:09<00:09,  5.53it/s]
#  51%|#####1    | 51/100 [00:09<00:08,  5.53it/s]
#  52%|#####2    | 52/100 [00:09<00:08,  5.53it/s]
#  53%|#####3    | 53/100 [00:09<00:08,  5.56it/s]
#  54%|#####4    | 54/100 [00:10<00:08,  5.54it/s]
#  55%|#####5    | 55/100 [00:10<00:08,  5.59it/s]
#  56%|#####6    | 56/100 [00:10<00:07,  5.63it/s]
#  57%|#####6    | 57/100 [00:10<00:07,  5.62it/s]
#  58%|#####8    | 58/100 [00:10<00:07,  5.45it/s]
#  59%|#####8    | 59/100 [00:11<00:07,  5.33it/s]
#  60%|######    | 60/100 [00:11<00:07,  5.21it/s]
#  61%|######1   | 61/100 [00:11<00:07,  5.08it/s]
#  62%|######2   | 62/100 [00:11<00:07,  5.08it/s]
#  63%|######3   | 63/100 [00:11<00:07,  5.01it/s]
#  64%|######4   | 64/100 [00:12<00:07,  5.08it/s]
#  65%|######5   | 65/100 [00:12<00:06,  5.12it/s]
#  66%|######6   | 66/100 [00:12<00:06,  5.07it/s]
#  67%|######7   | 67/100 [00:12<00:06,  5.08it/s]
#  68%|######8   | 68/100 [00:12<00:06,  5.05it/s]
#  69%|######9   | 69/100 [00:13<00:06,  5.12it/s]
#  70%|#######   | 70/100 [00:13<00:05,  5.25it/s]
#  71%|#######1  | 71/100 [00:13<00:05,  5.21it/s]
#  72%|#######2  | 72/100 [00:13<00:05,  5.26it/s]
#  73%|#######3  | 73/100 [00:13<00:05,  5.04it/s]
#  74%|#######4  | 74/100 [00:13<00:05,  5.18it/s]
#  75%|#######5  | 75/100 [00:14<00:04,  5.14it/s]
#  76%|#######6  | 76/100 [00:14<00:04,  5.21it/s]
#  77%|#######7  | 77/100 [00:14<00:04,  5.15it/s]
#  78%|#######8  | 78/100 [00:14<00:04,  5.11it/s]
#  79%|#######9  | 79/100 [00:14<00:04,  5.02it/s]
#  80%|########  | 80/100 [00:15<00:03,  5.09it/s]
#  81%|########1 | 81/100 [00:15<00:03,  5.21it/s]
#  82%|########2 | 82/100 [00:15<00:03,  5.14it/s]
#  83%|########2 | 83/100 [00:15<00:03,  5.23it/s]
#  84%|########4 | 84/100 [00:15<00:03,  5.32it/s]
#  85%|########5 | 85/100 [00:16<00:02,  5.28it/s]
#  86%|########6 | 86/100 [00:16<00:02,  5.41it/s]
#  87%|########7 | 87/100 [00:16<00:02,  5.51it/s]
#  88%|########8 | 88/100 [00:16<00:02,  5.54it/s]
#  89%|########9 | 89/100 [00:16<00:01,  5.53it/s]
#  90%|######### | 90/100 [00:17<00:01,  5.54it/s]
#  91%|#########1| 91/100 [00:17<00:01,  5.55it/s]
#  92%|#########2| 92/100 [00:17<00:01,  5.36it/s]
#  93%|#########3| 93/100 [00:17<00:01,  5.41it/s]
#  94%|#########3| 94/100 [00:17<00:01,  5.47it/s]
#  95%|#########5| 95/100 [00:17<00:00,  5.43it/s]
#  96%|#########6| 96/100 [00:18<00:00,  5.31it/s]
#  97%|#########7| 97/100 [00:18<00:00,  5.43it/s]
#  98%|#########8| 98/100 [00:18<00:00,  5.49it/s]
#  99%|#########9| 99/100 [00:18<00:00,  5.52it/s]
# 100%|##########| 100/100 [00:18<00:00,  5.57it/s]
# 100%|##########| 100/100 [00:18<00:00,  5.31it/s]
# 2025-09-22 13:14:43.600 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.6865 test 0.7004 metric ['0.7309']
# 100%|##########| 3/3 [01:16<00:00, 25.39s/it]
# 100%|##########| 3/3 [01:16<00:00, 25.46s/it]
# 100%|██████████| 3/3 [02:36<00:00, 52.12s/trial, best loss: 0.6821397212147713]

# %% [markdown]
# After running this, you can look at the best_result

# %%
best_result
# Out:
# {'filters': np.float64(40.0),
#  'kernel_size': np.float64(3.0),
#  'num_layers': np.float64(1.0)}

# %% [markdown]
# # MLflow GUI
# MLflow has a really great dashboard.
# you can see it with the command:
# ```bash
# mlflow server \
#     --backend-store-uri sqlite:///mlflow.db \
#     --host 127.0.0.1 \
#     --port 5000 \
# ```
#
# The `--backend-store-uri` argument specifies the location of the SQLite database file, which is used to store experiment metadata, such as parameters, metrics, and artifacts.
# We have initialized the experiment with `mlflow.set_tracking_uri("sqlite:///mlflow.db")`, so `mlflow.db` is the location we need.
#
# `--host` tells the server we use our own machine (localhost), and `--port` specifies the port number on which the server will listen for incoming requests. In this case, we are using port 5000. Sometimes, you can have conflicts on a specific port and it could help to change the port (eg to 5001)
#
# Note that on a windows machine, the `\` gives errors (because, why not, right) so for windows you might need to remove the `\` and put everything on a single line.
#
# I have created a `Makefile` to automate these commands, but if it doesnt work (again, because you are on windows for example) you can just type the command by hand in your terminal.
#
# After starting this up, go to `http://127.0.0.1:5000` in your browser. You should see the MLflow UI, where you can explore your experiments, runs, and metrics. The UI provides a user-friendly way to visualize and compare different runs, making it easier to analyze the results of your hyperparameter optimization and model training.

# %% [markdown]
# Test for tuning parameters

# %%
import torch
import torch.nn as nn
from typing import List, Literal, Optional

class FlexCNN(nn.Module):
    """
    Een modulaire CNN waarmee je conv-blokken, normalisatie en dropout als hyperparameters kunt variëren.
    """
    def __init__(
        self,
        input_channels: int = 1,
        num_classes: int = 10,
        conv_blocks: int = 3,
        base_filters: int = 32,
        filters_growth: float = 1.0,  # 1.0 = constant, 2.0 = verdubbelen per blok, etc.
        kernel_size: int = 3,
        pool_kernel: int = 2,
        norm: Literal["batch", "layer", "none"] = "batch",
        hidden_units: List[int] = [128, 64],
        dropout_p: float = 0.2,
        global_pool: Literal["avg", "max", "adaptive"] = "adaptive",
    ):
        super().__init__()
        self.input_channels = input_channels
        self.num_classes = num_classes
        self.conv_blocks = conv_blocks
        self.base_filters = base_filters
        self.filters_growth = filters_growth
        self.kernel_size = kernel_size
        self.pool_kernel = pool_kernel
        self.norm = norm
        self.hidden_units = hidden_units
        self.dropout_p = dropout_p
        self.global_pool = global_pool

        # ---- Convolutionele blokken (ModuleList) ----
        in_ch = input_channels
        convs = []
        filters = base_filters
        padding = kernel_size // 2  # 'same-ish' bij stride=1

        for b in range(conv_blocks):
            block = []
            block.append(nn.Conv2d(in_ch, int(filters), kernel_size=kernel_size, stride=1, padding=padding))
            if norm == "batch":
                block.append(nn.BatchNorm2d(int(filters)))
            elif norm == "layer":
                # LayerNorm over (C,H,W) -> channels-last LN: beter via GroupNorm met 1 group
                block.append(nn.GroupNorm(1, int(filters)))
            block.append(nn.ReLU(inplace=True))
            block.append(nn.MaxPool2d(kernel_size=pool_kernel))

            convs.append(nn.Sequential(*block))
            in_ch = int(filters)
            filters = int(filters * filters_growth if filters_growth > 0 else filters)

        self.convs = nn.ModuleList(convs)

        # ---- Global pooling om feature-dim te fixeren ----
        if global_pool == "avg":
            self.global_pool_layer = nn.AdaptiveAvgPool2d((1,1))
        elif global_pool == "max":
            self.global_pool_layer = nn.AdaptiveMaxPool2d((1,1))
        else:
            self.global_pool_layer = nn.AdaptiveAvgPool2d((1,1))  # default

        # ---- Dense gedeelte + Dropout ----
        dense_layers = [nn.Flatten()]  # (N, C, 1, 1) -> (N, C)
        in_features = in_ch  # na global pool is C over
        for hu in hidden_units:
            dense_layers.append(nn.Linear(in_features, hu))
            # Normalisatie kan ook op dense: BatchNorm1d of LayerNorm
            if norm == "batch":
                dense_layers.append(nn.BatchNorm1d(hu))
            elif norm == "layer":
                dense_layers.append(nn.LayerNorm(hu))
            dense_layers.append(nn.ReLU(inplace=True))
            if dropout_p and dropout_p > 0:
                dense_layers.append(nn.Dropout(p=dropout_p))
            in_features = hu

        dense_layers.append(nn.Linear(in_features, num_classes))
        self.dense = nn.Sequential(*dense_layers)

    def forward(self, x):
        for block in self.convs:
            x = block(x)
        x = self.global_pool_layer(x)
        logits = self.dense(x)
        return logits

# %%
import mlflow
from mltrainer import metrics, Trainer, TrainerSettings, ReportTypes
import torch.optim as optim

# Tracking en experiment instellen
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("cnn_hparam_search")

# Trainer settings (pas aan op jouw dataset/pipeline)
accuracy = metrics.Accuracy()
settings = TrainerSettings(
    epochs=6,                  # iets langer trainen geeft stabielere vergelijking
    metrics=[accuracy],
    logdir="modellogs",
    train_steps=200,           # pas aan naar je dataset/generator
    valid_steps=100,
    reporttypes=[ReportTypes.MLFLOW, ReportTypes.TOML],
)

# %%
# Voorbeeld search space (pas gerust aan of breid uit)
grids = {
    "conv_blocks": [4, 5],
    "base_filters": [32, 64],
    "filters_growth": [2.0, 3.0],
    "norm": ["batch", "layer"],
    "dropout_p": [0.0, 0.1],
    "hidden_units": [(128, 64), (128, 64, 32)],
    "lr": [1e-3, 3e-4],
    "weight_decay": [0.0, 1e-4],
    "batchsize": [64],  # als je batchsize varieert, log die ook en geef hem door aan je dataloader
}

import itertools

def run_one(hp):
    # Model maken
    model = FlexCNN(
        input_channels=1,
        num_classes=10,
        conv_blocks=hp["conv_blocks"],
        base_filters=hp["base_filters"],
        filters_growth=hp["filters_growth"],
        norm=hp["norm"],
        hidden_units=list(hp["hidden_units"]),
        dropout_p=hp["dropout_p"],
        global_pool="adaptive",
    ).to("cpu")

    # Trainer klaarzetten (je eigen streamers invullen)
    loss_fn = nn.CrossEntropyLoss()
    optimizer = optim.Adam
    scheduler = None  # of bijvoorbeeld optim.lr_scheduler.ReduceLROnPlateau

    trainer = Trainer(
        model=model,
        settings=settings,
        loss_fn=loss_fn,
        optimizer=optimizer,
        traindataloader=trainstreamer,     # <-- gebruik je bestaande
        validdataloader=validstreamer,     # <-- gebruik je bestaande
        scheduler=scheduler
    )

    # MLflow run
    with mlflow.start_run():
        # Hyperparameters loggen
        mlflow.log_params({
            "conv_blocks": hp["conv_blocks"],
            "base_filters": hp["base_filters"],
            "filters_growth": hp["filters_growth"],
            "norm": hp["norm"],
            "dropout_p": hp["dropout_p"],
            "hidden_units": "-".join(map(str, hp["hidden_units"])),
            "lr": hp["lr"],
            "weight_decay": hp["weight_decay"],
            "batchsize": hp["batchsize"],
        })
        mlflow.set_tag("model", "FlexCNN")
        mlflow.set_tag("dev", "JN")

        # Zorg dat je optimizer de lr/weight_decay mee krijgt (je Trainer kan dat als class doorgeven)
        # Als je Trainer explicit kwargs verwacht:
        trainer.optimizer_kwargs = {"lr": hp["lr"], "weight_decay": hp["weight_decay"]}

        # Trainen/valideren
        trainer.loop()  # jouw Trainer logt MLFLOW/TOML al via settings

        # (Optioneel) extra metrics of artefacten loggen
        # mlflow.log_metric("final_val_acc", float(...))
        # mlflow.log_artifact("path/naar/confusion_matrix.png")
    return

# Bruteforce grid (klein houden om te starten)
keys = list(grids.keys())
values = [grids[k] for k in keys]
for combo in itertools.product(*values):
    hp = dict(zip(keys, combo))
    run_one(hp)
# Out:
# 2025-09-22 13:14:43.716 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-131443
# 2025-09-22 13:14:43.718 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:15<00:00, 13.15it/s]
# 2025-09-22 13:15:01.153 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.6546 test 0.4604 metric ['0.8359']
# 100%|██████████| 200/200 [00:14<00:00, 13.34it/s]
# 2025-09-22 13:15:18.282 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3827 test 0.4067 metric ['0.8578']
# 100%|██████████| 200/200 [00:15<00:00, 13.18it/s]
# 2025-09-22 13:15:35.569 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3300 test 0.3682 metric ['0.8650']
# 100%|██████████| 200/200 [00:14<00:00, 13.43it/s]
# 2025-09-22 13:15:52.687 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.2859 test 0.3572 metric ['0.8728']
# 100%|██████████| 200/200 [00:15<00:00, 12.99it/s]
# 2025-09-22 13:16:10.482 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2817 test 0.3498 metric ['0.8744']
# 100%|██████████| 200/200 [00:15<00:00, 13.30it/s]
# 2025-09-22 13:16:27.753 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2722 test 0.3051 metric ['0.8869']
# 100%|██████████| 6/6 [01:43<00:00, 17.33s/it]
# 2025-09-22 13:16:27.780 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-131627
# 2025-09-22 13:16:27.783 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:15<00:00, 12.98it/s]
# 2025-09-22 13:16:45.359 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.6478 test 0.4537 metric ['0.8402']
# 100%|██████████| 200/200 [00:15<00:00, 13.27it/s]
# 2025-09-22 13:17:01.763 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3676 test 0.3672 metric ['0.8638']
# 100%|██████████| 200/200 [00:14<00:00, 13.66it/s]
# 2025-09-22 13:17:18.535 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3182 test 0.3235 metric ['0.8852']
# 100%|██████████| 200/200 [00:14<00:00, 13.64it/s]
# 2025-09-22 13:17:35.402 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3048 test 0.3416 metric ['0.8748']
# 2025-09-22 13:17:35.403 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3235, current loss 0.3416.Counter 1/10.
# 100%|██████████| 200/200 [00:14<00:00, 13.74it/s]
# 2025-09-22 13:17:52.056 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2765 test 0.3005 metric ['0.8892']
# 100%|██████████| 200/200 [00:15<00:00, 13.31it/s]
# 2025-09-22 13:18:09.252 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2721 test 0.2758 metric ['0.8977']
# 100%|██████████| 6/6 [01:41<00:00, 16.90s/it]
# 2025-09-22 13:18:09.277 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-131809
# 2025-09-22 13:18:09.279 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:15<00:00, 13.14it/s]
# 2025-09-22 13:18:26.777 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.6474 test 0.4247 metric ['0.8588']
# 100%|██████████| 200/200 [00:15<00:00, 13.29it/s]
# 2025-09-22 13:18:44.018 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3723 test 0.3669 metric ['0.8644']
# 100%|██████████| 200/200 [00:14<00:00, 13.73it/s]
# 2025-09-22 13:19:00.742 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3311 test 0.3035 metric ['0.8900']
# 100%|██████████| 200/200 [00:14<00:00, 13.74it/s]
# 2025-09-22 13:19:17.522 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3043 test 0.3180 metric ['0.8891']
# 2025-09-22 13:19:17.524 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3035, current loss 0.3180.Counter 1/10.
# 100%|██████████| 200/200 [00:14<00:00, 13.83it/s]
# 2025-09-22 13:19:34.089 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2880 test 0.3237 metric ['0.8777']
# 2025-09-22 13:19:34.090 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3035, current loss 0.3237.Counter 2/10.
# 100%|██████████| 200/200 [00:15<00:00, 12.97it/s]
# 2025-09-22 13:19:51.732 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2645 test 0.2856 metric ['0.9006']
# 100%|██████████| 6/6 [01:42<00:00, 17.07s/it]
# 2025-09-22 13:19:51.755 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-131951
# 2025-09-22 13:19:51.757 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:11<00:00, 17.33it/s]
# 2025-09-22 13:20:04.501 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.6383 test 0.4368 metric ['0.8497']
# 100%|██████████| 200/200 [00:15<00:00, 13.33it/s]
# 2025-09-22 13:20:21.795 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3682 test 0.3548 metric ['0.8745']
# 100%|██████████| 200/200 [00:07<00:00, 25.11it/s]
# 2025-09-22 13:20:30.850 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3357 test 0.3509 metric ['0.8731']
# 100%|██████████| 200/200 [00:06<00:00, 32.56it/s]
# 2025-09-22 13:20:38.031 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3115 test 0.2944 metric ['0.8961']
# 100%|██████████| 200/200 [00:05<00:00, 33.48it/s]
# 2025-09-22 13:20:44.955 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2648 test 0.2879 metric ['0.8997']
# 100%|██████████| 200/200 [00:06<00:00, 33.13it/s]
# 2025-09-22 13:20:52.009 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2640 test 0.3274 metric ['0.8814']
# 2025-09-22 13:20:52.010 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.2879, current loss 0.3274.Counter 1/10.
# 100%|██████████| 6/6 [01:00<00:00, 10.03s/it]
# 2025-09-22 13:20:52.024 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132052
# 2025-09-22 13:20:52.025 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 33.27it/s]
# 2025-09-22 13:20:59.093 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8518 test 0.6803 metric ['0.7694']
# 100%|██████████| 200/200 [00:06<00:00, 32.94it/s]
# 2025-09-22 13:21:06.380 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4280 test 0.3829 metric ['0.8633']
# 100%|██████████| 200/200 [00:06<00:00, 32.95it/s]
# 2025-09-22 13:21:13.456 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3449 test 0.3887 metric ['0.8600']
# 2025-09-22 13:21:13.457 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3829, current loss 0.3887.Counter 1/10.
# 100%|██████████| 200/200 [00:05<00:00, 33.92it/s]
# 2025-09-22 13:21:20.353 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3119 test 0.3243 metric ['0.8877']
# 100%|██████████| 200/200 [00:05<00:00, 34.23it/s]
# 2025-09-22 13:21:27.208 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2962 test 0.2996 metric ['0.8900']
# 100%|██████████| 200/200 [00:05<00:00, 33.84it/s]
# 2025-09-22 13:21:34.121 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2755 test 0.3089 metric ['0.8920']
# 2025-09-22 13:21:34.122 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.2996, current loss 0.3089.Counter 1/10.
# 100%|██████████| 6/6 [00:42<00:00,  7.01s/it]
# 2025-09-22 13:21:34.134 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132134
# 2025-09-22 13:21:34.135 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:05<00:00, 33.63it/s]
# 2025-09-22 13:21:41.137 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8524 test 0.5260 metric ['0.8378']
# 100%|██████████| 200/200 [00:06<00:00, 33.13it/s]
# 2025-09-22 13:21:48.190 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4203 test 0.4025 metric ['0.8600']
# 100%|██████████| 200/200 [00:05<00:00, 33.38it/s]
# 2025-09-22 13:21:55.228 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3500 test 0.3548 metric ['0.8764']
# 100%|██████████| 200/200 [00:05<00:00, 34.26it/s]
# 2025-09-22 13:22:02.078 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3340 test 0.3669 metric ['0.8602']
# 2025-09-22 13:22:02.079 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3548, current loss 0.3669.Counter 1/10.
# 100%|██████████| 200/200 [00:06<00:00, 33.17it/s]
# 2025-09-22 13:22:09.170 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3065 test 0.2964 metric ['0.8983']
# 100%|██████████| 200/200 [00:06<00:00, 30.37it/s]
# 2025-09-22 13:22:17.032 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2964 test 0.2903 metric ['0.8923']
# 100%|██████████| 6/6 [00:42<00:00,  7.14s/it]
# 2025-09-22 13:22:17.047 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132217
# 2025-09-22 13:22:17.048 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:07<00:00, 28.46it/s]
# 2025-09-22 13:22:25.267 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8554 test 0.5047 metric ['0.8411']
# 100%|██████████| 200/200 [00:06<00:00, 29.31it/s]
# 2025-09-22 13:22:33.267 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4341 test 0.4487 metric ['0.8387']
# 100%|██████████| 200/200 [00:07<00:00, 28.36it/s]
# 2025-09-22 13:22:41.535 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3635 test 0.3206 metric ['0.8894']
# 100%|██████████| 200/200 [00:07<00:00, 28.41it/s]
# 2025-09-22 13:22:49.816 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3359 test 0.3516 metric ['0.8784']
# 2025-09-22 13:22:49.817 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3206, current loss 0.3516.Counter 1/10.
# 100%|██████████| 200/200 [00:07<00:00, 26.93it/s]
# 2025-09-22 13:22:58.597 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2905 test 0.2974 metric ['0.8905']
# 100%|██████████| 200/200 [00:07<00:00, 25.85it/s]
# 2025-09-22 13:23:07.644 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2692 test 0.2996 metric ['0.8920']
# 2025-09-22 13:23:07.645 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.2974, current loss 0.2996.Counter 1/10.
# 100%|██████████| 6/6 [00:50<00:00,  8.43s/it]
# 2025-09-22 13:23:07.659 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132307
# 2025-09-22 13:23:07.660 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:07<00:00, 27.29it/s]
# 2025-09-22 13:23:16.321 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8657 test 0.7112 metric ['0.7783']
# 100%|██████████| 200/200 [00:07<00:00, 28.06it/s]
# 2025-09-22 13:23:24.735 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4366 test 0.3759 metric ['0.8683']
# 100%|██████████| 200/200 [00:06<00:00, 29.28it/s]
# 2025-09-22 13:23:32.814 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3658 test 0.3793 metric ['0.8611']
# 2025-09-22 13:23:32.814 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3759, current loss 0.3793.Counter 1/10.
# 100%|██████████| 200/200 [00:07<00:00, 27.68it/s]
# 2025-09-22 13:23:41.274 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3252 test 0.3529 metric ['0.8758']
# 100%|██████████| 200/200 [00:07<00:00, 28.28it/s]
# 2025-09-22 13:23:49.755 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2985 test 0.3175 metric ['0.8848']
# 100%|██████████| 200/200 [00:06<00:00, 28.75it/s]
# 2025-09-22 13:23:57.923 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2793 test 0.3235 metric ['0.8850']
# 2025-09-22 13:23:57.923 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3175, current loss 0.3235.Counter 1/10.
# 100%|██████████| 6/6 [00:50<00:00,  8.37s/it]
# 2025-09-22 13:23:57.935 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132357
# 2025-09-22 13:23:57.936 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 28.98it/s]
# 2025-09-22 13:24:06.036 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.6888 test 0.4273 metric ['0.8502']
# 100%|██████████| 200/200 [00:06<00:00, 28.70it/s]
# 2025-09-22 13:24:14.235 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3981 test 0.3512 metric ['0.8752']
# 100%|██████████| 200/200 [00:07<00:00, 28.16it/s]
# 2025-09-22 13:24:22.574 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3428 test 0.3754 metric ['0.8662']
# 2025-09-22 13:24:22.575 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3512, current loss 0.3754.Counter 1/10.
# 100%|██████████| 200/200 [00:07<00:00, 28.39it/s]
# 2025-09-22 13:24:30.765 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3110 test 0.3577 metric ['0.8698']
# 2025-09-22 13:24:30.766 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3512, current loss 0.3577.Counter 2/10.
# 100%|██████████| 200/200 [00:06<00:00, 28.97it/s]
# 2025-09-22 13:24:38.812 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3055 test 0.3207 metric ['0.8806']
# 100%|██████████| 200/200 [00:06<00:00, 29.05it/s]
# 2025-09-22 13:24:46.866 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2836 test 0.2993 metric ['0.8914']
# 100%|██████████| 6/6 [00:48<00:00,  8.15s/it]
# 2025-09-22 13:24:46.884 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132446
# 2025-09-22 13:24:46.886 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 29.26it/s]
# 2025-09-22 13:24:54.924 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.7001 test 0.4976 metric ['0.8275']
# 100%|██████████| 200/200 [00:06<00:00, 29.14it/s]
# 2025-09-22 13:25:03.113 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3961 test 0.4820 metric ['0.8228']
# 100%|██████████| 200/200 [00:06<00:00, 29.56it/s]
# 2025-09-22 13:25:11.092 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3464 test 0.3907 metric ['0.8567']
# 100%|██████████| 200/200 [00:07<00:00, 28.55it/s]
# 2025-09-22 13:25:19.301 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3136 test 0.3198 metric ['0.8842']
# 100%|██████████| 200/200 [00:06<00:00, 28.71it/s]
# 2025-09-22 13:25:27.501 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2968 test 0.3127 metric ['0.8902']
# 100%|██████████| 200/200 [00:06<00:00, 29.19it/s]
# 2025-09-22 13:25:35.345 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2805 test 0.2807 metric ['0.8980']
# 100%|██████████| 6/6 [00:48<00:00,  8.07s/it]
# 2025-09-22 13:25:35.357 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132535
# 2025-09-22 13:25:35.358 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 30.71it/s]
# 2025-09-22 13:25:43.052 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.6924 test 0.4552 metric ['0.8462']
# 100%|██████████| 200/200 [00:06<00:00, 31.40it/s]
# 2025-09-22 13:25:50.491 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3999 test 0.3743 metric ['0.8639']
# 100%|██████████| 200/200 [00:06<00:00, 31.16it/s]
# 2025-09-22 13:25:58.082 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3300 test 0.3285 metric ['0.8817']
# 100%|██████████| 200/200 [00:06<00:00, 32.75it/s]
# 2025-09-22 13:26:05.239 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3280 test 0.3228 metric ['0.8817']
# 100%|██████████| 200/200 [00:06<00:00, 32.98it/s]
# 2025-09-22 13:26:12.343 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2885 test 0.2910 metric ['0.8897']
# 100%|██████████| 200/200 [00:06<00:00, 32.54it/s]
# 2025-09-22 13:26:19.510 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2690 test 0.2888 metric ['0.8947']
# 100%|██████████| 6/6 [00:44<00:00,  7.35s/it]
# 2025-09-22 13:26:19.522 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132619
# 2025-09-22 13:26:19.524 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:05<00:00, 33.35it/s]
# 2025-09-22 13:26:26.601 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.6651 test 0.4237 metric ['0.8434']
# 100%|██████████| 200/200 [00:06<00:00, 32.92it/s]
# 2025-09-22 13:26:33.804 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3850 test 0.4283 metric ['0.8464']
# 2025-09-22 13:26:33.805 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.4237, current loss 0.4283.Counter 1/10.
# 100%|██████████| 200/200 [00:06<00:00, 32.39it/s]
# 2025-09-22 13:26:41.052 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3537 test 0.3665 metric ['0.8672']
# 100%|██████████| 200/200 [00:05<00:00, 33.38it/s]
# 2025-09-22 13:26:48.082 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.2993 test 0.3279 metric ['0.8752']
# 100%|██████████| 200/200 [00:06<00:00, 33.17it/s]
# 2025-09-22 13:26:55.251 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2932 test 0.3148 metric ['0.8848']
# 100%|██████████| 200/200 [00:06<00:00, 31.32it/s]
# 2025-09-22 13:27:02.666 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2886 test 0.3394 metric ['0.8734']
# 2025-09-22 13:27:02.667 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3148, current loss 0.3394.Counter 1/10.
# 100%|██████████| 6/6 [00:43<00:00,  7.19s/it]
# 2025-09-22 13:27:02.679 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132702
# 2025-09-22 13:27:02.680 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 29.88it/s]
# 2025-09-22 13:27:10.475 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8912 test 0.5265 metric ['0.8231']
# 100%|██████████| 200/200 [00:06<00:00, 30.23it/s]
# 2025-09-22 13:27:18.127 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4688 test 0.3537 metric ['0.8845']
# 100%|██████████| 200/200 [00:06<00:00, 31.69it/s]
# 2025-09-22 13:27:25.521 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3753 test 0.3861 metric ['0.8656']
# 2025-09-22 13:27:25.522 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3537, current loss 0.3861.Counter 1/10.
# 100%|██████████| 200/200 [00:06<00:00, 32.02it/s]
# 2025-09-22 13:27:32.891 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3490 test 0.3334 metric ['0.8809']
# 100%|██████████| 200/200 [00:06<00:00, 30.56it/s]
# 2025-09-22 13:27:40.622 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3341 test 0.2958 metric ['0.8933']
# 100%|██████████| 200/200 [00:06<00:00, 30.89it/s]
# 2025-09-22 13:27:48.187 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3077 test 0.3026 metric ['0.8919']
# 2025-09-22 13:27:48.188 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.2958, current loss 0.3026.Counter 1/10.
# 100%|██████████| 6/6 [00:45<00:00,  7.58s/it]
# 2025-09-22 13:27:48.200 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132748
# 2025-09-22 13:27:48.202 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 31.83it/s]
# 2025-09-22 13:27:55.565 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.9602 test 0.5198 metric ['0.8389']
# 100%|██████████| 200/200 [00:06<00:00, 32.17it/s]
# 2025-09-22 13:28:02.878 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4818 test 0.4063 metric ['0.8619']
# 100%|██████████| 200/200 [00:06<00:00, 32.85it/s]
# 2025-09-22 13:28:10.012 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3856 test 0.3966 metric ['0.8639']
# 100%|██████████| 200/200 [00:06<00:00, 33.30it/s]
# 2025-09-22 13:28:17.068 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3462 test 0.3260 metric ['0.8828']
# 100%|██████████| 200/200 [00:06<00:00, 33.26it/s]
# 2025-09-22 13:28:24.183 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3418 test 0.3041 metric ['0.8930']
# 100%|██████████| 200/200 [00:06<00:00, 32.65it/s]
# 2025-09-22 13:28:31.336 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3085 test 0.3611 metric ['0.8717']
# 2025-09-22 13:28:31.336 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3041, current loss 0.3611.Counter 1/10.
# 100%|██████████| 6/6 [00:43<00:00,  7.18s/it]
# 2025-09-22 13:28:31.348 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132831
# 2025-09-22 13:28:31.349 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 31.81it/s]
# 2025-09-22 13:28:38.730 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.9309 test 0.5397 metric ['0.8400']
# 100%|██████████| 200/200 [00:06<00:00, 31.36it/s]
# 2025-09-22 13:28:46.278 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4602 test 0.3991 metric ['0.8639']
# 100%|██████████| 200/200 [00:06<00:00, 31.97it/s]
# 2025-09-22 13:28:53.601 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3956 test 0.4037 metric ['0.8566']
# 2025-09-22 13:28:53.602 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3991, current loss 0.4037.Counter 1/10.
# 100%|██████████| 200/200 [00:06<00:00, 31.24it/s]
# 2025-09-22 13:29:01.122 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3376 test 0.3684 metric ['0.8694']
# 100%|██████████| 200/200 [00:06<00:00, 29.42it/s]
# 2025-09-22 13:29:09.005 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3295 test 0.3174 metric ['0.8892']
# 100%|██████████| 200/200 [00:06<00:00, 32.59it/s]
# 2025-09-22 13:29:16.211 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3217 test 0.3026 metric ['0.8950']
# 100%|██████████| 6/6 [00:44<00:00,  7.47s/it]
# 2025-09-22 13:29:16.227 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-132916
# 2025-09-22 13:29:16.229 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 33.13it/s]
# 2025-09-22 13:29:23.330 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.9503 test 0.5685 metric ['0.8137']
# 100%|██████████| 200/200 [00:05<00:00, 33.39it/s]
# 2025-09-22 13:29:30.396 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4752 test 0.4366 metric ['0.8478']
# 100%|██████████| 200/200 [00:06<00:00, 32.60it/s]
# 2025-09-22 13:29:37.620 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3899 test 0.3545 metric ['0.8775']
# 100%|██████████| 200/200 [00:06<00:00, 32.07it/s]
# 2025-09-22 13:29:44.918 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3531 test 0.3308 metric ['0.8792']
# 100%|██████████| 200/200 [00:06<00:00, 31.40it/s]
# 2025-09-22 13:29:52.555 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3361 test 0.3184 metric ['0.8833']
# 100%|██████████| 200/200 [00:06<00:00, 31.25it/s]
# 2025-09-22 13:30:00.177 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3244 test 0.3218 metric ['0.8853']
# 2025-09-22 13:30:00.178 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3184, current loss 0.3218.Counter 1/10.
# 100%|██████████| 6/6 [00:43<00:00,  7.32s/it]
# 2025-09-22 13:30:00.196 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133000
# 2025-09-22 13:30:00.198 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 30.00it/s]
# 2025-09-22 13:30:08.151 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.9229 test 0.5413 metric ['0.8191']
# 100%|██████████| 200/200 [00:06<00:00, 31.43it/s]
# 2025-09-22 13:30:15.680 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4677 test 0.4678 metric ['0.8381']
# 100%|██████████| 200/200 [00:06<00:00, 31.93it/s]
# 2025-09-22 13:30:23.117 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3959 test 0.4452 metric ['0.8370']
# 100%|██████████| 200/200 [00:06<00:00, 31.42it/s]
# 2025-09-22 13:30:30.740 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3545 test 0.3171 metric ['0.8856']
# 100%|██████████| 200/200 [00:06<00:00, 29.28it/s]
# 2025-09-22 13:30:38.782 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3395 test 0.3580 metric ['0.8686']
# 2025-09-22 13:30:38.783 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3171, current loss 0.3580.Counter 1/10.
# 100%|██████████| 200/200 [00:06<00:00, 30.78it/s]
# 2025-09-22 13:30:46.477 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3093 test 0.3348 metric ['0.8758']
# 2025-09-22 13:30:46.478 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3171, current loss 0.3348.Counter 2/10.
# 100%|██████████| 6/6 [00:46<00:00,  7.71s/it]
# 2025-09-22 13:30:46.501 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133046
# 2025-09-22 13:30:46.503 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 29.76it/s]
# 2025-09-22 13:30:54.554 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8898 test 0.4946 metric ['0.8256']
# 100%|██████████| 200/200 [00:06<00:00, 30.30it/s]
# 2025-09-22 13:31:02.394 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4680 test 0.4601 metric ['0.8370']
# 100%|██████████| 200/200 [00:06<00:00, 30.58it/s]
# 2025-09-22 13:31:10.192 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3909 test 0.4293 metric ['0.8467']
# 100%|██████████| 200/200 [00:06<00:00, 30.39it/s]
# 2025-09-22 13:31:18.126 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3512 test 0.3494 metric ['0.8720']
# 100%|██████████| 200/200 [00:06<00:00, 30.75it/s]
# 2025-09-22 13:31:25.878 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3139 test 0.3645 metric ['0.8653']
# 2025-09-22 13:31:25.879 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3494, current loss 0.3645.Counter 1/10.
# 100%|██████████| 200/200 [00:06<00:00, 30.56it/s]
# 2025-09-22 13:31:33.629 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2922 test 0.3085 metric ['0.8848']
# 100%|██████████| 6/6 [00:47<00:00,  7.85s/it]
# 2025-09-22 13:31:33.641 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133133
# 2025-09-22 13:31:33.642 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 30.31it/s]
# 2025-09-22 13:31:41.479 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8747 test 0.5182 metric ['0.8144']
# 100%|██████████| 200/200 [00:06<00:00, 30.58it/s]
# 2025-09-22 13:31:49.247 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4486 test 0.4274 metric ['0.8531']
# 100%|██████████| 200/200 [00:06<00:00, 30.73it/s]
# 2025-09-22 13:31:56.974 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3975 test 0.4033 metric ['0.8522']
# 100%|██████████| 200/200 [00:06<00:00, 28.77it/s]
# 2025-09-22 13:32:05.171 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3563 test 0.3301 metric ['0.8791']
# 100%|██████████| 200/200 [00:06<00:00, 30.08it/s]
# 2025-09-22 13:32:13.031 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3153 test 0.3798 metric ['0.8688']
# 2025-09-22 13:32:13.032 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3301, current loss 0.3798.Counter 1/10.
# 100%|██████████| 200/200 [00:06<00:00, 29.78it/s]
# 2025-09-22 13:32:20.942 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3111 test 0.3608 metric ['0.8703']
# 2025-09-22 13:32:20.943 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3301, current loss 0.3608.Counter 2/10.
# 100%|██████████| 6/6 [00:47<00:00,  7.88s/it]
# 2025-09-22 13:32:20.955 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133220
# 2025-09-22 13:32:20.956 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 31.08it/s]
# 2025-09-22 13:32:28.642 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8598 test 0.5489 metric ['0.8009']
# 100%|██████████| 200/200 [00:06<00:00, 30.83it/s]
# 2025-09-22 13:32:36.412 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4792 test 0.4269 metric ['0.8467']
# 100%|██████████| 200/200 [00:06<00:00, 31.21it/s]
# 2025-09-22 13:32:44.022 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3886 test 0.3884 metric ['0.8595']
# 100%|██████████| 200/200 [00:05<00:00, 34.08it/s]
# 2025-09-22 13:32:51.010 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3676 test 0.3501 metric ['0.8750']
# 100%|██████████| 200/200 [00:05<00:00, 34.69it/s]
# 2025-09-22 13:32:57.820 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3350 test 0.3377 metric ['0.8764']
# 100%|██████████| 200/200 [00:05<00:00, 34.04it/s]
# 2025-09-22 13:33:04.816 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3243 test 0.3081 metric ['0.8852']
# 100%|██████████| 6/6 [00:43<00:00,  7.30s/it]
# 2025-09-22 13:33:04.830 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133304
# 2025-09-22 13:33:04.832 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:07<00:00, 28.48it/s]
# 2025-09-22 13:33:13.132 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0851 test 0.6961 metric ['0.7569']
# 100%|██████████| 200/200 [00:06<00:00, 29.18it/s]
# 2025-09-22 13:33:21.374 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5374 test 0.5598 metric ['0.8052']
# 100%|██████████| 200/200 [00:07<00:00, 25.16it/s]
# 2025-09-22 13:33:30.817 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4403 test 0.4044 metric ['0.8581']
# 100%|██████████| 200/200 [00:07<00:00, 27.57it/s]
# 2025-09-22 13:33:39.460 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3817 test 0.3695 metric ['0.8719']
# 100%|██████████| 200/200 [00:06<00:00, 28.71it/s]
# 2025-09-22 13:33:47.756 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3539 test 0.3887 metric ['0.8547']
# 2025-09-22 13:33:47.756 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3695, current loss 0.3887.Counter 1/10.
# 100%|██████████| 200/200 [00:07<00:00, 26.79it/s]
# 2025-09-22 13:33:56.531 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3269 test 0.3795 metric ['0.8586']
# 2025-09-22 13:33:56.532 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3695, current loss 0.3795.Counter 2/10.
# 100%|██████████| 6/6 [00:51<00:00,  8.61s/it]
# 2025-09-22 13:33:56.544 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133356
# 2025-09-22 13:33:56.545 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 32.19it/s]
# 2025-09-22 13:34:03.851 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0925 test 0.6878 metric ['0.7739']
# 100%|██████████| 200/200 [00:06<00:00, 32.78it/s]
# 2025-09-22 13:34:11.153 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5206 test 0.5018 metric ['0.8122']
# 100%|██████████| 200/200 [00:06<00:00, 29.09it/s]
# 2025-09-22 13:34:19.407 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4213 test 0.4222 metric ['0.8434']
# 100%|██████████| 200/200 [00:06<00:00, 28.57it/s]
# 2025-09-22 13:34:27.868 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3637 test 0.3655 metric ['0.8720']
# 100%|██████████| 200/200 [00:06<00:00, 30.16it/s]
# 2025-09-22 13:34:35.638 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3467 test 0.3629 metric ['0.8683']
# 100%|██████████| 200/200 [00:06<00:00, 33.11it/s]
# 2025-09-22 13:34:42.872 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3174 test 0.3267 metric ['0.8836']
# 100%|██████████| 6/6 [00:46<00:00,  7.72s/it]
# 2025-09-22 13:34:42.886 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133442
# 2025-09-22 13:34:42.887 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:05<00:00, 33.36it/s]
# 2025-09-22 13:34:50.051 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0906 test 0.6622 metric ['0.7853']
# 100%|██████████| 200/200 [00:05<00:00, 34.16it/s]
# 2025-09-22 13:34:56.968 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5314 test 0.4706 metric ['0.8439']
# 100%|██████████| 200/200 [00:06<00:00, 32.31it/s]
# 2025-09-22 13:35:04.353 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4241 test 0.4364 metric ['0.8456']
# 100%|██████████| 200/200 [00:06<00:00, 32.44it/s]
# 2025-09-22 13:35:11.860 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3907 test 0.4006 metric ['0.8538']
# 100%|██████████| 200/200 [00:06<00:00, 32.39it/s]
# 2025-09-22 13:35:19.261 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3543 test 0.3611 metric ['0.8750']
# 100%|██████████| 200/200 [00:06<00:00, 30.62it/s]
# 2025-09-22 13:35:27.050 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3245 test 0.3284 metric ['0.8802']
# 100%|██████████| 6/6 [00:44<00:00,  7.35s/it]
# 2025-09-22 13:35:27.064 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133527
# 2025-09-22 13:35:27.065 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 29.41it/s]
# 2025-09-22 13:35:35.066 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0280 test 0.6029 metric ['0.7941']
# 100%|██████████| 200/200 [00:06<00:00, 31.61it/s]
# 2025-09-22 13:35:42.655 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5125 test 0.4270 metric ['0.8564']
# 100%|██████████| 200/200 [00:06<00:00, 32.81it/s]
# 2025-09-22 13:35:49.869 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4372 test 0.3844 metric ['0.8639']
# 100%|██████████| 200/200 [00:06<00:00, 33.10it/s]
# 2025-09-22 13:35:56.969 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3714 test 0.3541 metric ['0.8756']
# 100%|██████████| 200/200 [00:05<00:00, 33.96it/s]
# 2025-09-22 13:36:03.975 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3430 test 0.3256 metric ['0.8789']
# 100%|██████████| 200/200 [00:06<00:00, 32.49it/s]
# 2025-09-22 13:36:11.480 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3196 test 0.3386 metric ['0.8769']
# 2025-09-22 13:36:11.481 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3256, current loss 0.3386.Counter 1/10.
# 100%|██████████| 6/6 [00:44<00:00,  7.40s/it]
# 2025-09-22 13:36:11.495 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133611
# 2025-09-22 13:36:11.496 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 32.30it/s]
# 2025-09-22 13:36:18.799 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.9630 test 0.5715 metric ['0.7839']
# 100%|██████████| 200/200 [00:06<00:00, 32.45it/s]
# 2025-09-22 13:36:26.192 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5127 test 0.4867 metric ['0.8291']
# 100%|██████████| 200/200 [00:06<00:00, 32.96it/s]
# 2025-09-22 13:36:33.429 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4354 test 0.3902 metric ['0.8609']
# 100%|██████████| 200/200 [00:06<00:00, 32.29it/s]
# 2025-09-22 13:36:40.840 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3851 test 0.3729 metric ['0.8688']
# 100%|██████████| 200/200 [00:05<00:00, 34.18it/s]
# 2025-09-22 13:36:47.886 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3586 test 0.3469 metric ['0.8761']
# 100%|██████████| 200/200 [00:05<00:00, 34.62it/s]
# 2025-09-22 13:36:54.715 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3292 test 0.3276 metric ['0.8841']
# 100%|██████████| 6/6 [00:43<00:00,  7.20s/it]
# 2025-09-22 13:36:54.730 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133654
# 2025-09-22 13:36:54.732 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:05<00:00, 33.85it/s]
# 2025-09-22 13:37:01.778 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.9477 test 0.5474 metric ['0.7972']
# 100%|██████████| 200/200 [00:05<00:00, 33.69it/s]
# 2025-09-22 13:37:08.846 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5221 test 0.4637 metric ['0.8228']
# 100%|██████████| 200/200 [00:05<00:00, 33.78it/s]
# 2025-09-22 13:37:15.834 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4441 test 0.3916 metric ['0.8664']
# 100%|██████████| 200/200 [00:06<00:00, 32.36it/s]
# 2025-09-22 13:37:23.119 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3718 test 0.3633 metric ['0.8734']
# 100%|██████████| 200/200 [00:07<00:00, 28.12it/s]
# 2025-09-22 13:37:31.740 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3493 test 0.3281 metric ['0.8839']
# 100%|██████████| 200/200 [00:07<00:00, 25.89it/s]
# 2025-09-22 13:37:40.685 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3445 test 0.3282 metric ['0.8811']
# 2025-09-22 13:37:40.686 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3281, current loss 0.3282.Counter 1/10.
# 100%|██████████| 6/6 [00:45<00:00,  7.65s/it]
# 2025-09-22 13:37:40.701 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133740
# 2025-09-22 13:37:40.702 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 32.59it/s]
# 2025-09-22 13:37:48.085 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.9792 test 0.5905 metric ['0.7844']
# 100%|██████████| 200/200 [00:05<00:00, 33.98it/s]
# 2025-09-22 13:37:55.000 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5001 test 0.4893 metric ['0.8277']
# 100%|██████████| 200/200 [00:06<00:00, 31.76it/s]
# 2025-09-22 13:38:02.464 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4160 test 0.3789 metric ['0.8639']
# 100%|██████████| 200/200 [00:05<00:00, 33.79it/s]
# 2025-09-22 13:38:09.437 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3856 test 0.3564 metric ['0.8730']
# 100%|██████████| 200/200 [00:05<00:00, 35.10it/s]
# 2025-09-22 13:38:16.313 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3509 test 0.3503 metric ['0.8741']
# 100%|██████████| 200/200 [00:05<00:00, 34.02it/s]
# 2025-09-22 13:38:23.328 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3397 test 0.3204 metric ['0.8819']
# 100%|██████████| 6/6 [00:42<00:00,  7.10s/it]
# 2025-09-22 13:38:23.344 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133823
# 2025-09-22 13:38:23.345 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:05<00:00, 34.33it/s]
# 2025-09-22 13:38:30.240 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.9685 test 0.5368 metric ['0.8037']
# 100%|██████████| 200/200 [00:05<00:00, 34.34it/s]
# 2025-09-22 13:38:37.191 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.4991 test 0.4461 metric ['0.8367']
# 100%|██████████| 200/200 [00:05<00:00, 33.81it/s]
# 2025-09-22 13:38:44.215 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4255 test 0.3982 metric ['0.8553']
# 100%|██████████| 200/200 [00:06<00:00, 32.87it/s]
# 2025-09-22 13:38:51.558 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3696 test 0.3732 metric ['0.8705']
# 100%|██████████| 200/200 [00:06<00:00, 29.25it/s]
# 2025-09-22 13:38:59.594 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3633 test 0.3515 metric ['0.8769']
# 100%|██████████| 200/200 [00:06<00:00, 31.30it/s]
# 2025-09-22 13:39:07.150 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3298 test 0.3561 metric ['0.8817']
# 2025-09-22 13:39:07.151 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3515, current loss 0.3561.Counter 1/10.
# 100%|██████████| 6/6 [00:43<00:00,  7.30s/it]
# 2025-09-22 13:39:07.168 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133907
# 2025-09-22 13:39:07.170 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 30.16it/s]
# 2025-09-22 13:39:15.051 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2343 test 0.6333 metric ['0.7864']
# 100%|██████████| 200/200 [00:06<00:00, 32.40it/s]
# 2025-09-22 13:39:22.363 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6112 test 0.5271 metric ['0.8186']
# 100%|██████████| 200/200 [00:06<00:00, 31.28it/s]
# 2025-09-22 13:39:30.001 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5009 test 0.4502 metric ['0.8414']
# 100%|██████████| 200/200 [00:06<00:00, 33.21it/s]
# 2025-09-22 13:39:37.176 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4539 test 0.4015 metric ['0.8642']
# 100%|██████████| 200/200 [00:06<00:00, 32.01it/s]
# 2025-09-22 13:39:44.570 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4016 test 0.3670 metric ['0.8748']
# 100%|██████████| 200/200 [00:06<00:00, 32.56it/s]
# 2025-09-22 13:39:51.974 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3848 test 0.4068 metric ['0.8575']
# 2025-09-22 13:39:51.974 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3670, current loss 0.4068.Counter 1/10.
# 100%|██████████| 6/6 [00:44<00:00,  7.46s/it]
# 2025-09-22 13:39:51.987 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-133951
# 2025-09-22 13:39:51.988 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 33.22it/s]
# 2025-09-22 13:39:59.149 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2288 test 0.7073 metric ['0.7598']
# 100%|██████████| 200/200 [00:06<00:00, 32.66it/s]
# 2025-09-22 13:40:06.376 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6223 test 0.5166 metric ['0.8145']
# 100%|██████████| 200/200 [00:05<00:00, 33.70it/s]
# 2025-09-22 13:40:13.336 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5177 test 0.4460 metric ['0.8413']
# 100%|██████████| 200/200 [00:05<00:00, 33.64it/s]
# 2025-09-22 13:40:20.332 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4369 test 0.3833 metric ['0.8581']
# 100%|██████████| 200/200 [00:05<00:00, 33.78it/s]
# 2025-09-22 13:40:27.289 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4027 test 0.4379 metric ['0.8361']
# 2025-09-22 13:40:27.289 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3833, current loss 0.4379.Counter 1/10.
# 100%|██████████| 200/200 [00:05<00:00, 33.39it/s]
# 2025-09-22 13:40:34.387 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3988 test 0.3947 metric ['0.8648']
# 2025-09-22 13:40:34.388 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3833, current loss 0.3947.Counter 2/10.
# 100%|██████████| 6/6 [00:42<00:00,  7.06s/it]
# 2025-09-22 13:40:34.406 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-134034
# 2025-09-22 13:40:34.408 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:05<00:00, 34.04it/s]
# 2025-09-22 13:40:41.374 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2695 test 0.6781 metric ['0.7747']
# 100%|██████████| 200/200 [00:06<00:00, 32.11it/s]
# 2025-09-22 13:40:48.831 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6125 test 0.5306 metric ['0.8027']
# 100%|██████████| 200/200 [00:05<00:00, 33.52it/s]
# 2025-09-22 13:40:55.886 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5398 test 0.4657 metric ['0.8370']
# 100%|██████████| 200/200 [00:05<00:00, 33.44it/s]
# 2025-09-22 13:41:03.033 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4656 test 0.4240 metric ['0.8519']
# 100%|██████████| 200/200 [00:05<00:00, 34.00it/s]
# 2025-09-22 13:41:10.018 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4030 test 0.3721 metric ['0.8759']
# 100%|██████████| 200/200 [00:06<00:00, 33.33it/s]
# 2025-09-22 13:41:17.140 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3743 test 0.3500 metric ['0.8802']
# 100%|██████████| 6/6 [00:42<00:00,  7.12s/it]
# 2025-09-22 13:41:17.153 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-134117
# 2025-09-22 13:41:17.154 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:06<00:00, 31.47it/s]
# 2025-09-22 13:41:24.606 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2884 test 0.7256 metric ['0.7512']
# 100%|██████████| 200/200 [00:06<00:00, 33.30it/s]
# 2025-09-22 13:41:31.798 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6106 test 0.5232 metric ['0.8120']
# 100%|██████████| 200/200 [00:05<00:00, 33.64it/s]
# 2025-09-22 13:41:38.875 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4900 test 0.4136 metric ['0.8544']
# 100%|██████████| 200/200 [00:06<00:00, 32.88it/s]
# 2025-09-22 13:41:46.059 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4553 test 0.4347 metric ['0.8425']
# 2025-09-22 13:41:46.059 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.4136, current loss 0.4347.Counter 1/10.
# 100%|██████████| 200/200 [00:06<00:00, 33.16it/s]
# 2025-09-22 13:41:53.296 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4190 test 0.3669 metric ['0.8692']
# 100%|██████████| 200/200 [00:06<00:00, 33.10it/s]
# 2025-09-22 13:42:00.604 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3692 test 0.3376 metric ['0.8838']
# 100%|██████████| 6/6 [00:43<00:00,  7.24s/it]
# 2025-09-22 13:42:00.624 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-134200
# 2025-09-22 13:42:00.626 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:14<00:00, 13.85it/s]
# 2025-09-22 13:42:17.317 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.6198 test 0.5984 metric ['0.7867']
# 100%|██████████| 200/200 [00:15<00:00, 13.13it/s]
# 2025-09-22 13:42:34.807 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3731 test 0.3833 metric ['0.8608']
# 100%|██████████| 200/200 [00:14<00:00, 13.82it/s]
# 2025-09-22 13:42:51.426 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3202 test 0.3210 metric ['0.8847']
# 100%|██████████| 200/200 [00:14<00:00, 14.00it/s]
# 2025-09-22 13:43:07.915 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.2891 test 0.3050 metric ['0.8908']
# 100%|██████████| 200/200 [00:14<00:00, 13.75it/s]
# 2025-09-22 13:43:24.715 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2676 test 0.3691 metric ['0.8670']
# 2025-09-22 13:43:24.716 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3050, current loss 0.3691.Counter 1/10.
# 100%|██████████| 200/200 [00:15<00:00, 13.02it/s]
# 2025-09-22 13:43:42.393 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2615 test 0.3132 metric ['0.8828']
# ...
# 100%|██████████| 200/200 [00:55<00:00,  3.57it/s]
# 2025-09-22 18:41:13.224 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3429 test 0.3350 metric ['0.8858']
# 100%|██████████| 6/6 [06:42<00:00, 67.13s/it]
# 2025-09-22 18:41:13.291 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-184113
# 2025-09-22 18:41:13.293 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:56<00:00,  3.52it/s]
# 2025-09-22 18:42:18.294 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.1013 test 0.5923 metric ['0.7731']
# 100%|██████████| 200/200 [00:48<00:00,  4.12it/s]
# 2025-09-22 18:43:13.881 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5455 test 0.4732 metric ['0.8295']
# 100%|██████████| 200/200 [00:49<00:00,  4.00it/s]
# 2025-09-22 18:44:10.379 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4587 test 0.4056 metric ['0.8559']
# 100%|██████████| 200/200 [00:49<00:00,  4.01it/s]
# 2025-09-22 18:45:07.978 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4145 test 0.4181 metric ['0.8570']
# 2025-09-22 18:45:07.979 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.4056, current loss 0.4181.Counter 1/10.
# 100%|██████████| 200/200 [00:49<00:00,  4.06it/s]
# 2025-09-22 18:46:04.191 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3501 test 0.3890 metric ['0.8709']
# 100%|██████████| 200/200 [00:50<00:00,  3.99it/s]
# 2025-09-22 18:47:01.681 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3528 test 0.3575 metric ['0.8688']
# 100%|██████████| 6/6 [05:48<00:00, 58.06s/it]
# 2025-09-22 18:47:01.723 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-184701
# 2025-09-22 18:47:01.724 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:49<00:00,  4.06it/s]
# 2025-09-22 18:47:58.236 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0412 test 0.6359 metric ['0.7594']
# 100%|██████████| 200/200 [00:50<00:00,  3.97it/s]
# 2025-09-22 18:48:56.038 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5438 test 0.4917 metric ['0.8220']
# 100%|██████████| 200/200 [00:49<00:00,  4.02it/s]
# 2025-09-22 18:49:52.107 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4534 test 0.4114 metric ['0.8503']
# 100%|██████████| 200/200 [00:50<00:00,  3.96it/s]
# 2025-09-22 18:50:49.702 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4005 test 0.3705 metric ['0.8691']
# 100%|██████████| 200/200 [00:52<00:00,  3.84it/s]
# 2025-09-22 18:51:48.930 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3741 test 0.3744 metric ['0.8716']
# 2025-09-22 18:51:48.931 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3705, current loss 0.3744.Counter 1/10.
# 100%|██████████| 200/200 [00:51<00:00,  3.87it/s]
# 2025-09-22 18:52:47.962 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3498 test 0.3419 metric ['0.8798']
# 100%|██████████| 6/6 [05:46<00:00, 57.70s/it]
# 2025-09-22 18:52:48.008 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-185248
# 2025-09-22 18:52:48.010 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:52<00:00,  3.81it/s]
# 2025-09-22 18:53:48.125 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.1334 test 0.6081 metric ['0.7758']
# 100%|██████████| 200/200 [00:51<00:00,  3.89it/s]
# 2025-09-22 18:54:46.403 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.5690 test 0.4634 metric ['0.8330']
# 100%|██████████| 200/200 [00:52<00:00,  3.85it/s]
# 2025-09-22 18:55:45.889 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.4542 test 0.4150 metric ['0.8492']
# 100%|██████████| 200/200 [00:51<00:00,  3.88it/s]
# 2025-09-22 18:56:45.181 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3978 test 0.3795 metric ['0.8616']
# 100%|██████████| 200/200 [00:51<00:00,  3.91it/s]
# 2025-09-22 18:57:44.033 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.3614 test 0.3646 metric ['0.8658']
# 100%|██████████| 200/200 [00:51<00:00,  3.91it/s]
# 2025-09-22 18:58:43.051 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3530 test 0.3829 metric ['0.8595']
# 2025-09-22 18:58:43.051 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3646, current loss 0.3829.Counter 1/10.
# 100%|██████████| 6/6 [05:54<00:00, 59.17s/it]
# 2025-09-22 18:58:43.089 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-185843
# 2025-09-22 18:58:43.091 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:53<00:00,  3.77it/s]
# 2025-09-22 18:59:44.360 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.3709 test 0.7443 metric ['0.7478']
# 100%|██████████| 200/200 [00:51<00:00,  3.87it/s]
# 2025-09-22 19:00:43.755 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6687 test 0.5495 metric ['0.8023']
# 100%|██████████| 200/200 [00:50<00:00,  3.93it/s]
# 2025-09-22 19:01:41.892 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5512 test 0.5213 metric ['0.8175']
# 100%|██████████| 200/200 [00:54<00:00,  3.65it/s]
# 2025-09-22 19:02:48.559 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4840 test 0.5056 metric ['0.8203']
# 100%|██████████| 200/200 [00:57<00:00,  3.49it/s]
# 2025-09-22 19:03:54.859 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4378 test 0.3941 metric ['0.8605']
# 100%|██████████| 200/200 [00:56<00:00,  3.51it/s]
# 2025-09-22 19:05:00.419 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3981 test 0.3672 metric ['0.8744']
# 100%|██████████| 6/6 [06:17<00:00, 62.88s/it]
# 2025-09-22 19:05:00.475 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-190500
# 2025-09-22 19:05:00.477 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:53<00:00,  3.73it/s]
# 2025-09-22 19:06:01.990 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.3439 test 0.8120 metric ['0.7203']
# 100%|██████████| 200/200 [00:55<00:00,  3.60it/s]
# 2025-09-22 19:07:06.021 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6737 test 0.5713 metric ['0.7870']
# 100%|██████████| 200/200 [00:54<00:00,  3.67it/s]
# 2025-09-22 19:08:08.480 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5648 test 0.4817 metric ['0.8341']
# 100%|██████████| 200/200 [00:59<00:00,  3.35it/s]
# 2025-09-22 19:09:16.905 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4754 test 0.4338 metric ['0.8447']
# 100%|██████████| 200/200 [01:03<00:00,  3.17it/s]
# 2025-09-22 19:10:28.308 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4240 test 0.4307 metric ['0.8550']
# 100%|██████████| 200/200 [00:54<00:00,  3.67it/s]
# 2025-09-22 19:11:30.939 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4147 test 0.3594 metric ['0.8772']
# 100%|██████████| 6/6 [06:30<00:00, 65.07s/it]
# 2025-09-22 19:11:30.992 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-191130
# 2025-09-22 19:11:30.993 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [00:54<00:00,  3.65it/s]
# 2025-09-22 19:12:34.295 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.3096 test 0.6989 metric ['0.7566']
# 100%|██████████| 200/200 [00:59<00:00,  3.35it/s]
# 2025-09-22 19:13:42.766 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6686 test 0.5760 metric ['0.7944']
# 100%|██████████| 200/200 [00:56<00:00,  3.53it/s]
# 2025-09-22 19:14:51.896 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5289 test 0.5056 metric ['0.8241']
# 100%|██████████| 200/200 [00:58<00:00,  3.42it/s]
# 2025-09-22 19:15:58.885 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4748 test 0.4218 metric ['0.8494']
# 100%|██████████| 200/200 [00:57<00:00,  3.48it/s]
# 2025-09-22 19:17:08.992 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4363 test 0.3869 metric ['0.8669']
# 100%|██████████| 200/200 [00:54<00:00,  3.64it/s]
# 2025-09-22 19:18:14.293 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.4032 test 0.3516 metric ['0.8798']
# 100%|██████████| 6/6 [06:43<00:00, 67.21s/it]
# 2025-09-22 19:18:14.340 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-191814
# 2025-09-22 19:18:14.342 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 200/200 [01:01<00:00,  3.26it/s]
# 2025-09-22 19:19:24.746 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.4622 test 0.8886 metric ['0.6886']
# 100%|██████████| 200/200 [00:56<00:00,  3.53it/s]
# 2025-09-22 19:20:28.725 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6882 test 0.5474 metric ['0.7981']
# 100%|██████████| 200/200 [00:54<00:00,  3.66it/s]
# 2025-09-22 19:21:32.000 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5531 test 0.4906 metric ['0.8280']
# 100%|██████████| 200/200 [00:53<00:00,  3.74it/s]
# 2025-09-22 19:22:33.290 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4826 test 0.4174 metric ['0.8481']
# 100%|██████████| 200/200 [00:55<00:00,  3.63it/s]
# 2025-09-22 19:23:36.173 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4454 test 0.3974 metric ['0.8569']
# 100%|██████████| 200/200 [00:55<00:00,  3.57it/s]
# 2025-09-22 19:24:41.360 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.3911 test 0.3606 metric ['0.8720']
# 100%|██████████| 6/6 [06:26<00:00, 64.50s/it]
# 2025-09-22 19:24:41.379 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs\20250922-192441
# 2025-09-22 19:24:41.380 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 79
#      77 for combo in itertools.product(*values):
#      78     hp = dict(zip(keys, combo))
# ---> 79     run_one(hp)
#
# Cell In[26], line 67, in run_one(hp)
#      64     trainer.optimizer_kwargs = {"lr": hp["lr"], "weight_decay": hp["weight_decay"]}
#      66     # Trainen/valideren
# ---> 67     trainer.loop()  # jouw Trainer logt MLFLOW/TOML al via settings
#      69     # (Optioneel) extra metrics of artefacten loggen
#      70     # mlflow.log_metric("final_val_acc", float(...))
#      71     # mlflow.log_artifact("path/naar/confusion_matrix.png")
#      72 return
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mltrainer\trainer.py:95, in Trainer.loop(self)
#      93 epoch = 0
#      94 for epoch in tqdm(range(self.settings.epochs), colour="#1e4706"):
# ---> 95     train_loss = self.trainbatches()
#      96     metric_dict, test_loss = self.evalbatches()
#      97     self.report(epoch, train_loss, test_loss, metric_dict)
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mltrainer\trainer.py:124, in Trainer.trainbatches(self)
#     122     x, y = x.to(self.device), y.to(self.device)
#     123 self.optimizer.zero_grad()  # type: ignore
# --> 124 yhat = self.model(x)
#     125 loss = self.loss_fn(yhat, y)
#     126 loss.backward()
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# Cell In[24], line 87, in FlexCNN.forward(self, x)
#      85 def forward(self, x):
#      86     for block in self.convs:
# ---> 87         x = block(x)
#      88     x = self.global_pool_layer(x)
#      89     logits = self.dense(x)
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\modules\container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\modules\pooling.py:224, in MaxPool2d.forward(self, input)
#     223 def forward(self, input: Tensor):
# --> 224     return F.max_pool2d(
#     225         input,
#     226         self.kernel_size,
#     227         self.stride,
#     228         self.padding,
#     229         self.dilation,
#     230         ceil_mode=self.ceil_mode,
#     231         return_indices=self.return_indices,
#     232     )
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\_jit_internal.py:627, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     625     return if_true(*args, **kwargs)
#     626 else:
# --> 627     return if_false(*args, **kwargs)
#
# File c:\GitHub\portfolio-JN\.venv\Lib\site-packages\torch\nn\functional.py:827, in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     825 if stride is None:
#     826     stride = torch.jit.annotate(list[int], [])
# --> 827 return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# RuntimeError: Given input size: (512x1x1). Calculated output size: (512x0x0). Output size is too small

# %%
import toml
import mlflow
from pathlib import Path

mlflow.set_tracking_uri("file:///C:/GitHub/portfolio-JN/2-hypertuning-mlflow/mlruns")
mlflow.set_experiment("hyperparam_scan")


for run_dir in Path("modellogs").iterdir():
    model_toml = run_dir / "model.toml"
    results_toml = run_dir / "results.toml"
    if not (model_toml.exists() and results_toml.exists()):
        continue

    cfg = toml.load(model_toml)
    res = toml.load(results_toml)

    with mlflow.start_run(run_name=run_dir.name):
        # parameters
        for k,v in cfg["train"].items():
            mlflow.log_param(k, v)
        for k,v in cfg["model"].items():
            mlflow.log_param(k, v)

        # metrics
        for k,v in res["metrics"].items():
            mlflow.log_metric(k, v)

        # artifacts (optioneel)
        mlflow.log_artifacts(str(run_dir))
# Out:
# WARNI [root] Malformed experiment '1'. Detailed error Yaml file 'C:\GitHub\portfolio-JN\2-hypertuning-mlflow\mlruns\1\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 366, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 464, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 1634, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 1627, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\utils\yaml_utils.py", line 107, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\GitHub\portfolio-JN\2-hypertuning-mlflow\mlruns\1\meta.yaml' does not exist.
# 2025/09/20 10:46:20 INFO mlflow.tracking.fluent: Experiment with name 'hyperparam_scan' does not exist. Creating a new experiment.
# WARNI [root] Malformed experiment '1'. Detailed error Yaml file 'C:\GitHub\portfolio-JN\2-hypertuning-mlflow\mlruns\1\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 366, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 464, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 1634, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 1627, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\utils\yaml_utils.py", line 107, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\GitHub\portfolio-JN\2-hypertuning-mlflow\mlruns\1\meta.yaml' does not exist.

# %%
import mlflow
import toml
from pathlib import Path

mlflow.set_tracking_uri("file:///C:/GitHub/portfolio-JN/2-hypertuning-mlflow/mlruns")
mlflow.set_experiment("hyperparam_scan")

for run_dir in Path("modellogs").iterdir():
    model_toml = run_dir / "model.toml"
    results_toml = run_dir / "results.toml"
    if not (model_toml.exists() and results_toml.exists()):
        continue

    cfg = toml.load(model_toml)
    res = toml.load(results_toml)

    with mlflow.start_run(run_name=run_dir.name):
        # parameters
        for section in ["train", "model", "data"]:
            if section in cfg:
                for k, v in cfg[section].items():
                    mlflow.log_param(f"{section}.{k}", v)

        # metrics
        for k, v in res["metrics"].items():
            mlflow.log_metric(k, v)

        # artifacts (optioneel: log de hele map)
        mlflow.log_artifacts(str(run_dir))
# Out:
# WARNI [root] Malformed experiment '1'. Detailed error Yaml file 'C:\GitHub\portfolio-JN\2-hypertuning-mlflow\mlruns\1\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 366, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 464, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 1634, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 1627, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\GitHub\portfolio-JN\.venv\Lib\site-packages\mlflow\utils\yaml_utils.py", line 107, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\GitHub\portfolio-JN\2-hypertuning-mlflow\mlruns\1\meta.yaml' does not exist.
